# %%
# ==========================================================
# FINAL, COMPLETE TRAINING SCRIPT FOR ZONAL-MEAN (2D) OUTPUT
# ==========================================================
# This script has been fully reviewed and corrected to handle the
# new 2D target variable without shape or variable name errors.

import os
import gc
import logging
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import r2_score
from keras.models import Model
from keras.layers import Dense, PReLU, Dropout, Conv2D, Flatten, MaxPooling2D, Activation
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA
from scipy.stats import pearsonr
import xarray as xr
import scipy.io as sio
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
import joblib


# --- 1. Configuration ---
# Ensure this section points to the correct files for the model you are training (e.g., CESM1 or CESM2)
# Using CESM2 paths as an example:
path_input = "/ocean/projects/ees250004p/ezhu3/data/CESM1/control/input.B1850C5CN.TS.ANN.0400-2200.new.nc"
In_name = "TS" 
path_output = "/ocean/projects/ees250004p/ezhu3/data/CESM1/control/output.B1850C5CN.TOA.zmean.ANN.0400-2200.new.nc"
Out_name = "TOA_anom"
data_dir_out = '/ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D_PCA'

# Hyperparameters from your script
kernels = [32, 32]
kernel_acts = ["gelu", "gelu"]
hiddens = [16, 8]
activation_function_dense = ["PReLU", "PReLU"]
loss_function = 'mse'
reg_strength = 0
dropout_rate = 0.25
epoch_max = 25000
batch_size = 32
learning_rate = 0.000005
num_folds = 5
NNrepeats = 1
Use_PCA_y =  1
PCA_y_variability_factor = 0.9999
# This assumes 'my_callbacks' and 'logger' are configured as in your script.
# For simplicity, they are omitted here but should be in your final code.
# Out:
# 2025-07-16 02:17:18.459558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-16 02:17:19.789363: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-16 02:17:20.071707: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import logging
from tensorflow.keras.callbacks import Callback

def create_NN_name():
    NN_name = 'CNN'
    activation_function_str = '_' + kernel_acts[0] + '+' + activation_function_dense[0]
    NN_structure_str = 'x'.join(map(str, kernels))
    reg_str = f'Reg{reg_strength}' + (f'Drop{dropout_rate}' if dropout_rate != 0 else '')
    batch_size_str = f'BS{batch_size}_'
    # This creates a long, descriptive name like "CNN_Neur32x32_BS32_..."
    return f"{NN_name}_Neur{NN_structure_str}_{batch_size_str}{num_folds}foldCV_{reg_str}{activation_function_str}"

NN_name = create_NN_name()
# The final output_dir will be something like .../trained_model_2D/NeuralNet/CNN_Neur32x32.../TOA_anom
output_dir = os.path.join(data_dir_out, 'NeuralNet', NN_name, "TOA_anom")
os.makedirs(output_dir, exist_ok=True)
print(f"✅ Models and logs will be saved in: {output_dir}")

# ==========================================================
# Logger and Custom Callback Configuration
# ==========================================================

# --- 1. Configure the Logger ---
# This sets up logging to save progress messages to 'logfile.log'
# and also print them to your screen.

print("--- Configuring Logger ---")
logger_name = 'logfile.log'
# Get a logger instance
logger = logging.getLogger(__name__)
# Clear existing handlers to avoid duplicate messages in notebooks
if (logger.hasHandlers()):
    logger.handlers.clear()
    
logger.setLevel(logging.INFO)

# Create handlers for file and console
file_handler = logging.FileHandler(os.path.join(output_dir, logger_name))
console_handler = logging.StreamHandler()
file_handler.setLevel(logging.INFO)
console_handler.setLevel(logging.INFO)

# Create a formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add the handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

logger.info(f"Logging configured. Output will be saved in: {output_dir}")


# --- 2. Define Custom Callback for Periodic Logging ---
# This creates the functionality to print the training loss every 10 epochs.

print("--- Defining Custom Keras Callbacks ---")
log_path = os.path.join(output_dir, 'training_logs.txt')

class PrintTrainingOnTextEvery10EpochsCallback(Callback):
    def __init__(self, log_path):
        super().__init__()
        self.log_path = log_path

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        if epoch % 10 == 0:
            # Log to a text file
            with open(self.log_path, "a") as log_file:
                log_file.write(
                    f"Epoch: {epoch:>4} | "
                    f"Loss: {logs.get('loss', 0):.2e} | "
                    f"Validation loss: {logs.get('val_loss', 0):.2e}\n"
                )
            # Also print to the console
            print(
                f"Epoch {epoch:>4} - "
                f"Loss: {logs.get('loss', 0):.2e}, "
                f"Validation loss: {logs.get('val_loss', 0):.2e}"
            )

# Create the my_callbacks list that will be passed to model.fit()
my_callbacks = [
    PrintTrainingOnTextEvery10EpochsCallback(log_path=log_path),
]

print("✅ Logger and my_callbacks are now defined.")
# Out:
# 2025-07-16 02:17:25,669 - Logging configured. Output will be saved in: /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D_PCA/NeuralNet/CNN_Neur32x32_BS32_5foldCV_Reg0Drop0.25_gelu+PReLU/TOA_anom
# ✅ Models and logs will be saved in: /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D_PCA/NeuralNet/CNN_Neur32x32_BS32_5foldCV_Reg0Drop0.25_gelu+PReLU/TOA_anom
# --- Configuring Logger ---
# --- Defining Custom Keras Callbacks ---
# ✅ Logger and my_callbacks are now defined.

# %%
# --- 2. Load and Prepare Data ---
print("--- Loading and Preparing Data ---")
# Load input data (TS maps)
ds_X = xr.open_dataset(path_input)
input_data = ds_X[In_name].values # Shape: (time, lat, lon)
lat = ds_X['lat'].values
lon = ds_X['lon'].values
num_latitudes = len(lat)

# Load NEW target output data (zonal-mean TOA)
ds_y = xr.open_dataset(path_output)
output_data = ds_y[Out_name].values # Shape: (time, lat)

# Check for consistent time dimension length
if input_data.shape[0] != output_data.shape[0]:
    raise ValueError(f"Time dimension mismatch! Input X has {input_data.shape[0]} samples, while Target Y has {output_data.shape[0]} samples.")

# The variables X and y will hold the raw data before normalization
X = input_data[:, :, :, np.newaxis] # Add channel dimension
y = output_data # Already in the correct [time, lat] shape

print(f"Input data shape (X): {X.shape}")
print(f"Output data shape (y): {y.shape}")

# --- 3. Normalization ---
print("--- Normalizing Data ---")
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
y_mean = np.mean(y, axis=0)
y_std = np.std(y, axis=0)

# These are the final, normalized arrays we will use for training
X_norm = (X - X_mean) / X_std
y_norm = (y - y_mean) / y_std
print("✅ Normalization complete.")

# Save normalization statistics
os.makedirs(data_dir_out, exist_ok=True)
sio.savemat(os.path.join(data_dir_out, 'Normalization_zonal.mat'),
            {'X_mean': X_mean, 'X_std': X_std, 'y_mean': y_mean, 'y_std': y_std})
print(f"Normalization data saved to {data_dir_out}")
# Out:
# --- Loading and Preparing Data ---
# Input data shape (X): (1801, 192, 288, 1)
# Output data shape (y): (1801, 192)
# --- Normalizing Data ---
# ✅ Normalization complete.
# Normalization data saved to /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D_PCA

# %%
# --- 4. Define train_model function ---
def train_model(X_train, y_train, X_test, y_test, y_mean, y_std):
    kernels = [32, 32]
    kernel_acts =  ["gelu", "gelu"]
    kernel_size = 3
    stride = 1
    rng_seed = 42
    hiddens = [16, 8]
    activation_function_dense = ["PRelu", "PRelu"]
    pool_size = 2

    inputs = tf.keras.Input(shape=(X_train.shape[1:]),)
    layers = inputs

    # Convolutional Layers
    for i, kernel_filters in enumerate(kernels): # Assuming kernels is a list of filter numbers
        layers = Conv2D(
            kernel_filters,
            (kernel_size, kernel_size), # Assuming kernel_size is defined
            strides=(stride, stride),     # Assuming stride is defined
            use_bias=True,
            padding="same",
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming kernel_acts[i] could be 'prelu', 'gelu', 'relu', etc.
        if kernel_acts[i].lower() == 'prelu':
            layers = PReLU(shared_axes=[1, 2],
                           alpha_initializer=tf.keras.initializers.Constant(0.25) # Common starting point
                          )(layers) # shared_axes for Conv2D with channels_last
        elif kernel_acts[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers) # Using Activation layer for GeLU
        elif kernel_acts[i]: # For 'relu', 'elu', etc.
            layers = tf.keras.layers.Activation(kernel_acts[i])(layers)
        # If kernel_acts[i] is None or an empty string, no explicit activation layer added here.

        layers = MaxPooling2D((pool_size, pool_size))(layers) # Assuming pool_size is defined
    
    layers = Flatten()(layers)
    # Dense Layers
    for i, hidden_units in enumerate(hiddens): # Assuming hiddens is a list of unit numbers
        layers = Dense(
            hidden_units,
            use_bias=True,
            # NO 'activation' argument here
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming activation_function_dense[i] could be 'prelu', 'gelu', 'elu', etc.
        if activation_function_dense[i].lower() == 'prelu':
            layers = PReLU(alpha_initializer=tf.keras.initializers.Constant(0.25))(layers) # No shared_axes for Dense
        elif activation_function_dense[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers)
        elif activation_function_dense[i]: # For 'elu', 'relu', etc.
            layers = tf.keras.layers.Activation(activation_function_dense[i])(layers)
        # If activation_function_dense[i] is None or an empty string, no explicit activation layer.

    num_latitudes = len(lat) # or lat.size
    output_layer = Dense(
        num_latitudes, # This is the change
        activation="linear",
        use_bias=True,
        bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
    )(layers)
    
    model = Model(inputs, output_layer)
    if fold_no + ens_no == 2: # Assuming these are defined in your script's scope
        model.summary()
        with open(os.path.join(output_dir, 'model_' + names_str  + '.txt'), 'w') as f:
            model.summary(print_fn=lambda x: f.write(x + '\n'))
            
        dot_img_file = os.path.join(output_dir, 'model_' + names_str  + '.png')
        plot_model(model, to_file=dot_img_file, show_shapes=True, show_dtype=False, show_layer_names=True,rankdir='LR',expand_nested=False,dpi=300,show_layer_activations=True)

    model.compile(loss=loss_function, optimizer=Adam(learning_rate=learning_rate)) # Assuming these are defined

    early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='auto', restore_best_weights=True, verbose=1) # restore_best_weights=1 is True

    # Make sure my_callbacks is defined in this scope or passed as an argument
    history = model.fit(X_train, y_train, epochs=epoch_max, batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[early_stopping] + my_callbacks, verbose=0) # Added '+' for list concatenation

    skill = model.evaluate(X_test, y_test, verbose=0)
    pred = (model.predict(X_test) * y_std) + y_mean # Make sure y_std and y_mean are defined

    # R2_val = []
    # truth = (y_test * y_std) + y_mean
    # for latind in range(truth.shape[1] if truth.ndim > 1 else 1): # Handle if y_test is 1D output
    #     y_lat = truth[:, latind] if truth.ndim > 1 else truth
    #     y_pred_lat = pred[:, latind] if pred.ndim > 1 else pred
    #     R2_val.append(r2_score(y_lat, y_pred_lat))
    
    model.save(os.path.join(output_dir,'model_fold'+str(fold_no)+'_ens'+str(ens_no)+'.h5'))
    
    return skill, history, pred, R2_val

# %%
def build_and_train_model(X_train, y_train, X_test, y_test):
    tf.keras.backend.clear_session()
    gc.collect()

    input_shape = X_train.shape[1:]
    output_shape = y_train.shape[1]
    
    # --- Define Model Architecture ---
    inputs = tf.keras.Input(shape=input_shape)
    # Define layers based on your hyperparameters
    x = Conv2D(kernels[0], 3, padding='same', activation=kernel_acts[0])(inputs)
    x = MaxPooling2D(2)(x)
    x = Conv2D(kernels[1], 3, padding='same', activation=kernel_acts[1])(x)
    x = MaxPooling2D(2)(x)
    x = Flatten()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(hiddens[0])(x)
    x = PReLU()(x) # As per your activation_function_dense
    x = Dense(hiddens[1])(x)
    x = PReLU()(x) # As per your activation_function_dense
    outputs = Dense(output_shape, activation='linear')(x)
    model = Model(inputs=inputs, outputs=outputs)
    
    model.compile(loss=loss_function, optimizer=Adam(learning_rate=learning_rate))
    
    early_stopping = EarlyStopping(patience=50, monitor='val_loss', mode='min', restore_best_weights=True, verbose=1)
    
    history = model.fit(X_train, y_train, epochs=epoch_max, batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[early_stopping]+my_callbacks, verbose=0)
    
    pred_normalized = model.predict(X_test)
    
    return model, history, pred_normalized

# --- 5. K-Fold Training Loop ---
kfold = KFold(n_splits=num_folds, shuffle=False)
fold_no = 1
trained_model_predictions = []
trained_model_histories = []

print("\n--- Starting K-Fold Training ---")
for trainind, testind in kfold.split(X_norm, y_norm):
    X_train, X_test = X_norm[trainind], X_norm[testind]
    y_train, y_test = y_norm[trainind], y_norm[testind]
    
    pca_y = PCA(n_components=PCA_y_variability_factor)
    y_train = pca_y.fit_transform(y_train) # Fit and transform train data
    y_test = pca_y.transform(y_test)       # Only transform test data

    
    print(f"--- Training Model: Fold {fold_no} ---")
    model, history, fold_pred = build_and_train_model(X_train, y_train, X_test, y_test)

    # PCA convert
    pred_original_space = pca_y.inverse_transform(fold_pred)
    # #un-normalize prediction
    # y_mean_fold = y_mean[testind]
    # y_std_fold = y_std[testind]
    pred_final = pred_original_space * y_std + y_mean

    
    trained_model_histories.append(history)
    trained_model_predictions.append(pred_final)
    joblib.dump(pca_y, os.path.join(output_dir, f'pca_y_fold{fold_no}.pkl'))
    
    model_filename = f'model_fold{fold_no}_ens1.h5' # Assuming 1 ensemble
    model.save(os.path.join(data_dir_out, model_filename))
    print(f"Saved model for fold {fold_no}: {model_filename}")
    fold_no += 1

print("\n✅ Training with {num_folds}-fold cross-validation finished!")
# Out:
# --- Starting K-Fold Training ---
# --- Training Model: Fold 1 ---
# 2025-07-16 02:17:27.820198: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-16 02:17:28.851504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:b3:00.0, compute capability: 7.0
# 2025-07-16 02:17:31.026873: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8201
# Epoch    0 - Loss: 5.97e+00, Validation loss: 6.37e+00
# Epoch   10 - Loss: 5.68e+00, Validation loss: 6.17e+00
# Epoch   20 - Loss: 5.60e+00, Validation loss: 6.12e+00
# Epoch   30 - Loss: 5.55e+00, Validation loss: 6.09e+00
# Epoch   40 - Loss: 5.50e+00, Validation loss: 6.07e+00
# Epoch   50 - Loss: 5.45e+00, Validation loss: 6.06e+00
# Epoch   60 - Loss: 5.41e+00, Validation loss: 6.04e+00
# Epoch   70 - Loss: 5.37e+00, Validation loss: 6.03e+00
# Epoch   80 - Loss: 5.33e+00, Validation loss: 6.01e+00
# Epoch   90 - Loss: 5.30e+00, Validation loss: 5.99e+00
# Epoch  100 - Loss: 5.26e+00, Validation loss: 5.98e+00
# Epoch  110 - Loss: 5.22e+00, Validation loss: 5.97e+00
# Epoch  120 - Loss: 5.19e+00, Validation loss: 5.95e+00
# Epoch  130 - Loss: 5.16e+00, Validation loss: 5.94e+00
# Epoch  140 - Loss: 5.13e+00, Validation loss: 5.92e+00
# Epoch  150 - Loss: 5.10e+00, Validation loss: 5.91e+00
# Epoch  160 - Loss: 5.07e+00, Validation loss: 5.89e+00
# Epoch  170 - Loss: 5.04e+00, Validation loss: 5.89e+00
# Epoch  180 - Loss: 5.01e+00, Validation loss: 5.87e+00
# Epoch  190 - Loss: 4.99e+00, Validation loss: 5.86e+00
# Epoch  200 - Loss: 4.97e+00, Validation loss: 5.85e+00
# Epoch  210 - Loss: 4.94e+00, Validation loss: 5.83e+00
# Epoch  220 - Loss: 4.91e+00, Validation loss: 5.82e+00
# Epoch  230 - Loss: 4.89e+00, Validation loss: 5.81e+00
# Epoch  240 - Loss: 4.86e+00, Validation loss: 5.80e+00
# Epoch  250 - Loss: 4.83e+00, Validation loss: 5.79e+00
# Epoch  260 - Loss: 4.81e+00, Validation loss: 5.78e+00
# Epoch  270 - Loss: 4.78e+00, Validation loss: 5.78e+00
# Epoch  280 - Loss: 4.76e+00, Validation loss: 5.76e+00
# Epoch  290 - Loss: 4.73e+00, Validation loss: 5.74e+00
# Epoch  300 - Loss: 4.71e+00, Validation loss: 5.74e+00
# Epoch  310 - Loss: 4.68e+00, Validation loss: 5.72e+00
# Epoch  320 - Loss: 4.65e+00, Validation loss: 5.71e+00
# Epoch  330 - Loss: 4.63e+00, Validation loss: 5.69e+00
# Epoch  340 - Loss: 4.60e+00, Validation loss: 5.68e+00
# Epoch  350 - Loss: 4.58e+00, Validation loss: 5.68e+00
# Epoch  360 - Loss: 4.55e+00, Validation loss: 5.66e+00
# Epoch  370 - Loss: 4.53e+00, Validation loss: 5.65e+00
# Epoch  380 - Loss: 4.51e+00, Validation loss: 5.64e+00
# Epoch  390 - Loss: 4.48e+00, Validation loss: 5.62e+00
# Epoch  400 - Loss: 4.46e+00, Validation loss: 5.61e+00
# Epoch  410 - Loss: 4.44e+00, Validation loss: 5.62e+00
# Epoch  420 - Loss: 4.41e+00, Validation loss: 5.60e+00
# Epoch  430 - Loss: 4.39e+00, Validation loss: 5.59e+00
# Epoch  440 - Loss: 4.37e+00, Validation loss: 5.57e+00
# Epoch  450 - Loss: 4.35e+00, Validation loss: 5.55e+00
# Epoch  460 - Loss: 4.32e+00, Validation loss: 5.55e+00
# Epoch  470 - Loss: 4.30e+00, Validation loss: 5.55e+00
# Epoch  480 - Loss: 4.28e+00, Validation loss: 5.52e+00
# Epoch  490 - Loss: 4.26e+00, Validation loss: 5.50e+00
# Epoch  500 - Loss: 4.23e+00, Validation loss: 5.51e+00
# Epoch  510 - Loss: 4.22e+00, Validation loss: 5.49e+00
# Epoch  520 - Loss: 4.20e+00, Validation loss: 5.49e+00
# Epoch  530 - Loss: 4.18e+00, Validation loss: 5.50e+00
# Epoch  540 - Loss: 4.16e+00, Validation loss: 5.48e+00
# Epoch  550 - Loss: 4.14e+00, Validation loss: 5.47e+00
# Epoch  560 - Loss: 4.12e+00, Validation loss: 5.45e+00
# Epoch  570 - Loss: 4.10e+00, Validation loss: 5.46e+00
# Epoch  580 - Loss: 4.09e+00, Validation loss: 5.44e+00
# Epoch  590 - Loss: 4.07e+00, Validation loss: 5.45e+00
# Epoch  600 - Loss: 4.05e+00, Validation loss: 5.43e+00
# Epoch  610 - Loss: 4.03e+00, Validation loss: 5.42e+00
# Epoch  620 - Loss: 4.01e+00, Validation loss: 5.43e+00
# Epoch  630 - Loss: 4.00e+00, Validation loss: 5.43e+00
# Epoch  640 - Loss: 3.98e+00, Validation loss: 5.42e+00
# Epoch  650 - Loss: 3.96e+00, Validation loss: 5.39e+00
# Epoch  660 - Loss: 3.95e+00, Validation loss: 5.39e+00
# Epoch  670 - Loss: 3.93e+00, Validation loss: 5.39e+00
# Epoch  680 - Loss: 3.92e+00, Validation loss: 5.38e+00
# Epoch  690 - Loss: 3.90e+00, Validation loss: 5.38e+00
# Epoch  700 - Loss: 3.89e+00, Validation loss: 5.38e+00
# Epoch  710 - Loss: 3.88e+00, Validation loss: 5.38e+00
# Epoch  720 - Loss: 3.86e+00, Validation loss: 5.34e+00
# Epoch  730 - Loss: 3.85e+00, Validation loss: 5.35e+00
# Epoch  740 - Loss: 3.83e+00, Validation loss: 5.34e+00
# Epoch  750 - Loss: 3.82e+00, Validation loss: 5.33e+00
# Epoch  760 - Loss: 3.81e+00, Validation loss: 5.32e+00
# Epoch  770 - Loss: 3.79e+00, Validation loss: 5.31e+00
# Epoch  780 - Loss: 3.78e+00, Validation loss: 5.32e+00
# Epoch  790 - Loss: 3.77e+00, Validation loss: 5.34e+00
# Epoch  800 - Loss: 3.75e+00, Validation loss: 5.31e+00
# Epoch  810 - Loss: 3.74e+00, Validation loss: 5.29e+00
# Epoch  820 - Loss: 3.73e+00, Validation loss: 5.30e+00
# Epoch  830 - Loss: 3.72e+00, Validation loss: 5.29e+00
# Epoch  840 - Loss: 3.70e+00, Validation loss: 5.30e+00
# Epoch  850 - Loss: 3.69e+00, Validation loss: 5.29e+00
# Epoch  860 - Loss: 3.68e+00, Validation loss: 5.27e+00
# Epoch  870 - Loss: 3.66e+00, Validation loss: 5.27e+00
# Epoch  880 - Loss: 3.66e+00, Validation loss: 5.26e+00
# Epoch  890 - Loss: 3.64e+00, Validation loss: 5.26e+00
# Epoch  900 - Loss: 3.63e+00, Validation loss: 5.26e+00
# Epoch  910 - Loss: 3.62e+00, Validation loss: 5.24e+00
# Epoch  920 - Loss: 3.60e+00, Validation loss: 5.28e+00
# Epoch  930 - Loss: 3.59e+00, Validation loss: 5.24e+00
# Epoch  940 - Loss: 3.58e+00, Validation loss: 5.23e+00
# Epoch  950 - Loss: 3.57e+00, Validation loss: 5.25e+00
# Epoch  960 - Loss: 3.56e+00, Validation loss: 5.23e+00
# Restoring model weights from the end of the best epoch: 916.
# Epoch 966: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 1: model_fold1_ens1.h5
# --- Training Model: Fold 2 ---
# Epoch    0 - Loss: 6.06e+00, Validation loss: 5.90e+00
# Epoch   10 - Loss: 5.72e+00, Validation loss: 5.67e+00
# Epoch   20 - Loss: 5.63e+00, Validation loss: 5.62e+00
# Epoch   30 - Loss: 5.57e+00, Validation loss: 5.60e+00
# Epoch   40 - Loss: 5.51e+00, Validation loss: 5.58e+00
# Epoch   50 - Loss: 5.47e+00, Validation loss: 5.56e+00
# Epoch   60 - Loss: 5.44e+00, Validation loss: 5.55e+00
# Epoch   70 - Loss: 5.40e+00, Validation loss: 5.55e+00
# Epoch   80 - Loss: 5.37e+00, Validation loss: 5.54e+00
# Epoch   90 - Loss: 5.34e+00, Validation loss: 5.53e+00
# Epoch  100 - Loss: 5.31e+00, Validation loss: 5.53e+00
# Epoch  110 - Loss: 5.27e+00, Validation loss: 5.52e+00
# Epoch  120 - Loss: 5.25e+00, Validation loss: 5.51e+00
# Epoch  130 - Loss: 5.22e+00, Validation loss: 5.50e+00
# Epoch  140 - Loss: 5.20e+00, Validation loss: 5.49e+00
# Epoch  150 - Loss: 5.17e+00, Validation loss: 5.49e+00
# Epoch  160 - Loss: 5.15e+00, Validation loss: 5.48e+00
# Epoch  170 - Loss: 5.12e+00, Validation loss: 5.47e+00
# Epoch  180 - Loss: 5.10e+00, Validation loss: 5.47e+00
# Epoch  190 - Loss: 5.07e+00, Validation loss: 5.46e+00
# Epoch  200 - Loss: 5.05e+00, Validation loss: 5.45e+00
# Epoch  210 - Loss: 5.02e+00, Validation loss: 5.44e+00
# Epoch  220 - Loss: 5.00e+00, Validation loss: 5.44e+00
# Epoch  230 - Loss: 4.97e+00, Validation loss: 5.43e+00
# Epoch  240 - Loss: 4.95e+00, Validation loss: 5.41e+00
# Epoch  250 - Loss: 4.92e+00, Validation loss: 5.41e+00
# Epoch  260 - Loss: 4.90e+00, Validation loss: 5.40e+00
# Epoch  270 - Loss: 4.87e+00, Validation loss: 5.40e+00
# Epoch  280 - Loss: 4.85e+00, Validation loss: 5.39e+00
# Epoch  290 - Loss: 4.82e+00, Validation loss: 5.39e+00
# Epoch  300 - Loss: 4.80e+00, Validation loss: 5.38e+00
# Epoch  310 - Loss: 4.78e+00, Validation loss: 5.36e+00
# Epoch  320 - Loss: 4.75e+00, Validation loss: 5.37e+00
# Epoch  330 - Loss: 4.73e+00, Validation loss: 5.36e+00
# Epoch  340 - Loss: 4.71e+00, Validation loss: 5.35e+00
# Epoch  350 - Loss: 4.68e+00, Validation loss: 5.34e+00
# Epoch  360 - Loss: 4.66e+00, Validation loss: 5.33e+00
# Epoch  370 - Loss: 4.64e+00, Validation loss: 5.33e+00
# Epoch  380 - Loss: 4.61e+00, Validation loss: 5.33e+00
# Epoch  390 - Loss: 4.59e+00, Validation loss: 5.31e+00
# Epoch  400 - Loss: 4.56e+00, Validation loss: 5.33e+00
# Epoch  410 - Loss: 4.54e+00, Validation loss: 5.31e+00
# Epoch  420 - Loss: 4.52e+00, Validation loss: 5.32e+00
# Epoch  430 - Loss: 4.50e+00, Validation loss: 5.31e+00
# Epoch  440 - Loss: 4.47e+00, Validation loss: 5.30e+00
# Epoch  450 - Loss: 4.45e+00, Validation loss: 5.30e+00
# Epoch  460 - Loss: 4.42e+00, Validation loss: 5.30e+00
# Epoch  470 - Loss: 4.40e+00, Validation loss: 5.30e+00
# Epoch  480 - Loss: 4.38e+00, Validation loss: 5.29e+00
# Epoch  490 - Loss: 4.36e+00, Validation loss: 5.29e+00
# Epoch  500 - Loss: 4.33e+00, Validation loss: 5.28e+00
# Epoch  510 - Loss: 4.31e+00, Validation loss: 5.26e+00
# Epoch  520 - Loss: 4.29e+00, Validation loss: 5.28e+00
# Epoch  530 - Loss: 4.27e+00, Validation loss: 5.26e+00
# Epoch  540 - Loss: 4.25e+00, Validation loss: 5.26e+00
# Epoch  550 - Loss: 4.23e+00, Validation loss: 5.25e+00
# Epoch  560 - Loss: 4.21e+00, Validation loss: 5.26e+00
# Epoch  570 - Loss: 4.20e+00, Validation loss: 5.27e+00
# Epoch  580 - Loss: 4.17e+00, Validation loss: 5.25e+00
# Epoch  590 - Loss: 4.15e+00, Validation loss: 5.24e+00
# Epoch  600 - Loss: 4.13e+00, Validation loss: 5.24e+00
# Epoch  610 - Loss: 4.11e+00, Validation loss: 5.22e+00
# Epoch  620 - Loss: 4.09e+00, Validation loss: 5.23e+00
# Epoch  630 - Loss: 4.08e+00, Validation loss: 5.22e+00
# Epoch  640 - Loss: 4.06e+00, Validation loss: 5.22e+00
# Epoch  650 - Loss: 4.04e+00, Validation loss: 5.21e+00
# Epoch  660 - Loss: 4.02e+00, Validation loss: 5.21e+00
# Epoch  670 - Loss: 4.01e+00, Validation loss: 5.21e+00
# Epoch  680 - Loss: 4.00e+00, Validation loss: 5.20e+00
# Epoch  690 - Loss: 3.98e+00, Validation loss: 5.18e+00
# Epoch  700 - Loss: 3.96e+00, Validation loss: 5.18e+00
# Epoch  710 - Loss: 3.95e+00, Validation loss: 5.18e+00
# Epoch  720 - Loss: 3.94e+00, Validation loss: 5.18e+00
# Epoch  730 - Loss: 3.92e+00, Validation loss: 5.19e+00
# Epoch  740 - Loss: 3.90e+00, Validation loss: 5.17e+00
# Epoch  750 - Loss: 3.88e+00, Validation loss: 5.16e+00
# Epoch  760 - Loss: 3.87e+00, Validation loss: 5.12e+00
# Epoch  770 - Loss: 3.85e+00, Validation loss: 5.14e+00
# Epoch  780 - Loss: 3.83e+00, Validation loss: 5.13e+00
# Epoch  790 - Loss: 3.82e+00, Validation loss: 5.14e+00
# Epoch  800 - Loss: 3.81e+00, Validation loss: 5.12e+00
# Epoch  810 - Loss: 3.80e+00, Validation loss: 5.10e+00
# Epoch  820 - Loss: 3.77e+00, Validation loss: 5.13e+00
# Epoch  830 - Loss: 3.76e+00, Validation loss: 5.09e+00
# Epoch  840 - Loss: 3.75e+00, Validation loss: 5.08e+00
# Epoch  850 - Loss: 3.73e+00, Validation loss: 5.12e+00
# Epoch  860 - Loss: 3.72e+00, Validation loss: 5.09e+00
# Epoch  870 - Loss: 3.71e+00, Validation loss: 5.09e+00
# Epoch  880 - Loss: 3.71e+00, Validation loss: 5.07e+00
# Epoch  890 - Loss: 3.68e+00, Validation loss: 5.06e+00
# Epoch  900 - Loss: 3.67e+00, Validation loss: 5.06e+00
# Epoch  910 - Loss: 3.65e+00, Validation loss: 5.07e+00
# Epoch  920 - Loss: 3.64e+00, Validation loss: 5.07e+00
# Epoch  930 - Loss: 3.63e+00, Validation loss: 5.06e+00
# Epoch  940 - Loss: 3.62e+00, Validation loss: 5.06e+00
# Epoch  950 - Loss: 3.60e+00, Validation loss: 5.06e+00
# Epoch  960 - Loss: 3.59e+00, Validation loss: 5.08e+00
# Epoch  970 - Loss: 3.58e+00, Validation loss: 5.03e+00
# Epoch  980 - Loss: 3.56e+00, Validation loss: 5.05e+00
# Epoch  990 - Loss: 3.55e+00, Validation loss: 5.02e+00
# Epoch 1000 - Loss: 3.54e+00, Validation loss: 5.01e+00
# Epoch 1010 - Loss: 3.53e+00, Validation loss: 5.02e+00
# Epoch 1020 - Loss: 3.52e+00, Validation loss: 5.02e+00
# Epoch 1030 - Loss: 3.51e+00, Validation loss: 5.04e+00
# Epoch 1040 - Loss: 3.49e+00, Validation loss: 5.02e+00
# Epoch 1050 - Loss: 3.48e+00, Validation loss: 5.03e+00
# Epoch 1060 - Loss: 3.47e+00, Validation loss: 5.02e+00
# Epoch 1070 - Loss: 3.45e+00, Validation loss: 5.02e+00
# Epoch 1080 - Loss: 3.44e+00, Validation loss: 5.01e+00
# Epoch 1090 - Loss: 3.43e+00, Validation loss: 4.99e+00
# Epoch 1100 - Loss: 3.42e+00, Validation loss: 4.99e+00
# Epoch 1110 - Loss: 3.41e+00, Validation loss: 4.98e+00
# Epoch 1120 - Loss: 3.40e+00, Validation loss: 4.99e+00
# Epoch 1130 - Loss: 3.39e+00, Validation loss: 4.97e+00
# Epoch 1140 - Loss: 3.37e+00, Validation loss: 5.00e+00
# Epoch 1150 - Loss: 3.36e+00, Validation loss: 4.97e+00
# Epoch 1160 - Loss: 3.35e+00, Validation loss: 4.98e+00
# Epoch 1170 - Loss: 3.35e+00, Validation loss: 4.97e+00
# Epoch 1180 - Loss: 3.33e+00, Validation loss: 4.97e+00
# Epoch 1190 - Loss: 3.32e+00, Validation loss: 4.97e+00
# Epoch 1200 - Loss: 3.32e+00, Validation loss: 4.95e+00
# Epoch 1210 - Loss: 3.30e+00, Validation loss: 4.95e+00
# Epoch 1220 - Loss: 3.30e+00, Validation loss: 4.96e+00
# Epoch 1230 - Loss: 3.28e+00, Validation loss: 4.94e+00
# Epoch 1240 - Loss: 3.27e+00, Validation loss: 4.94e+00
# Epoch 1250 - Loss: 3.26e+00, Validation loss: 4.95e+00
# Epoch 1260 - Loss: 3.25e+00, Validation loss: 4.95e+00
# Epoch 1270 - Loss: 3.24e+00, Validation loss: 4.93e+00
# Epoch 1280 - Loss: 3.23e+00, Validation loss: 4.93e+00
# Epoch 1290 - Loss: 3.23e+00, Validation loss: 4.95e+00
# Epoch 1300 - Loss: 3.22e+00, Validation loss: 4.92e+00
# Epoch 1310 - Loss: 3.21e+00, Validation loss: 4.92e+00
# Epoch 1320 - Loss: 3.21e+00, Validation loss: 4.93e+00
# Epoch 1330 - Loss: 3.19e+00, Validation loss: 4.91e+00
# Epoch 1340 - Loss: 3.18e+00, Validation loss: 4.89e+00
# Epoch 1350 - Loss: 3.17e+00, Validation loss: 4.88e+00
# Epoch 1360 - Loss: 3.17e+00, Validation loss: 4.90e+00
# Epoch 1370 - Loss: 3.16e+00, Validation loss: 4.90e+00
# Epoch 1380 - Loss: 3.16e+00, Validation loss: 4.89e+00
# Epoch 1390 - Loss: 3.14e+00, Validation loss: 4.88e+00
# Epoch 1400 - Loss: 3.14e+00, Validation loss: 4.86e+00
# Epoch 1410 - Loss: 3.12e+00, Validation loss: 4.84e+00
# Epoch 1420 - Loss: 3.12e+00, Validation loss: 4.88e+00
# Epoch 1430 - Loss: 3.11e+00, Validation loss: 4.85e+00
# Epoch 1440 - Loss: 3.10e+00, Validation loss: 4.86e+00
# Epoch 1450 - Loss: 3.09e+00, Validation loss: 4.86e+00
# Epoch 1460 - Loss: 3.08e+00, Validation loss: 4.85e+00
# Restoring model weights from the end of the best epoch: 1416.
# Epoch 1466: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 2: model_fold2_ens1.h5
# --- Training Model: Fold 3 ---
# Epoch    0 - Loss: 6.08e+00, Validation loss: 6.04e+00
# Epoch   10 - Loss: 5.84e+00, Validation loss: 5.84e+00
# Epoch   20 - Loss: 5.74e+00, Validation loss: 5.78e+00
# Epoch   30 - Loss: 5.65e+00, Validation loss: 5.73e+00
# Epoch   40 - Loss: 5.55e+00, Validation loss: 5.66e+00
# Epoch   50 - Loss: 5.45e+00, Validation loss: 5.61e+00
# Epoch   60 - Loss: 5.38e+00, Validation loss: 5.58e+00
# Epoch   70 - Loss: 5.32e+00, Validation loss: 5.56e+00
# Epoch   80 - Loss: 5.29e+00, Validation loss: 5.55e+00
# Epoch   90 - Loss: 5.25e+00, Validation loss: 5.54e+00
# Epoch  100 - Loss: 5.21e+00, Validation loss: 5.52e+00
# Epoch  110 - Loss: 5.18e+00, Validation loss: 5.51e+00
# Epoch  120 - Loss: 5.15e+00, Validation loss: 5.51e+00
# Epoch  130 - Loss: 5.12e+00, Validation loss: 5.50e+00
# Epoch  140 - Loss: 5.09e+00, Validation loss: 5.49e+00
# Epoch  150 - Loss: 5.06e+00, Validation loss: 5.49e+00
# Epoch  160 - Loss: 5.04e+00, Validation loss: 5.48e+00
# Epoch  170 - Loss: 5.01e+00, Validation loss: 5.47e+00
# Epoch  180 - Loss: 4.98e+00, Validation loss: 5.46e+00
# Epoch  190 - Loss: 4.96e+00, Validation loss: 5.45e+00
# Epoch  200 - Loss: 4.94e+00, Validation loss: 5.44e+00
# Epoch  210 - Loss: 4.91e+00, Validation loss: 5.44e+00
# Epoch  220 - Loss: 4.88e+00, Validation loss: 5.42e+00
# Epoch  230 - Loss: 4.87e+00, Validation loss: 5.41e+00
# Epoch  240 - Loss: 4.83e+00, Validation loss: 5.41e+00
# Epoch  250 - Loss: 4.81e+00, Validation loss: 5.40e+00
# Epoch  260 - Loss: 4.78e+00, Validation loss: 5.39e+00
# Epoch  270 - Loss: 4.76e+00, Validation loss: 5.38e+00
# Epoch  280 - Loss: 4.73e+00, Validation loss: 5.38e+00
# Epoch  290 - Loss: 4.71e+00, Validation loss: 5.38e+00
# Epoch  300 - Loss: 4.68e+00, Validation loss: 5.35e+00
# Epoch  310 - Loss: 4.66e+00, Validation loss: 5.34e+00
# Epoch  320 - Loss: 4.63e+00, Validation loss: 5.34e+00
# Epoch  330 - Loss: 4.61e+00, Validation loss: 5.33e+00
# Epoch  340 - Loss: 4.59e+00, Validation loss: 5.32e+00
# Epoch  350 - Loss: 4.57e+00, Validation loss: 5.31e+00
# Epoch  360 - Loss: 4.54e+00, Validation loss: 5.30e+00
# Epoch  370 - Loss: 4.51e+00, Validation loss: 5.29e+00
# Epoch  380 - Loss: 4.49e+00, Validation loss: 5.28e+00
# Epoch  390 - Loss: 4.47e+00, Validation loss: 5.27e+00
# Epoch  400 - Loss: 4.44e+00, Validation loss: 5.26e+00
# Epoch  410 - Loss: 4.42e+00, Validation loss: 5.24e+00
# Epoch  420 - Loss: 4.39e+00, Validation loss: 5.23e+00
# Epoch  430 - Loss: 4.37e+00, Validation loss: 5.22e+00
# Epoch  440 - Loss: 4.35e+00, Validation loss: 5.21e+00
# Epoch  450 - Loss: 4.33e+00, Validation loss: 5.19e+00
# Epoch  460 - Loss: 4.30e+00, Validation loss: 5.19e+00
# Epoch  470 - Loss: 4.28e+00, Validation loss: 5.18e+00
# Epoch  480 - Loss: 4.26e+00, Validation loss: 5.17e+00
# Epoch  490 - Loss: 4.24e+00, Validation loss: 5.16e+00
# Epoch  500 - Loss: 4.23e+00, Validation loss: 5.13e+00
# Epoch  510 - Loss: 4.20e+00, Validation loss: 5.13e+00
# Epoch  520 - Loss: 4.17e+00, Validation loss: 5.13e+00
# Epoch  530 - Loss: 4.15e+00, Validation loss: 5.10e+00
# Epoch  540 - Loss: 4.13e+00, Validation loss: 5.10e+00
# Epoch  550 - Loss: 4.12e+00, Validation loss: 5.08e+00
# Epoch  560 - Loss: 4.12e+00, Validation loss: 5.07e+00
# Epoch  570 - Loss: 4.07e+00, Validation loss: 5.05e+00
# Epoch  580 - Loss: 4.05e+00, Validation loss: 5.04e+00
# Epoch  590 - Loss: 4.03e+00, Validation loss: 5.03e+00
# Epoch  600 - Loss: 4.01e+00, Validation loss: 5.03e+00
# Epoch  610 - Loss: 4.00e+00, Validation loss: 5.02e+00
# Epoch  620 - Loss: 3.98e+00, Validation loss: 5.01e+00
# Epoch  630 - Loss: 3.95e+00, Validation loss: 4.99e+00
# Epoch  640 - Loss: 3.94e+00, Validation loss: 4.98e+00
# Epoch  650 - Loss: 3.92e+00, Validation loss: 4.97e+00
# Epoch  660 - Loss: 3.90e+00, Validation loss: 4.96e+00
# Epoch  670 - Loss: 3.88e+00, Validation loss: 4.95e+00
# Epoch  680 - Loss: 3.87e+00, Validation loss: 4.94e+00
# Epoch  690 - Loss: 3.86e+00, Validation loss: 4.92e+00
# Epoch  700 - Loss: 3.83e+00, Validation loss: 4.93e+00
# Epoch  710 - Loss: 3.82e+00, Validation loss: 4.93e+00
# Epoch  720 - Loss: 3.80e+00, Validation loss: 4.89e+00
# Epoch  730 - Loss: 3.79e+00, Validation loss: 4.89e+00
# Epoch  740 - Loss: 3.76e+00, Validation loss: 4.88e+00
# Epoch  750 - Loss: 3.75e+00, Validation loss: 4.87e+00
# Epoch  760 - Loss: 3.73e+00, Validation loss: 4.87e+00
# Epoch  770 - Loss: 3.72e+00, Validation loss: 4.86e+00
# Epoch  780 - Loss: 3.70e+00, Validation loss: 4.86e+00
# Epoch  790 - Loss: 3.69e+00, Validation loss: 4.85e+00
# Epoch  800 - Loss: 3.67e+00, Validation loss: 4.85e+00
# Epoch  810 - Loss: 3.66e+00, Validation loss: 4.83e+00
# Epoch  820 - Loss: 3.64e+00, Validation loss: 4.82e+00
# Epoch  830 - Loss: 3.63e+00, Validation loss: 4.81e+00
# Epoch  840 - Loss: 3.62e+00, Validation loss: 4.81e+00
# Epoch  850 - Loss: 3.60e+00, Validation loss: 4.80e+00
# Epoch  860 - Loss: 3.59e+00, Validation loss: 4.79e+00
# Epoch  870 - Loss: 3.57e+00, Validation loss: 4.80e+00
# Epoch  880 - Loss: 3.56e+00, Validation loss: 4.78e+00
# Epoch  890 - Loss: 3.54e+00, Validation loss: 4.78e+00
# Epoch  900 - Loss: 3.53e+00, Validation loss: 4.76e+00
# Epoch  910 - Loss: 3.52e+00, Validation loss: 4.77e+00
# Epoch  920 - Loss: 3.51e+00, Validation loss: 4.75e+00
# Epoch  930 - Loss: 3.49e+00, Validation loss: 4.75e+00
# Epoch  940 - Loss: 3.47e+00, Validation loss: 4.75e+00
# Epoch  950 - Loss: 3.46e+00, Validation loss: 4.75e+00
# Epoch  960 - Loss: 3.45e+00, Validation loss: 4.75e+00
# Epoch  970 - Loss: 3.43e+00, Validation loss: 4.75e+00
# Epoch  980 - Loss: 3.42e+00, Validation loss: 4.74e+00
# Epoch  990 - Loss: 3.43e+00, Validation loss: 4.72e+00
# Epoch 1000 - Loss: 3.40e+00, Validation loss: 4.72e+00
# Epoch 1010 - Loss: 3.38e+00, Validation loss: 4.73e+00
# Epoch 1020 - Loss: 3.37e+00, Validation loss: 4.72e+00
# Epoch 1030 - Loss: 3.35e+00, Validation loss: 4.72e+00
# Epoch 1040 - Loss: 3.35e+00, Validation loss: 4.71e+00
# Epoch 1050 - Loss: 3.33e+00, Validation loss: 4.71e+00
# Epoch 1060 - Loss: 3.32e+00, Validation loss: 4.71e+00
# Epoch 1070 - Loss: 3.31e+00, Validation loss: 4.72e+00
# Epoch 1080 - Loss: 3.30e+00, Validation loss: 4.71e+00
# Epoch 1090 - Loss: 3.29e+00, Validation loss: 4.70e+00
# Epoch 1100 - Loss: 3.28e+00, Validation loss: 4.70e+00
# Epoch 1110 - Loss: 3.27e+00, Validation loss: 4.71e+00
# Epoch 1120 - Loss: 3.25e+00, Validation loss: 4.69e+00
# Epoch 1130 - Loss: 3.25e+00, Validation loss: 4.70e+00
# Restoring model weights from the end of the best epoch: 1083.
# Epoch 1133: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 3: model_fold3_ens1.h5
# --- Training Model: Fold 4 ---
# Epoch    0 - Loss: 6.15e+00, Validation loss: 5.62e+00
# Epoch   10 - Loss: 5.81e+00, Validation loss: 5.36e+00
# Epoch   20 - Loss: 5.69e+00, Validation loss: 5.27e+00
# Epoch   30 - Loss: 5.60e+00, Validation loss: 5.22e+00
# Epoch   40 - Loss: 5.54e+00, Validation loss: 5.19e+00
# Epoch   50 - Loss: 5.49e+00, Validation loss: 5.16e+00
# Epoch   60 - Loss: 5.44e+00, Validation loss: 5.14e+00
# Epoch   70 - Loss: 5.40e+00, Validation loss: 5.13e+00
# Epoch   80 - Loss: 5.36e+00, Validation loss: 5.13e+00
# Epoch   90 - Loss: 5.32e+00, Validation loss: 5.12e+00
# Epoch  100 - Loss: 5.29e+00, Validation loss: 5.11e+00
# Epoch  110 - Loss: 5.26e+00, Validation loss: 5.11e+00
# Epoch  120 - Loss: 5.22e+00, Validation loss: 5.10e+00
# Epoch  130 - Loss: 5.19e+00, Validation loss: 5.09e+00
# Epoch  140 - Loss: 5.16e+00, Validation loss: 5.09e+00
# Epoch  150 - Loss: 5.13e+00, Validation loss: 5.08e+00
# Epoch  160 - Loss: 5.11e+00, Validation loss: 5.07e+00
# Epoch  170 - Loss: 5.08e+00, Validation loss: 5.06e+00
# Epoch  180 - Loss: 5.05e+00, Validation loss: 5.06e+00
# Epoch  190 - Loss: 5.03e+00, Validation loss: 5.06e+00
# Epoch  200 - Loss: 5.01e+00, Validation loss: 5.05e+00
# Epoch  210 - Loss: 4.97e+00, Validation loss: 5.04e+00
# Epoch  220 - Loss: 4.95e+00, Validation loss: 5.04e+00
# Epoch  230 - Loss: 4.92e+00, Validation loss: 5.03e+00
# Epoch  240 - Loss: 4.90e+00, Validation loss: 5.03e+00
# Epoch  250 - Loss: 4.87e+00, Validation loss: 5.01e+00
# Epoch  260 - Loss: 4.85e+00, Validation loss: 5.01e+00
# Epoch  270 - Loss: 4.83e+00, Validation loss: 5.00e+00
# Epoch  280 - Loss: 4.80e+00, Validation loss: 4.99e+00
# Epoch  290 - Loss: 4.78e+00, Validation loss: 4.99e+00
# Epoch  300 - Loss: 4.75e+00, Validation loss: 4.98e+00
# Epoch  310 - Loss: 4.73e+00, Validation loss: 4.97e+00
# Epoch  320 - Loss: 4.71e+00, Validation loss: 4.96e+00
# Epoch  330 - Loss: 4.69e+00, Validation loss: 4.95e+00
# Epoch  340 - Loss: 4.67e+00, Validation loss: 4.94e+00
# Epoch  350 - Loss: 4.65e+00, Validation loss: 4.94e+00
# Epoch  360 - Loss: 4.62e+00, Validation loss: 4.94e+00
# Epoch  370 - Loss: 4.60e+00, Validation loss: 4.93e+00
# Epoch  380 - Loss: 4.58e+00, Validation loss: 4.91e+00
# Epoch  390 - Loss: 4.56e+00, Validation loss: 4.91e+00
# Epoch  400 - Loss: 4.54e+00, Validation loss: 4.90e+00
# Epoch  410 - Loss: 4.52e+00, Validation loss: 4.91e+00
# Epoch  420 - Loss: 4.50e+00, Validation loss: 4.90e+00
# Epoch  430 - Loss: 4.47e+00, Validation loss: 4.89e+00
# Epoch  440 - Loss: 4.46e+00, Validation loss: 4.88e+00
# Epoch  450 - Loss: 4.44e+00, Validation loss: 4.88e+00
# Epoch  460 - Loss: 4.42e+00, Validation loss: 4.88e+00
# Epoch  470 - Loss: 4.40e+00, Validation loss: 4.87e+00
# Epoch  480 - Loss: 4.38e+00, Validation loss: 4.87e+00
# Epoch  490 - Loss: 4.36e+00, Validation loss: 4.85e+00
# Epoch  500 - Loss: 4.34e+00, Validation loss: 4.85e+00
# Epoch  510 - Loss: 4.33e+00, Validation loss: 4.85e+00
# Epoch  520 - Loss: 4.31e+00, Validation loss: 4.83e+00
# Epoch  530 - Loss: 4.29e+00, Validation loss: 4.84e+00
# Epoch  540 - Loss: 4.27e+00, Validation loss: 4.83e+00
# Epoch  550 - Loss: 4.26e+00, Validation loss: 4.82e+00
# Epoch  560 - Loss: 4.24e+00, Validation loss: 4.83e+00
# Epoch  570 - Loss: 4.22e+00, Validation loss: 4.82e+00
# Epoch  580 - Loss: 4.20e+00, Validation loss: 4.82e+00
# Epoch  590 - Loss: 4.19e+00, Validation loss: 4.80e+00
# Epoch  600 - Loss: 4.17e+00, Validation loss: 4.80e+00
# Epoch  610 - Loss: 4.15e+00, Validation loss: 4.80e+00
# Epoch  620 - Loss: 4.14e+00, Validation loss: 4.78e+00
# Epoch  630 - Loss: 4.12e+00, Validation loss: 4.79e+00
# Epoch  640 - Loss: 4.10e+00, Validation loss: 4.78e+00
# Epoch  650 - Loss: 4.09e+00, Validation loss: 4.78e+00
# Epoch  660 - Loss: 4.07e+00, Validation loss: 4.77e+00
# Epoch  670 - Loss: 4.06e+00, Validation loss: 4.76e+00
# Epoch  680 - Loss: 4.04e+00, Validation loss: 4.76e+00
# Epoch  690 - Loss: 4.02e+00, Validation loss: 4.77e+00
# Epoch  700 - Loss: 4.00e+00, Validation loss: 4.76e+00
# Epoch  710 - Loss: 3.99e+00, Validation loss: 4.76e+00
# Epoch  720 - Loss: 3.98e+00, Validation loss: 4.77e+00
# Epoch  730 - Loss: 3.96e+00, Validation loss: 4.75e+00
# Epoch  740 - Loss: 3.95e+00, Validation loss: 4.75e+00
# Epoch  750 - Loss: 3.94e+00, Validation loss: 4.76e+00
# Epoch  760 - Loss: 3.92e+00, Validation loss: 4.73e+00
# Epoch  770 - Loss: 3.90e+00, Validation loss: 4.74e+00
# Epoch  780 - Loss: 3.89e+00, Validation loss: 4.73e+00
# Epoch  790 - Loss: 3.87e+00, Validation loss: 4.74e+00
# Epoch  800 - Loss: 3.86e+00, Validation loss: 4.73e+00
# Epoch  810 - Loss: 3.84e+00, Validation loss: 4.73e+00
# Epoch  820 - Loss: 3.83e+00, Validation loss: 4.73e+00
# Epoch  830 - Loss: 3.81e+00, Validation loss: 4.73e+00
# Epoch  840 - Loss: 3.80e+00, Validation loss: 4.74e+00
# Epoch  850 - Loss: 3.78e+00, Validation loss: 4.72e+00
# Epoch  860 - Loss: 3.77e+00, Validation loss: 4.73e+00
# Epoch  870 - Loss: 3.76e+00, Validation loss: 4.74e+00
# Epoch  880 - Loss: 3.74e+00, Validation loss: 4.73e+00
# Epoch  890 - Loss: 3.73e+00, Validation loss: 4.74e+00
# Restoring model weights from the end of the best epoch: 850.
# Epoch 900: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 4: model_fold4_ens1.h5
# --- Training Model: Fold 5 ---
# Epoch    0 - Loss: 6.02e+00, Validation loss: 6.19e+00
# Epoch   10 - Loss: 5.71e+00, Validation loss: 5.92e+00
# Epoch   20 - Loss: 5.62e+00, Validation loss: 5.87e+00
# Epoch   30 - Loss: 5.57e+00, Validation loss: 5.84e+00
# Epoch   40 - Loss: 5.52e+00, Validation loss: 5.82e+00
# Epoch   50 - Loss: 5.49e+00, Validation loss: 5.81e+00
# Epoch   60 - Loss: 5.45e+00, Validation loss: 5.80e+00
# Epoch   70 - Loss: 5.42e+00, Validation loss: 5.79e+00
# Epoch   80 - Loss: 5.39e+00, Validation loss: 5.78e+00
# Epoch   90 - Loss: 5.36e+00, Validation loss: 5.76e+00
# Epoch  100 - Loss: 5.34e+00, Validation loss: 5.76e+00
# Epoch  110 - Loss: 5.31e+00, Validation loss: 5.75e+00
# Epoch  120 - Loss: 5.28e+00, Validation loss: 5.73e+00
# Epoch  130 - Loss: 5.26e+00, Validation loss: 5.72e+00
# Epoch  140 - Loss: 5.23e+00, Validation loss: 5.71e+00
# Epoch  150 - Loss: 5.21e+00, Validation loss: 5.71e+00
# Epoch  160 - Loss: 5.19e+00, Validation loss: 5.69e+00
# Epoch  170 - Loss: 5.16e+00, Validation loss: 5.68e+00
# Epoch  180 - Loss: 5.14e+00, Validation loss: 5.67e+00
# Epoch  190 - Loss: 5.12e+00, Validation loss: 5.66e+00
# Epoch  200 - Loss: 5.09e+00, Validation loss: 5.64e+00
# Epoch  210 - Loss: 5.07e+00, Validation loss: 5.64e+00
# Epoch  220 - Loss: 5.05e+00, Validation loss: 5.63e+00
# Epoch  230 - Loss: 5.03e+00, Validation loss: 5.61e+00
# Epoch  240 - Loss: 5.00e+00, Validation loss: 5.60e+00
# Epoch  250 - Loss: 4.98e+00, Validation loss: 5.60e+00
# Epoch  260 - Loss: 4.95e+00, Validation loss: 5.59e+00
# Epoch  270 - Loss: 4.92e+00, Validation loss: 5.59e+00
# Epoch  280 - Loss: 4.90e+00, Validation loss: 5.58e+00
# Epoch  290 - Loss: 4.88e+00, Validation loss: 5.58e+00
# Epoch  300 - Loss: 4.85e+00, Validation loss: 5.57e+00
# Epoch  310 - Loss: 4.83e+00, Validation loss: 5.57e+00
# Epoch  320 - Loss: 4.80e+00, Validation loss: 5.56e+00
# Epoch  330 - Loss: 4.78e+00, Validation loss: 5.56e+00
# Epoch  340 - Loss: 4.76e+00, Validation loss: 5.54e+00
# Epoch  350 - Loss: 4.74e+00, Validation loss: 5.55e+00
# Epoch  360 - Loss: 4.72e+00, Validation loss: 5.54e+00
# Epoch  370 - Loss: 4.70e+00, Validation loss: 5.52e+00
# Epoch  380 - Loss: 4.68e+00, Validation loss: 5.52e+00
# Epoch  390 - Loss: 4.66e+00, Validation loss: 5.52e+00
# Epoch  400 - Loss: 4.64e+00, Validation loss: 5.51e+00
# Epoch  410 - Loss: 4.62e+00, Validation loss: 5.50e+00
# Epoch  420 - Loss: 4.60e+00, Validation loss: 5.49e+00
# Epoch  430 - Loss: 4.58e+00, Validation loss: 5.48e+00
# Epoch  440 - Loss: 4.56e+00, Validation loss: 5.48e+00
# Epoch  450 - Loss: 4.54e+00, Validation loss: 5.47e+00
# Epoch  460 - Loss: 4.52e+00, Validation loss: 5.46e+00
# Epoch  470 - Loss: 4.50e+00, Validation loss: 5.45e+00
# Epoch  480 - Loss: 4.48e+00, Validation loss: 5.46e+00
# Epoch  490 - Loss: 4.49e+00, Validation loss: 5.45e+00
# Epoch  500 - Loss: 4.45e+00, Validation loss: 5.44e+00
# Epoch  510 - Loss: 4.44e+00, Validation loss: 5.41e+00
# Epoch  520 - Loss: 4.41e+00, Validation loss: 5.41e+00
# Epoch  530 - Loss: 4.39e+00, Validation loss: 5.40e+00
# Epoch  540 - Loss: 4.37e+00, Validation loss: 5.41e+00
# Epoch  550 - Loss: 4.36e+00, Validation loss: 5.39e+00
# Epoch  560 - Loss: 4.33e+00, Validation loss: 5.40e+00
# Epoch  570 - Loss: 4.32e+00, Validation loss: 5.37e+00
# Epoch  580 - Loss: 4.30e+00, Validation loss: 5.39e+00
# Epoch  590 - Loss: 4.28e+00, Validation loss: 5.37e+00
# Epoch  600 - Loss: 4.26e+00, Validation loss: 5.36e+00
# Epoch  610 - Loss: 4.24e+00, Validation loss: 5.35e+00
# Epoch  620 - Loss: 4.22e+00, Validation loss: 5.35e+00
# Epoch  630 - Loss: 4.20e+00, Validation loss: 5.35e+00
# Epoch  640 - Loss: 4.18e+00, Validation loss: 5.34e+00
# Epoch  650 - Loss: 4.16e+00, Validation loss: 5.31e+00
# Epoch  660 - Loss: 4.15e+00, Validation loss: 5.31e+00
# Epoch  670 - Loss: 4.13e+00, Validation loss: 5.30e+00
# Epoch  680 - Loss: 4.11e+00, Validation loss: 5.29e+00
# Epoch  690 - Loss: 4.09e+00, Validation loss: 5.29e+00
# Epoch  700 - Loss: 4.07e+00, Validation loss: 5.29e+00
# Epoch  710 - Loss: 4.06e+00, Validation loss: 5.27e+00
# Epoch  720 - Loss: 4.04e+00, Validation loss: 5.27e+00
# Epoch  730 - Loss: 4.02e+00, Validation loss: 5.27e+00
# Epoch  740 - Loss: 4.00e+00, Validation loss: 5.25e+00
# Epoch  750 - Loss: 3.98e+00, Validation loss: 5.24e+00
# Epoch  760 - Loss: 3.97e+00, Validation loss: 5.24e+00
# Epoch  770 - Loss: 3.94e+00, Validation loss: 5.24e+00
# Epoch  780 - Loss: 3.93e+00, Validation loss: 5.21e+00
# Epoch  790 - Loss: 3.92e+00, Validation loss: 5.22e+00
# Epoch  800 - Loss: 3.90e+00, Validation loss: 5.19e+00
# Epoch  810 - Loss: 3.88e+00, Validation loss: 5.21e+00
# Epoch  820 - Loss: 3.87e+00, Validation loss: 5.19e+00
# Epoch  830 - Loss: 3.84e+00, Validation loss: 5.20e+00
# Epoch  840 - Loss: 3.83e+00, Validation loss: 5.18e+00
# Epoch  850 - Loss: 3.81e+00, Validation loss: 5.17e+00
# Epoch  860 - Loss: 3.79e+00, Validation loss: 5.15e+00
# Epoch  870 - Loss: 3.77e+00, Validation loss: 5.14e+00
# Epoch  880 - Loss: 3.76e+00, Validation loss: 5.17e+00
# Epoch  890 - Loss: 3.74e+00, Validation loss: 5.16e+00
# Epoch  900 - Loss: 3.72e+00, Validation loss: 5.14e+00
# Epoch  910 - Loss: 3.71e+00, Validation loss: 5.14e+00
# Epoch  920 - Loss: 3.69e+00, Validation loss: 5.11e+00
# Epoch  930 - Loss: 3.67e+00, Validation loss: 5.11e+00
# Epoch  940 - Loss: 3.66e+00, Validation loss: 5.10e+00
# Epoch  950 - Loss: 3.64e+00, Validation loss: 5.10e+00
# Epoch  960 - Loss: 3.62e+00, Validation loss: 5.09e+00
# Epoch  970 - Loss: 3.61e+00, Validation loss: 5.09e+00
# Epoch  980 - Loss: 3.60e+00, Validation loss: 5.07e+00
# Epoch  990 - Loss: 3.58e+00, Validation loss: 5.06e+00
# Epoch 1000 - Loss: 3.57e+00, Validation loss: 5.06e+00
# Epoch 1010 - Loss: 3.55e+00, Validation loss: 5.07e+00
# Epoch 1020 - Loss: 3.54e+00, Validation loss: 5.05e+00
# Epoch 1030 - Loss: 3.53e+00, Validation loss: 5.06e+00
# Epoch 1040 - Loss: 3.51e+00, Validation loss: 5.06e+00
# Epoch 1050 - Loss: 3.49e+00, Validation loss: 5.04e+00
# Epoch 1060 - Loss: 3.48e+00, Validation loss: 5.03e+00
# Epoch 1070 - Loss: 3.46e+00, Validation loss: 5.02e+00
# Epoch 1080 - Loss: 3.45e+00, Validation loss: 5.03e+00
# Epoch 1090 - Loss: 3.44e+00, Validation loss: 5.01e+00
# Epoch 1100 - Loss: 3.42e+00, Validation loss: 5.00e+00
# Epoch 1110 - Loss: 3.41e+00, Validation loss: 5.01e+00
# Epoch 1120 - Loss: 3.40e+00, Validation loss: 5.02e+00
# Epoch 1130 - Loss: 3.39e+00, Validation loss: 4.99e+00
# Epoch 1140 - Loss: 3.37e+00, Validation loss: 4.98e+00
# Epoch 1150 - Loss: 3.36e+00, Validation loss: 5.00e+00
# Epoch 1160 - Loss: 3.35e+00, Validation loss: 4.99e+00
# Epoch 1170 - Loss: 3.33e+00, Validation loss: 4.98e+00
# Epoch 1180 - Loss: 3.33e+00, Validation loss: 4.98e+00
# Epoch 1190 - Loss: 3.31e+00, Validation loss: 4.98e+00
# Epoch 1200 - Loss: 3.30e+00, Validation loss: 4.97e+00
# Epoch 1210 - Loss: 3.29e+00, Validation loss: 4.97e+00
# Epoch 1220 - Loss: 3.28e+00, Validation loss: 4.97e+00
# Epoch 1230 - Loss: 3.26e+00, Validation loss: 4.96e+00
# Epoch 1240 - Loss: 3.25e+00, Validation loss: 4.95e+00
# Epoch 1250 - Loss: 3.24e+00, Validation loss: 4.96e+00
# Epoch 1260 - Loss: 3.23e+00, Validation loss: 4.97e+00
# Epoch 1270 - Loss: 3.22e+00, Validation loss: 4.95e+00
# Epoch 1280 - Loss: 3.22e+00, Validation loss: 4.94e+00
# Epoch 1290 - Loss: 3.19e+00, Validation loss: 4.94e+00
# Epoch 1300 - Loss: 3.18e+00, Validation loss: 4.93e+00
# Epoch 1310 - Loss: 3.17e+00, Validation loss: 4.92e+00
# Epoch 1320 - Loss: 3.16e+00, Validation loss: 4.92e+00
# Epoch 1330 - Loss: 3.15e+00, Validation loss: 4.92e+00
# Epoch 1340 - Loss: 3.14e+00, Validation loss: 4.90e+00
# Epoch 1350 - Loss: 3.13e+00, Validation loss: 4.90e+00
# Epoch 1360 - Loss: 3.12e+00, Validation loss: 4.91e+00
# Epoch 1370 - Loss: 3.11e+00, Validation loss: 4.91e+00
# Epoch 1380 - Loss: 3.10e+00, Validation loss: 4.91e+00
# Epoch 1390 - Loss: 3.10e+00, Validation loss: 4.89e+00
# Epoch 1400 - Loss: 3.08e+00, Validation loss: 4.88e+00
# Epoch 1410 - Loss: 3.07e+00, Validation loss: 4.90e+00
# Epoch 1420 - Loss: 3.06e+00, Validation loss: 4.89e+00
# Epoch 1430 - Loss: 3.05e+00, Validation loss: 4.87e+00
# Epoch 1440 - Loss: 3.04e+00, Validation loss: 4.88e+00
# Epoch 1450 - Loss: 3.03e+00, Validation loss: 4.85e+00
# Epoch 1460 - Loss: 3.02e+00, Validation loss: 4.85e+00
# Epoch 1470 - Loss: 3.01e+00, Validation loss: 4.86e+00
# Epoch 1480 - Loss: 3.00e+00, Validation loss: 4.84e+00
# Epoch 1490 - Loss: 2.99e+00, Validation loss: 4.84e+00
# Epoch 1500 - Loss: 2.98e+00, Validation loss: 4.85e+00
# Epoch 1510 - Loss: 2.97e+00, Validation loss: 4.84e+00
# Epoch 1520 - Loss: 2.96e+00, Validation loss: 4.83e+00
# Epoch 1530 - Loss: 2.95e+00, Validation loss: 4.85e+00
# Epoch 1540 - Loss: 2.95e+00, Validation loss: 4.83e+00
# Epoch 1550 - Loss: 2.93e+00, Validation loss: 4.84e+00
# Epoch 1560 - Loss: 2.92e+00, Validation loss: 4.82e+00
# Epoch 1570 - Loss: 2.92e+00, Validation loss: 4.83e+00
# Epoch 1580 - Loss: 2.91e+00, Validation loss: 4.81e+00
# Epoch 1590 - Loss: 2.90e+00, Validation loss: 4.83e+00
# Epoch 1600 - Loss: 2.89e+00, Validation loss: 4.81e+00
# Epoch 1610 - Loss: 2.88e+00, Validation loss: 4.82e+00
# Epoch 1620 - Loss: 2.87e+00, Validation loss: 4.81e+00
# Epoch 1630 - Loss: 2.86e+00, Validation loss: 4.81e+00
# Epoch 1640 - Loss: 2.85e+00, Validation loss: 4.80e+00
# Epoch 1650 - Loss: 2.85e+00, Validation loss: 4.80e+00
# Epoch 1660 - Loss: 2.84e+00, Validation loss: 4.78e+00
# Epoch 1670 - Loss: 2.83e+00, Validation loss: 4.81e+00
# Epoch 1680 - Loss: 2.82e+00, Validation loss: 4.80e+00
# Epoch 1690 - Loss: 2.81e+00, Validation loss: 4.78e+00
# Epoch 1700 - Loss: 2.81e+00, Validation loss: 4.79e+00
# Epoch 1710 - Loss: 2.80e+00, Validation loss: 4.78e+00
# Epoch 1720 - Loss: 2.80e+00, Validation loss: 4.75e+00
# Epoch 1730 - Loss: 2.78e+00, Validation loss: 4.77e+00
# Epoch 1740 - Loss: 2.77e+00, Validation loss: 4.75e+00
# Epoch 1750 - Loss: 2.77e+00, Validation loss: 4.74e+00
# Epoch 1760 - Loss: 2.77e+00, Validation loss: 4.75e+00
# Epoch 1770 - Loss: 2.76e+00, Validation loss: 4.74e+00
# Epoch 1780 - Loss: 2.75e+00, Validation loss: 4.74e+00
# Epoch 1790 - Loss: 2.74e+00, Validation loss: 4.74e+00
# Epoch 1800 - Loss: 2.74e+00, Validation loss: 4.74e+00
# Epoch 1810 - Loss: 2.73e+00, Validation loss: 4.73e+00
# Epoch 1820 - Loss: 2.73e+00, Validation loss: 4.71e+00
# Epoch 1830 - Loss: 2.72e+00, Validation loss: 4.73e+00
# Epoch 1840 - Loss: 2.71e+00, Validation loss: 4.72e+00
# Epoch 1850 - Loss: 2.70e+00, Validation loss: 4.72e+00
# Epoch 1860 - Loss: 2.69e+00, Validation loss: 4.69e+00
# Epoch 1870 - Loss: 2.69e+00, Validation loss: 4.70e+00
# Epoch 1880 - Loss: 2.68e+00, Validation loss: 4.71e+00
# Epoch 1890 - Loss: 2.67e+00, Validation loss: 4.70e+00
# Epoch 1900 - Loss: 2.67e+00, Validation loss: 4.68e+00
# Epoch 1910 - Loss: 2.66e+00, Validation loss: 4.69e+00
# Epoch 1920 - Loss: 2.66e+00, Validation loss: 4.68e+00
# Epoch 1930 - Loss: 2.65e+00, Validation loss: 4.68e+00
# Epoch 1940 - Loss: 2.65e+00, Validation loss: 4.70e+00
# Epoch 1950 - Loss: 2.64e+00, Validation loss: 4.68e+00
# Epoch 1960 - Loss: 2.63e+00, Validation loss: 4.69e+00
# Epoch 1970 - Loss: 2.62e+00, Validation loss: 4.68e+00
# Epoch 1980 - Loss: 2.62e+00, Validation loss: 4.68e+00
# Epoch 1990 - Loss: 2.61e+00, Validation loss: 4.68e+00
# Epoch 2000 - Loss: 2.61e+00, Validation loss: 4.67e+00
# Epoch 2010 - Loss: 2.60e+00, Validation loss: 4.66e+00
# Epoch 2020 - Loss: 2.60e+00, Validation loss: 4.66e+00
# Epoch 2030 - Loss: 2.59e+00, Validation loss: 4.66e+00
# Epoch 2040 - Loss: 2.59e+00, Validation loss: 4.64e+00
# Epoch 2050 - Loss: 2.58e+00, Validation loss: 4.66e+00
# Epoch 2060 - Loss: 2.58e+00, Validation loss: 4.65e+00
# Epoch 2070 - Loss: 2.57e+00, Validation loss: 4.65e+00
# Epoch 2080 - Loss: 2.57e+00, Validation loss: 4.65e+00
# Epoch 2090 - Loss: 2.56e+00, Validation loss: 4.64e+00
# Epoch 2100 - Loss: 2.55e+00, Validation loss: 4.65e+00
# Epoch 2110 - Loss: 2.55e+00, Validation loss: 4.62e+00
# Epoch 2120 - Loss: 2.54e+00, Validation loss: 4.64e+00
# Epoch 2130 - Loss: 2.54e+00, Validation loss: 4.61e+00
# Epoch 2140 - Loss: 2.54e+00, Validation loss: 4.62e+00
# Epoch 2150 - Loss: 2.53e+00, Validation loss: 4.61e+00
# Epoch 2160 - Loss: 2.53e+00, Validation loss: 4.60e+00
# Epoch 2170 - Loss: 2.52e+00, Validation loss: 4.61e+00
# Epoch 2180 - Loss: 2.52e+00, Validation loss: 4.60e+00
# Epoch 2190 - Loss: 2.51e+00, Validation loss: 4.59e+00
# Epoch 2200 - Loss: 2.51e+00, Validation loss: 4.60e+00
# Epoch 2210 - Loss: 2.50e+00, Validation loss: 4.59e+00
# Epoch 2220 - Loss: 2.50e+00, Validation loss: 4.58e+00
# Epoch 2230 - Loss: 2.49e+00, Validation loss: 4.58e+00
# Epoch 2240 - Loss: 2.49e+00, Validation loss: 4.59e+00
# Epoch 2250 - Loss: 2.49e+00, Validation loss: 4.58e+00
# Epoch 2260 - Loss: 2.48e+00, Validation loss: 4.57e+00
# Epoch 2270 - Loss: 2.48e+00, Validation loss: 4.58e+00
# Epoch 2280 - Loss: 2.47e+00, Validation loss: 4.57e+00
# Epoch 2290 - Loss: 2.47e+00, Validation loss: 4.56e+00
# Epoch 2300 - Loss: 2.46e+00, Validation loss: 4.57e+00
# Epoch 2310 - Loss: 2.46e+00, Validation loss: 4.55e+00
# Epoch 2320 - Loss: 2.45e+00, Validation loss: 4.56e+00
# Epoch 2330 - Loss: 2.45e+00, Validation loss: 4.55e+00
# Epoch 2340 - Loss: 2.45e+00, Validation loss: 4.55e+00
# Epoch 2350 - Loss: 2.44e+00, Validation loss: 4.55e+00
# Epoch 2360 - Loss: 2.44e+00, Validation loss: 4.54e+00
# Epoch 2370 - Loss: 2.43e+00, Validation loss: 4.53e+00
# Epoch 2380 - Loss: 2.43e+00, Validation loss: 4.53e+00
# Epoch 2390 - Loss: 2.43e+00, Validation loss: 4.54e+00
# Epoch 2400 - Loss: 2.42e+00, Validation loss: 4.52e+00
# Epoch 2410 - Loss: 2.42e+00, Validation loss: 4.52e+00
# Epoch 2420 - Loss: 2.42e+00, Validation loss: 4.52e+00
# Epoch 2430 - Loss: 2.42e+00, Validation loss: 4.51e+00
# Epoch 2440 - Loss: 2.41e+00, Validation loss: 4.52e+00
# Epoch 2450 - Loss: 2.40e+00, Validation loss: 4.52e+00
# Epoch 2460 - Loss: 2.40e+00, Validation loss: 4.52e+00
# Epoch 2470 - Loss: 2.40e+00, Validation loss: 4.51e+00
# Epoch 2480 - Loss: 2.40e+00, Validation loss: 4.50e+00
# Epoch 2490 - Loss: 2.39e+00, Validation loss: 4.50e+00
# Epoch 2500 - Loss: 2.39e+00, Validation loss: 4.49e+00
# Epoch 2510 - Loss: 2.38e+00, Validation loss: 4.51e+00
# Epoch 2520 - Loss: 2.38e+00, Validation loss: 4.49e+00
# Epoch 2530 - Loss: 2.37e+00, Validation loss: 4.48e+00
# Epoch 2540 - Loss: 2.37e+00, Validation loss: 4.49e+00
# Epoch 2550 - Loss: 2.37e+00, Validation loss: 4.49e+00
# Epoch 2560 - Loss: 2.37e+00, Validation loss: 4.48e+00
# Epoch 2570 - Loss: 2.36e+00, Validation loss: 4.48e+00
# Epoch 2580 - Loss: 2.36e+00, Validation loss: 4.47e+00
# Epoch 2590 - Loss: 2.36e+00, Validation loss: 4.47e+00
# Epoch 2600 - Loss: 2.35e+00, Validation loss: 4.46e+00
# Epoch 2610 - Loss: 2.35e+00, Validation loss: 4.46e+00
# Epoch 2620 - Loss: 2.35e+00, Validation loss: 4.47e+00
# Epoch 2630 - Loss: 2.35e+00, Validation loss: 4.46e+00
# Epoch 2640 - Loss: 2.34e+00, Validation loss: 4.46e+00
# Epoch 2650 - Loss: 2.34e+00, Validation loss: 4.46e+00
# Epoch 2660 - Loss: 2.33e+00, Validation loss: 4.45e+00
# Epoch 2670 - Loss: 2.33e+00, Validation loss: 4.44e+00
# Epoch 2680 - Loss: 2.33e+00, Validation loss: 4.44e+00
# Epoch 2690 - Loss: 2.33e+00, Validation loss: 4.44e+00
# Epoch 2700 - Loss: 2.33e+00, Validation loss: 4.43e+00
# Epoch 2710 - Loss: 2.32e+00, Validation loss: 4.43e+00
# Epoch 2720 - Loss: 2.32e+00, Validation loss: 4.43e+00
# Epoch 2730 - Loss: 2.31e+00, Validation loss: 4.43e+00
# Epoch 2740 - Loss: 2.31e+00, Validation loss: 4.42e+00
# Epoch 2750 - Loss: 2.31e+00, Validation loss: 4.42e+00
# Epoch 2760 - Loss: 2.30e+00, Validation loss: 4.42e+00
# Epoch 2770 - Loss: 2.30e+00, Validation loss: 4.42e+00
# Epoch 2780 - Loss: 2.30e+00, Validation loss: 4.40e+00
# Epoch 2790 - Loss: 2.30e+00, Validation loss: 4.40e+00
# Epoch 2800 - Loss: 2.29e+00, Validation loss: 4.41e+00
# Epoch 2810 - Loss: 2.29e+00, Validation loss: 4.41e+00
# Epoch 2820 - Loss: 2.29e+00, Validation loss: 4.40e+00
# Epoch 2830 - Loss: 2.29e+00, Validation loss: 4.40e+00
# Epoch 2840 - Loss: 2.28e+00, Validation loss: 4.40e+00
# Epoch 2850 - Loss: 2.28e+00, Validation loss: 4.40e+00
# Epoch 2860 - Loss: 2.28e+00, Validation loss: 4.39e+00
# Epoch 2870 - Loss: 2.28e+00, Validation loss: 4.38e+00
# Epoch 2880 - Loss: 2.28e+00, Validation loss: 4.38e+00
# Epoch 2890 - Loss: 2.27e+00, Validation loss: 4.38e+00
# Epoch 2900 - Loss: 2.27e+00, Validation loss: 4.38e+00
# Epoch 2910 - Loss: 2.26e+00, Validation loss: 4.37e+00
# Epoch 2920 - Loss: 2.26e+00, Validation loss: 4.37e+00
# Epoch 2930 - Loss: 2.26e+00, Validation loss: 4.37e+00
# Epoch 2940 - Loss: 2.26e+00, Validation loss: 4.37e+00
# Epoch 2950 - Loss: 2.26e+00, Validation loss: 4.36e+00
# Epoch 2960 - Loss: 2.25e+00, Validation loss: 4.36e+00
# Epoch 2970 - Loss: 2.25e+00, Validation loss: 4.36e+00
# Epoch 2980 - Loss: 2.26e+00, Validation loss: 4.36e+00
# Epoch 2990 - Loss: 2.25e+00, Validation loss: 4.35e+00
# Epoch 3000 - Loss: 2.24e+00, Validation loss: 4.35e+00
# Epoch 3010 - Loss: 2.24e+00, Validation loss: 4.34e+00
# Epoch 3020 - Loss: 2.24e+00, Validation loss: 4.34e+00
# Epoch 3030 - Loss: 2.24e+00, Validation loss: 4.35e+00
# Epoch 3040 - Loss: 2.23e+00, Validation loss: 4.34e+00
# Epoch 3050 - Loss: 2.24e+00, Validation loss: 4.33e+00
# Epoch 3060 - Loss: 2.23e+00, Validation loss: 4.34e+00
# Epoch 3070 - Loss: 2.23e+00, Validation loss: 4.34e+00
# Epoch 3080 - Loss: 2.23e+00, Validation loss: 4.32e+00
# Epoch 3090 - Loss: 2.22e+00, Validation loss: 4.33e+00
# Epoch 3100 - Loss: 2.22e+00, Validation loss: 4.32e+00
# Epoch 3110 - Loss: 2.22e+00, Validation loss: 4.32e+00
# Epoch 3120 - Loss: 2.22e+00, Validation loss: 4.32e+00
# Epoch 3130 - Loss: 2.22e+00, Validation loss: 4.32e+00
# Epoch 3140 - Loss: 2.22e+00, Validation loss: 4.31e+00
# Epoch 3150 - Loss: 2.21e+00, Validation loss: 4.31e+00
# Epoch 3160 - Loss: 2.21e+00, Validation loss: 4.32e+00
# Epoch 3170 - Loss: 2.21e+00, Validation loss: 4.31e+00
# Epoch 3180 - Loss: 2.21e+00, Validation loss: 4.29e+00
# Epoch 3190 - Loss: 2.20e+00, Validation loss: 4.31e+00
# Epoch 3200 - Loss: 2.20e+00, Validation loss: 4.29e+00
# Epoch 3210 - Loss: 2.20e+00, Validation loss: 4.29e+00
# Epoch 3220 - Loss: 2.20e+00, Validation loss: 4.28e+00
# Epoch 3230 - Loss: 2.20e+00, Validation loss: 4.28e+00
# Epoch 3240 - Loss: 2.20e+00, Validation loss: 4.28e+00
# Epoch 3250 - Loss: 2.19e+00, Validation loss: 4.27e+00
# Epoch 3260 - Loss: 2.19e+00, Validation loss: 4.27e+00
# Epoch 3270 - Loss: 2.19e+00, Validation loss: 4.28e+00
# Epoch 3280 - Loss: 2.19e+00, Validation loss: 4.27e+00
# Epoch 3290 - Loss: 2.19e+00, Validation loss: 4.27e+00
# Epoch 3300 - Loss: 2.18e+00, Validation loss: 4.26e+00
# Epoch 3310 - Loss: 2.18e+00, Validation loss: 4.26e+00
# Epoch 3320 - Loss: 2.18e+00, Validation loss: 4.26e+00
# Epoch 3330 - Loss: 2.18e+00, Validation loss: 4.25e+00
# Epoch 3340 - Loss: 2.18e+00, Validation loss: 4.26e+00
# Epoch 3350 - Loss: 2.18e+00, Validation loss: 4.25e+00
# Epoch 3360 - Loss: 2.17e+00, Validation loss: 4.25e+00
# Epoch 3370 - Loss: 2.18e+00, Validation loss: 4.25e+00
# Epoch 3380 - Loss: 2.17e+00, Validation loss: 4.24e+00
# Epoch 3390 - Loss: 2.17e+00, Validation loss: 4.24e+00
# Epoch 3400 - Loss: 2.17e+00, Validation loss: 4.25e+00
# Epoch 3410 - Loss: 2.17e+00, Validation loss: 4.23e+00
# Epoch 3420 - Loss: 2.17e+00, Validation loss: 4.23e+00
# Epoch 3430 - Loss: 2.16e+00, Validation loss: 4.23e+00
# Epoch 3440 - Loss: 2.16e+00, Validation loss: 4.23e+00
# Epoch 3450 - Loss: 2.16e+00, Validation loss: 4.23e+00
# Epoch 3460 - Loss: 2.16e+00, Validation loss: 4.22e+00
# Epoch 3470 - Loss: 2.16e+00, Validation loss: 4.22e+00
# Epoch 3480 - Loss: 2.16e+00, Validation loss: 4.21e+00
# Epoch 3490 - Loss: 2.15e+00, Validation loss: 4.22e+00
# Epoch 3500 - Loss: 2.15e+00, Validation loss: 4.21e+00
# Epoch 3510 - Loss: 2.15e+00, Validation loss: 4.22e+00
# Epoch 3520 - Loss: 2.15e+00, Validation loss: 4.21e+00
# Epoch 3530 - Loss: 2.15e+00, Validation loss: 4.21e+00
# Epoch 3540 - Loss: 2.15e+00, Validation loss: 4.20e+00
# Epoch 3550 - Loss: 2.14e+00, Validation loss: 4.20e+00
# Epoch 3560 - Loss: 2.14e+00, Validation loss: 4.20e+00
# Epoch 3570 - Loss: 2.14e+00, Validation loss: 4.18e+00
# Epoch 3580 - Loss: 2.14e+00, Validation loss: 4.19e+00
# Epoch 3590 - Loss: 2.14e+00, Validation loss: 4.20e+00
# Epoch 3600 - Loss: 2.14e+00, Validation loss: 4.19e+00
# Epoch 3610 - Loss: 2.14e+00, Validation loss: 4.18e+00
# Epoch 3620 - Loss: 2.13e+00, Validation loss: 4.17e+00
# Epoch 3630 - Loss: 2.13e+00, Validation loss: 4.18e+00
# Epoch 3640 - Loss: 2.13e+00, Validation loss: 4.17e+00
# Epoch 3650 - Loss: 2.13e+00, Validation loss: 4.17e+00
# Epoch 3660 - Loss: 2.13e+00, Validation loss: 4.17e+00
# Epoch 3670 - Loss: 2.13e+00, Validation loss: 4.17e+00
# Epoch 3680 - Loss: 2.12e+00, Validation loss: 4.17e+00
# Epoch 3690 - Loss: 2.12e+00, Validation loss: 4.17e+00
# Epoch 3700 - Loss: 2.12e+00, Validation loss: 4.16e+00
# Epoch 3710 - Loss: 2.12e+00, Validation loss: 4.16e+00
# Epoch 3720 - Loss: 2.12e+00, Validation loss: 4.16e+00
# Epoch 3730 - Loss: 2.12e+00, Validation loss: 4.16e+00
# Epoch 3740 - Loss: 2.12e+00, Validation loss: 4.15e+00
# Epoch 3750 - Loss: 2.12e+00, Validation loss: 4.15e+00
# Epoch 3760 - Loss: 2.11e+00, Validation loss: 4.15e+00
# Epoch 3770 - Loss: 2.11e+00, Validation loss: 4.14e+00
# Epoch 3780 - Loss: 2.11e+00, Validation loss: 4.14e+00
# Epoch 3790 - Loss: 2.11e+00, Validation loss: 4.14e+00
# Epoch 3800 - Loss: 2.11e+00, Validation loss: 4.13e+00
# Epoch 3810 - Loss: 2.11e+00, Validation loss: 4.13e+00
# Epoch 3820 - Loss: 2.11e+00, Validation loss: 4.13e+00
# Epoch 3830 - Loss: 2.10e+00, Validation loss: 4.13e+00
# Epoch 3840 - Loss: 2.10e+00, Validation loss: 4.13e+00
# Epoch 3850 - Loss: 2.10e+00, Validation loss: 4.12e+00
# Epoch 3860 - Loss: 2.10e+00, Validation loss: 4.12e+00
# Epoch 3870 - Loss: 2.10e+00, Validation loss: 4.12e+00
# Epoch 3880 - Loss: 2.10e+00, Validation loss: 4.12e+00
# Epoch 3890 - Loss: 2.10e+00, Validation loss: 4.11e+00
# Epoch 3900 - Loss: 2.10e+00, Validation loss: 4.11e+00
# Epoch 3910 - Loss: 2.10e+00, Validation loss: 4.10e+00
# Epoch 3920 - Loss: 2.09e+00, Validation loss: 4.11e+00
# Epoch 3930 - Loss: 2.09e+00, Validation loss: 4.11e+00
# Epoch 3940 - Loss: 2.09e+00, Validation loss: 4.11e+00
# Epoch 3950 - Loss: 2.09e+00, Validation loss: 4.10e+00
# Epoch 3960 - Loss: 2.09e+00, Validation loss: 4.10e+00
# Epoch 3970 - Loss: 2.09e+00, Validation loss: 4.10e+00
# Epoch 3980 - Loss: 2.09e+00, Validation loss: 4.11e+00
# Epoch 3990 - Loss: 2.09e+00, Validation loss: 4.09e+00
# Epoch 4000 - Loss: 2.08e+00, Validation loss: 4.10e+00
# Epoch 4010 - Loss: 2.08e+00, Validation loss: 4.09e+00
# Epoch 4020 - Loss: 2.08e+00, Validation loss: 4.09e+00
# Epoch 4030 - Loss: 2.08e+00, Validation loss: 4.09e+00
# Epoch 4040 - Loss: 2.08e+00, Validation loss: 4.08e+00
# Epoch 4050 - Loss: 2.08e+00, Validation loss: 4.08e+00
# Epoch 4060 - Loss: 2.08e+00, Validation loss: 4.08e+00
# Epoch 4070 - Loss: 2.08e+00, Validation loss: 4.07e+00
# Epoch 4080 - Loss: 2.08e+00, Validation loss: 4.08e+00
# Epoch 4090 - Loss: 2.07e+00, Validation loss: 4.08e+00
# Epoch 4100 - Loss: 2.07e+00, Validation loss: 4.08e+00
# Epoch 4110 - Loss: 2.07e+00, Validation loss: 4.07e+00
# Epoch 4120 - Loss: 2.07e+00, Validation loss: 4.08e+00
# Epoch 4130 - Loss: 2.07e+00, Validation loss: 4.07e+00
# Epoch 4140 - Loss: 2.07e+00, Validation loss: 4.07e+00
# Epoch 4150 - Loss: 2.07e+00, Validation loss: 4.07e+00
# Epoch 4160 - Loss: 2.07e+00, Validation loss: 4.07e+00
# Epoch 4170 - Loss: 2.07e+00, Validation loss: 4.06e+00
# Epoch 4180 - Loss: 2.06e+00, Validation loss: 4.06e+00
# Epoch 4190 - Loss: 2.06e+00, Validation loss: 4.06e+00
# Epoch 4200 - Loss: 2.06e+00, Validation loss: 4.06e+00
# Epoch 4210 - Loss: 2.06e+00, Validation loss: 4.05e+00
# Epoch 4220 - Loss: 2.06e+00, Validation loss: 4.05e+00
# Epoch 4230 - Loss: 2.06e+00, Validation loss: 4.05e+00
# Epoch 4240 - Loss: 2.06e+00, Validation loss: 4.05e+00
# Epoch 4250 - Loss: 2.06e+00, Validation loss: 4.04e+00
# Epoch 4260 - Loss: 2.06e+00, Validation loss: 4.05e+00
# Epoch 4270 - Loss: 2.06e+00, Validation loss: 4.04e+00
# Epoch 4280 - Loss: 2.06e+00, Validation loss: 4.04e+00
# Epoch 4290 - Loss: 2.05e+00, Validation loss: 4.04e+00
# Epoch 4300 - Loss: 2.05e+00, Validation loss: 4.04e+00
# Epoch 4310 - Loss: 2.05e+00, Validation loss: 4.04e+00
# Epoch 4320 - Loss: 2.05e+00, Validation loss: 4.03e+00
# Epoch 4330 - Loss: 2.05e+00, Validation loss: 4.03e+00
# Epoch 4340 - Loss: 2.05e+00, Validation loss: 4.03e+00
# Epoch 4350 - Loss: 2.05e+00, Validation loss: 4.02e+00
# Epoch 4360 - Loss: 2.05e+00, Validation loss: 4.03e+00
# Epoch 4370 - Loss: 2.05e+00, Validation loss: 4.02e+00
# Epoch 4380 - Loss: 2.04e+00, Validation loss: 4.02e+00
# Epoch 4390 - Loss: 2.04e+00, Validation loss: 4.02e+00
# Epoch 4400 - Loss: 2.04e+00, Validation loss: 4.02e+00
# Epoch 4410 - Loss: 2.04e+00, Validation loss: 4.02e+00
# Epoch 4420 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4430 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4440 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4450 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4460 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4470 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4480 - Loss: 2.04e+00, Validation loss: 4.01e+00
# Epoch 4490 - Loss: 2.03e+00, Validation loss: 4.01e+00
# Epoch 4500 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4510 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4520 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4530 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4540 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4550 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4560 - Loss: 2.03e+00, Validation loss: 4.00e+00
# Epoch 4570 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4580 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4590 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4600 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4610 - Loss: 2.03e+00, Validation loss: 3.99e+00
# Epoch 4620 - Loss: 2.02e+00, Validation loss: 3.99e+00
# Epoch 4630 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4640 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4650 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4660 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4670 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4680 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4690 - Loss: 2.02e+00, Validation loss: 3.97e+00
# Epoch 4700 - Loss: 2.02e+00, Validation loss: 3.98e+00
# Epoch 4710 - Loss: 2.02e+00, Validation loss: 3.97e+00
# Epoch 4720 - Loss: 2.02e+00, Validation loss: 3.97e+00
# Epoch 4730 - Loss: 2.02e+00, Validation loss: 3.97e+00
# Epoch 4740 - Loss: 2.02e+00, Validation loss: 3.97e+00
# Epoch 4750 - Loss: 2.01e+00, Validation loss: 3.97e+00
# Epoch 4760 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4770 - Loss: 2.01e+00, Validation loss: 3.97e+00
# Epoch 4780 - Loss: 2.01e+00, Validation loss: 3.97e+00
# Epoch 4790 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4800 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4810 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4820 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4830 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4840 - Loss: 2.01e+00, Validation loss: 3.96e+00
# Epoch 4850 - Loss: 2.01e+00, Validation loss: 3.95e+00
# Epoch 4860 - Loss: 2.01e+00, Validation loss: 3.95e+00
# Epoch 4870 - Loss: 2.01e+00, Validation loss: 3.95e+00
# Epoch 4880 - Loss: 2.01e+00, Validation loss: 3.95e+00
# Epoch 4890 - Loss: 2.00e+00, Validation loss: 3.95e+00
# Epoch 4900 - Loss: 2.00e+00, Validation loss: 3.95e+00
# Epoch 4910 - Loss: 2.00e+00, Validation loss: 3.95e+00
# Epoch 4920 - Loss: 2.00e+00, Validation loss: 3.95e+00
# Epoch 4930 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 4940 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 4950 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 4960 - Loss: 2.00e+00, Validation loss: 3.95e+00
# Epoch 4970 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 4980 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 4990 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 5000 - Loss: 2.00e+00, Validation loss: 3.93e+00
# Epoch 5010 - Loss: 2.00e+00, Validation loss: 3.94e+00
# Epoch 5020 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5030 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5040 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5050 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5060 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5070 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5080 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5090 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5100 - Loss: 1.99e+00, Validation loss: 3.93e+00
# Epoch 5110 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5120 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5130 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5140 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5150 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5160 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5170 - Loss: 1.99e+00, Validation loss: 3.92e+00
# Epoch 5180 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5190 - Loss: 1.98e+00, Validation loss: 3.92e+00
# Epoch 5200 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5210 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5220 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5230 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5240 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5250 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5260 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5270 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5280 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5290 - Loss: 1.98e+00, Validation loss: 3.91e+00
# Epoch 5300 - Loss: 1.98e+00, Validation loss: 3.90e+00
# Epoch 5310 - Loss: 1.98e+00, Validation loss: 3.90e+00
# Epoch 5320 - Loss: 1.98e+00, Validation loss: 3.90e+00
# Epoch 5330 - Loss: 1.98e+00, Validation loss: 3.90e+00
# Epoch 5340 - Loss: 1.98e+00, Validation loss: 3.90e+00
# Epoch 5350 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5360 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5370 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5380 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5390 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5400 - Loss: 1.97e+00, Validation loss: 3.90e+00
# Epoch 5410 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5420 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5430 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5440 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5450 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5460 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5470 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5480 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5490 - Loss: 1.97e+00, Validation loss: 3.89e+00
# Epoch 5500 - Loss: 1.97e+00, Validation loss: 3.88e+00
# Epoch 5510 - Loss: 1.97e+00, Validation loss: 3.88e+00
# Epoch 5520 - Loss: 1.97e+00, Validation loss: 3.88e+00
# Epoch 5530 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5540 - Loss: 1.97e+00, Validation loss: 3.88e+00
# Epoch 5550 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5560 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5570 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5580 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5590 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5600 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5610 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5620 - Loss: 1.96e+00, Validation loss: 3.87e+00
# Epoch 5630 - Loss: 1.96e+00, Validation loss: 3.88e+00
# Epoch 5640 - Loss: 1.96e+00, Validation loss: 3.87e+00
# Restoring model weights from the end of the best epoch: 5592.
# Epoch 5642: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 5: model_fold5_ens1.h5
#
# ✅ Training with {num_folds}-fold cross-validation finished!

# %%
# --- 6. Post-Training Analysis and Visualization ---
print("\n--- Starting Post-Training Analysis ---")
Model_pred_zonal = np.concatenate(trained_model_predictions, axis=0)
y_truth_zonal = y # Use the un-normalized ground truth for comparison
print(f"Shape of final truth data for analysis: {y_truth_zonal.shape}")
print(f"Shape of final prediction data for analysis: {Model_pred_zonal.shape}")

# --- Calculate and Print Overall Pattern Correlation ---
print("\n    Calculating Overall Pattern Correlation...")
from scipy.stats import pearsonr # Ensure this is imported

# Flatten the 2D [time, lat] matrices into 1D vectors
truth_flat = y_truth_zonal.flatten()
pred_flat = Model_pred_zonal.flatten()

# Calculate Pearson correlation between the two flattened vectors
pattern_r, _ = pearsonr(truth_flat, pred_flat)

# Print the single pattern correlation value
print(f"✅ Overall Pattern Correlation (r) = {pattern_r:.4f}")

# --- 3. UPDATED: Plot R-squared as a Function of Latitude ---
print("\n    Calculating and plotting R-squared per latitude...")
from sklearn.metrics import r2_score # Ensure this is imported
r2_by_latitude = []
# Use num_latitudes, which should be defined from your data loading cell (e.g., len(lat))
for i in range(num_latitudes):
    # Calculate R-squared score for each latitude time series
    r2 = r2_score(y_truth_zonal[:, i], Model_pred_zonal[:, i])
    r2_by_latitude.append(r2)

# Plot R2 vs. Latitude
plt.figure(figsize=(10, 6))
plt.plot(lat, r2_by_latitude, marker='o', linestyle='-')
plt.title('Model Performance (R²) by Latitude', fontsize=16)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('R-squared Score', fontsize=12)
plt.grid(True, linestyle='--'); plt.ylim(0, 1)
plt.tight_layout()
# Use your 'output_dir' variable for saving
plt.savefig(os.path.join(output_dir, 'R2_vs_Latitude.png'), dpi=300)
plt.show()

# --- 4. Plot Truth vs. Prediction as a 2D Contour Map ---
print("\n    Plotting Truth vs. Prediction as contour maps...")
time_axis = np.arange(y_truth_zonal.shape[0])

# Use constrained_layout=True to automatically handle spacing
fig, axes = plt.subplots(1, 2, figsize=(20, 7), constrained_layout=True, sharey=True)

# Set the single color scale based on the ground truth
vmax = np.percentile(np.abs(y_truth_zonal), 98)
vmin = -vmax

# --- Plot Ground Truth ---
axes[0].set_title('Ground Truth TOA Zonal Mean', fontsize=16)
axes[0].contourf(time_axis, lat, y_truth_zonal.T, levels=20, cmap='RdBu_r', vmin=vmin, vmax=vmax)
axes[0].set_xlabel('Time (Years)', fontsize=12)
axes[0].set_ylabel('Latitude', fontsize=12)

# --- Plot Model Prediction ---
axes[1].set_title('Predicted TOA Zonal Mean', fontsize=16)
# Capture the output of this plot for the color bar
cf = axes[1].contourf(time_axis, lat, Model_pred_zonal.T, levels=20, cmap='RdBu_r', vmin=vmin, vmax=vmax)
axes[1].set_xlabel('Time (Years)', fontsize=12)

# --- Create Color Bar and Title ---
# Create the color bar for the whole figure
fig.colorbar(cf, ax=axes.ravel().tolist(), shrink=0.8, label='TOA Anomaly (W/m²)')
# Set a main title for the figure
fig.suptitle('In-Sample Performance for Zonal-Mean Prediction', fontsize=20, weight='bold')

# Save and show the figure. No need for fig.tight_layout().
plt.savefig(os.path.join(output_dir, 'Truth_vs_Prediction_ZonalMean.png'), dpi=300)
plt.show()
# Out:
# --- Starting Post-Training Analysis ---
# Shape of final truth data for analysis: (1801, 192)
# Shape of final prediction data for analysis: (1801, 192)
#
#     Calculating Overall Pattern Correlation...
# ✅ Overall Pattern Correlation (r) = 0.4899
#
#     Calculating and plotting R-squared per latitude...
#     Plotting Truth vs. Prediction as contour maps...
