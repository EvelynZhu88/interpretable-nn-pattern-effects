# %%
# ==========================================================
# FINAL, COMPLETE TRAINING SCRIPT FOR ZONAL-MEAN (2D) OUTPUT
# ==========================================================

"GlobalAveragePooling layer"
"TERRIBLE PERFORMANCE DO NOT USE"

import os
import gc
import logging
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import r2_score
from keras.models import Model
from keras.layers import Dense, PReLU, Dropout, Conv2D, Flatten, MaxPooling2D, Activation
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from sklearn.model_selection import KFold
from scipy.stats import pearsonr
import xarray as xr
import scipy.io as sio
from keras.layers import Dense, PReLU, Dropout, Conv2D, Flatten, MaxPooling2D, Activation, GlobalAveragePooling2D

# --- 1. Configuration ---
# Ensure this section points to the correct files for the model you are training (e.g., CESM1 or CESM2)
# Using CESM2 paths as an example:
path_input = "/ocean/projects/ees250004p/ezhu3/data/CESM1/control/input.B1850C5CN.TS.ANN.0400-2200.new.nc"
In_name = "TS" 
path_output = "/ocean/projects/ees250004p/ezhu3/data/CESM1/control/output.B1850C5CN.TOA.zmean.ANN.0400-2200.new.nc"
Out_name = "TOA_anom" 
data_dir_out = '/ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D'

# Hyperparameters from your script
kernels = [32, 32]
kernel_acts = ["gelu", "gelu"]
hiddens = [16, 8]
activation_function_dense = ["PReLU", "PReLU"]
loss_function = 'mse'
reg_strength = 0
dropout_rate = 0.25
epoch_max = 25000
batch_size = 32
learning_rate = 0.000005
num_folds = 5
NNrepeats = 1
# Out:
# 2025-07-30 04:55:12.072651: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-30 04:55:12.194036: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-30 04:55:12.227871: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import logging
from tensorflow.keras.callbacks import Callback

def create_NN_name():
    NN_name = 'CNN'
    activation_function_str = '_' + kernel_acts[0] + '+' + activation_function_dense[0]
    NN_structure_str = 'x'.join(map(str, kernels))
    reg_str = f'Reg{reg_strength}' + (f'Drop{dropout_rate}' if dropout_rate != 0 else '')
    batch_size_str = f'BS{batch_size}_'
    # This creates a long, descriptive name like "CNN_Neur32x32_BS32_..."
    return f"{NN_name}_Neur{NN_structure_str}_{batch_size_str}{num_folds}foldCV_{reg_str}{activation_function_str}"

NN_name = create_NN_name()
# The final output_dir will be something like .../trained_model_2D/NeuralNet/CNN_Neur32x32.../TOA_anom
output_dir = os.path.join(data_dir_out, 'NeuralNet', NN_name, "TOA_anom")
os.makedirs(output_dir, exist_ok=True)
print(f"✅ Models and logs will be saved in: {output_dir}")

# ==========================================================
# Logger and Custom Callback Configuration
# ==========================================================

# --- 1. Configure the Logger ---
# This sets up logging to save progress messages to 'logfile.log'
# and also print them to your screen.

print("--- Configuring Logger ---")
logger_name = 'logfile.log'
# Get a logger instance
logger = logging.getLogger(__name__)
# Clear existing handlers to avoid duplicate messages in notebooks
if (logger.hasHandlers()):
    logger.handlers.clear()
    
logger.setLevel(logging.INFO)

# Create handlers for file and console
file_handler = logging.FileHandler(os.path.join(output_dir, logger_name))
console_handler = logging.StreamHandler()
file_handler.setLevel(logging.INFO)
console_handler.setLevel(logging.INFO)

# Create a formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add the handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

logger.info(f"Logging configured. Output will be saved in: {output_dir}")


# --- 2. Define Custom Callback for Periodic Logging ---
# This creates the functionality to print the training loss every 10 epochs.

print("--- Defining Custom Keras Callbacks ---")
log_path = os.path.join(output_dir, 'training_logs.txt')

class PrintTrainingOnTextEvery10EpochsCallback(Callback):
    def __init__(self, log_path):
        super().__init__()
        self.log_path = log_path

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        if epoch % 10 == 0:
            # Log to a text file
            with open(self.log_path, "a") as log_file:
                log_file.write(
                    f"Epoch: {epoch:>4} | "
                    f"Loss: {logs.get('loss', 0):.2e} | "
                    f"Validation loss: {logs.get('val_loss', 0):.2e}\n"
                )
            # Also print to the console
            print(
                f"Epoch {epoch:>4} - "
                f"Loss: {logs.get('loss', 0):.2e}, "
                f"Validation loss: {logs.get('val_loss', 0):.2e}"
            )

# Create the my_callbacks list that will be passed to model.fit()
my_callbacks = [
    PrintTrainingOnTextEvery10EpochsCallback(log_path=log_path),
]

print("✅ Logger and my_callbacks are now defined.")
# Out:
# 2025-07-30 04:55:14,950 - Logging configured. Output will be saved in: /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D/NeuralNet/CNN_Neur32x32_BS32_5foldCV_Reg0Drop0.25_gelu+PReLU/TOA_anom
# ✅ Models and logs will be saved in: /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D/NeuralNet/CNN_Neur32x32_BS32_5foldCV_Reg0Drop0.25_gelu+PReLU/TOA_anom
# --- Configuring Logger ---
# --- Defining Custom Keras Callbacks ---
# ✅ Logger and my_callbacks are now defined.

# %%
# --- 2. Load and Prepare Data ---
print("--- Loading and Preparing Data ---")
# Load input data (TS maps)
ds_X = xr.open_dataset(path_input)
input_data = ds_X[In_name].values # Shape: (time, lat, lon)
lat = ds_X['lat'].values
lon = ds_X['lon'].values
num_latitudes = len(lat)

# Load NEW target output data (zonal-mean TOA)
ds_y = xr.open_dataset(path_output)
output_data = ds_y[Out_name].values # Shape: (time, lat)

# Check for consistent time dimension length
if input_data.shape[0] != output_data.shape[0]:
    raise ValueError(f"Time dimension mismatch! Input X has {input_data.shape[0]} samples, while Target Y has {output_data.shape[0]} samples.")

# The variables X and y will hold the raw data before normalization
X = input_data[:, :, :, np.newaxis] # Add channel dimension
y = output_data # Already in the correct [time, lat] shape

print(f"Input data shape (X): {X.shape}")
print(f"Output data shape (y): {y.shape}")

# --- 3. Normalization ---
print("--- Normalizing Data ---")
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
y_mean = np.mean(y, axis=0)
y_std = np.std(y, axis=0)

# These are the final, normalized arrays we will use for training
X_norm = (X - X_mean) / X_std
y_norm = (y - y_mean) / y_std
print("✅ Normalization complete.")

# Save normalization statistics
os.makedirs(data_dir_out, exist_ok=True)
sio.savemat(os.path.join(data_dir_out, 'Normalization_zonal.mat'),
            {'X_mean': X_mean, 'X_std': X_std, 'y_mean': y_mean, 'y_std': y_std})
print(f"Normalization data saved to {data_dir_out}")
# Out:
# --- Loading and Preparing Data ---
# Input data shape (X): (1801, 192, 288, 1)
# Output data shape (y): (1801, 192)
# --- Normalizing Data ---
# ✅ Normalization complete.
# Normalization data saved to /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_model_2D

# %%
# --- 4. Define your train_model function ---
# (You should have your 'train_model' function defined here as it was in your original script,
# making sure the final Dense layer is set to `Dense(num_latitudes, ...)` )
# For completeness, here is a compatible 'build_model' and 'train_model' structure:
def train_model(X_train, y_train, X_test, y_test, y_mean, y_std):
    inputs = tf.keras.Input(shape=(X_train.shape[1:]),)
    layers = inputs

    # Convolutional Layers
    for i, kernel_filters in enumerate(kernels): # Assuming kernels is a list of filter numbers
        layers = Conv2D(
            kernel_filters,
            (kernel_size, kernel_size), # Assuming kernel_size is defined
            strides=(stride, stride),     # Assuming stride is defined
            use_bias=True,
            padding="same",
            # NO 'activation' argument here if PReLU or another layer follows
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming kernel_acts[i] could be 'prelu', 'gelu', 'relu', etc.
        if kernel_acts[i].lower() == 'prelu':
            layers = PReLU(shared_axes=[1, 2],
                           alpha_initializer=tf.keras.initializers.Constant(0.25) # Common starting point
                          )(layers) # shared_axes for Conv2D with channels_last
        elif kernel_acts[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers) # Using Activation layer for GeLU
        elif kernel_acts[i]: # For 'relu', 'elu', etc.
            layers = tf.keras.layers.Activation(kernel_acts[i])(layers)
        # If kernel_acts[i] is None or an empty string, no explicit activation layer added here.

        layers = MaxPooling2D((pool_size, pool_size))(layers) # Assuming pool_size is defined
    
    layers = Flatten()(layers)
    # Dense Layers
    for i, hidden_units in enumerate(hiddens): # Assuming hiddens is a list of unit numbers
        layers = Dense(
            hidden_units,
            use_bias=True,
            # NO 'activation' argument here
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming activation_function_dense[i] could be 'prelu', 'gelu', 'elu', etc.
        if activation_function_dense[i].lower() == 'prelu':
            layers = PReLU(alpha_initializer=tf.keras.initializers.Constant(0.25))(layers) # No shared_axes for Dense
        elif activation_function_dense[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers)
        elif activation_function_dense[i]: # For 'elu', 'relu', etc.
            layers = tf.keras.layers.Activation(activation_function_dense[i])(layers)
        # If activation_function_dense[i] is None or an empty string, no explicit activation layer.

    num_latitudes = len(lat) # or lat.size
    output_layer = Dense(
        num_latitudes, # This is the change
        activation="linear",
        use_bias=True,
        bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
    )(layers)
    
    model = Model(inputs, output_layer)
    if fold_no + ens_no == 2: # Assuming these are defined in your script's scope
        model.summary()

    model.compile(loss=loss_function, optimizer=Adam(learning_rate=learning_rate)) # Assuming these are defined

    early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='auto', restore_best_weights=True, verbose=1) # restore_best_weights=1 is True

    # Make sure my_callbacks is defined in this scope or passed as an argument
    history = model.fit(X_train, y_train, epochs=epoch_max, batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[early_stopping] + my_callbacks, verbose=0) # Added '+' for list concatenation

    skill = model.evaluate(X_test, y_test, verbose=0)
    pred = (model.predict(X_test) * y_std) + y_mean # Make sure y_std and y_mean are defined

    R2_val = []
    truth = (y_test * y_std) + y_mean
    for latind in range(truth.shape[1] if truth.ndim > 1 else 1): # Handle if y_test is 1D output
        y_lat = truth[:, latind] if truth.ndim > 1 else truth
        y_pred_lat = pred[:, latind] if pred.ndim > 1 else pred
        R2_val.append(r2_score(y_lat, y_pred_lat))
    
    model.save(os.path.join(output_dir,'model_fold'+str(fold_no)+'_ens'+str(ens_no)+'.h5'))
    
    return skill, history, pred, R2_val

# %%
def build_and_train_model(X_train, y_train, X_test, y_test):
    tf.keras.backend.clear_session()
    gc.collect()

    input_shape = X_train.shape[1:]
    output_shape = y_train.shape[1]
    
    # --- Define Model Architecture ---
    inputs = tf.keras.Input(shape=input_shape)
    # Define layers based on your hyperparameters
    x = Conv2D(kernels[0], 3, padding='same', activation=kernel_acts[0])(inputs)
    x = MaxPooling2D(2)(x)
    x = Conv2D(kernels[1], 3, padding='same', activation=kernel_acts[1])(x)
    x = MaxPooling2D(2)(x)
    x = GlobalAveragePooling2D()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(hiddens[0])(x)
    x = PReLU()(x) # As per your activation_function_dense
    x = Dense(hiddens[1])(x)
    x = PReLU()(x) # As per your activation_function_dense
    outputs = Dense(output_shape, activation='linear')(x)
    model = Model(inputs=inputs, outputs=outputs)
    
    model.compile(loss=loss_function, optimizer=Adam(learning_rate=learning_rate))
    
    early_stopping = EarlyStopping(patience=50, monitor='val_loss', mode='min', restore_best_weights=True, verbose=1)
    
    history = model.fit(X_train, y_train, epochs=epoch_max, batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[early_stopping]+my_callbacks, verbose=0)
    
    # Un-normalize prediction for storage
    pred_normalized = model.predict(X_test)
    pred_unnormalized = pred_normalized * y_std + y_mean
    
    return model, history, pred_unnormalized

# --- 5. K-Fold Training Loop ---
kfold = KFold(n_splits=num_folds, shuffle=False)
fold_no = 1
trained_model_predictions = []
trained_model_histories = []

print("\n--- Starting K-Fold Training ---")
for trainind, testind in kfold.split(X_norm, y_norm):
    X_train, X_test = X_norm[trainind], X_norm[testind]
    y_train, y_test = y_norm[trainind], y_norm[testind]
    
    print(f"--- Training Model: Fold {fold_no} ---")
    model, history, fold_pred = build_and_train_model(X_train, y_train, X_test, y_test)
    
    trained_model_histories.append(history)
    trained_model_predictions.append(fold_pred)
    
    model_filename = f'model_fold{fold_no}_ens1.h5' # Assuming 1 ensemble
    model.save(os.path.join(data_dir_out, model_filename))
    print(f"Saved model for fold {fold_no}: {model_filename}")
    fold_no += 1

print("\n✅ Training with {num_folds}-fold cross-validation finished!")
# Out:
# --- Starting K-Fold Training ---
# --- Training Model: Fold 1 ---
# 2025-07-30 04:55:16.181708: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-30 04:55:16.626433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:16:00.0, compute capability: 7.0
# 2025-07-30 04:55:18.209999: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8201
# Epoch    0 - Loss: 9.87e-01, Validation loss: 1.05e+00
# Epoch   10 - Loss: 9.86e-01, Validation loss: 1.05e+00
# Epoch   20 - Loss: 9.86e-01, Validation loss: 1.05e+00
# Epoch   30 - Loss: 9.86e-01, Validation loss: 1.05e+00
# Epoch   40 - Loss: 9.86e-01, Validation loss: 1.05e+00
# Epoch   50 - Loss: 9.85e-01, Validation loss: 1.05e+00
# Epoch   60 - Loss: 9.85e-01, Validation loss: 1.05e+00
# Epoch   70 - Loss: 9.84e-01, Validation loss: 1.05e+00
# Epoch   80 - Loss: 9.84e-01, Validation loss: 1.05e+00
# Epoch   90 - Loss: 9.83e-01, Validation loss: 1.05e+00
# Epoch  100 - Loss: 9.82e-01, Validation loss: 1.05e+00
# Epoch  110 - Loss: 9.81e-01, Validation loss: 1.05e+00
# Epoch  120 - Loss: 9.80e-01, Validation loss: 1.05e+00
# Epoch  130 - Loss: 9.79e-01, Validation loss: 1.05e+00
# Epoch  140 - Loss: 9.78e-01, Validation loss: 1.04e+00
# Epoch  150 - Loss: 9.77e-01, Validation loss: 1.04e+00
# Epoch  160 - Loss: 9.75e-01, Validation loss: 1.04e+00
# Epoch  170 - Loss: 9.75e-01, Validation loss: 1.04e+00
# Epoch  180 - Loss: 9.73e-01, Validation loss: 1.04e+00
# Epoch  190 - Loss: 9.72e-01, Validation loss: 1.04e+00
# Epoch  200 - Loss: 9.70e-01, Validation loss: 1.04e+00
# Epoch  210 - Loss: 9.70e-01, Validation loss: 1.03e+00
# Epoch  220 - Loss: 9.68e-01, Validation loss: 1.03e+00
# Epoch  230 - Loss: 9.67e-01, Validation loss: 1.03e+00
# Epoch  240 - Loss: 9.66e-01, Validation loss: 1.03e+00
# Epoch  250 - Loss: 9.64e-01, Validation loss: 1.03e+00
# Epoch  260 - Loss: 9.64e-01, Validation loss: 1.03e+00
# Epoch  270 - Loss: 9.62e-01, Validation loss: 1.03e+00
# Epoch  280 - Loss: 9.60e-01, Validation loss: 1.02e+00
# Epoch  290 - Loss: 9.59e-01, Validation loss: 1.02e+00
# Epoch  300 - Loss: 9.58e-01, Validation loss: 1.02e+00
# Epoch  310 - Loss: 9.56e-01, Validation loss: 1.02e+00
# Epoch  320 - Loss: 9.57e-01, Validation loss: 1.02e+00
# Epoch  330 - Loss: 9.55e-01, Validation loss: 1.02e+00
# Epoch  340 - Loss: 9.55e-01, Validation loss: 1.02e+00
# Epoch  350 - Loss: 9.52e-01, Validation loss: 1.01e+00
# Epoch  360 - Loss: 9.51e-01, Validation loss: 1.01e+00
# Epoch  370 - Loss: 9.49e-01, Validation loss: 1.01e+00
# Epoch  380 - Loss: 9.48e-01, Validation loss: 1.01e+00
# Epoch  390 - Loss: 9.46e-01, Validation loss: 1.01e+00
# Epoch  400 - Loss: 9.45e-01, Validation loss: 1.01e+00
# Epoch  410 - Loss: 9.46e-01, Validation loss: 1.01e+00
# Epoch  420 - Loss: 9.42e-01, Validation loss: 1.01e+00
# Epoch  430 - Loss: 9.45e-01, Validation loss: 1.00e+00
# Epoch  440 - Loss: 9.43e-01, Validation loss: 1.00e+00
# Epoch  450 - Loss: 9.43e-01, Validation loss: 1.00e+00
# Epoch  460 - Loss: 9.39e-01, Validation loss: 1.00e+00
# Epoch  470 - Loss: 9.41e-01, Validation loss: 1.00e+00
# Epoch  480 - Loss: 9.41e-01, Validation loss: 1.00e+00
# Epoch  490 - Loss: 9.39e-01, Validation loss: 9.99e-01
# Epoch  500 - Loss: 9.38e-01, Validation loss: 9.98e-01
# Epoch  510 - Loss: 9.35e-01, Validation loss: 9.97e-01
# Epoch  520 - Loss: 9.35e-01, Validation loss: 9.97e-01
# Epoch  530 - Loss: 9.35e-01, Validation loss: 9.96e-01
# Epoch  540 - Loss: 9.40e-01, Validation loss: 9.95e-01
# Epoch  550 - Loss: 9.36e-01, Validation loss: 9.95e-01
# Epoch  560 - Loss: 9.35e-01, Validation loss: 9.94e-01
# Epoch  570 - Loss: 9.32e-01, Validation loss: 9.93e-01
# Epoch  580 - Loss: 9.33e-01, Validation loss: 9.93e-01
# Epoch  590 - Loss: 9.32e-01, Validation loss: 9.92e-01
# Epoch  600 - Loss: 9.35e-01, Validation loss: 9.92e-01
# Epoch  610 - Loss: 9.31e-01, Validation loss: 9.91e-01
# Epoch  620 - Loss: 9.30e-01, Validation loss: 9.91e-01
# Epoch  630 - Loss: 9.31e-01, Validation loss: 9.90e-01
# Epoch  640 - Loss: 9.30e-01, Validation loss: 9.90e-01
# Epoch  650 - Loss: 9.28e-01, Validation loss: 9.89e-01
# Epoch  660 - Loss: 9.30e-01, Validation loss: 9.89e-01
# Epoch  670 - Loss: 9.29e-01, Validation loss: 9.89e-01
# Epoch  680 - Loss: 9.30e-01, Validation loss: 9.88e-01
# Epoch  690 - Loss: 9.29e-01, Validation loss: 9.88e-01
# Epoch  700 - Loss: 9.28e-01, Validation loss: 9.88e-01
# Epoch  710 - Loss: 9.29e-01, Validation loss: 9.87e-01
# Epoch  720 - Loss: 9.29e-01, Validation loss: 9.87e-01
# Epoch  730 - Loss: 9.28e-01, Validation loss: 9.87e-01
# Epoch  740 - Loss: 9.28e-01, Validation loss: 9.86e-01
# Epoch  750 - Loss: 9.26e-01, Validation loss: 9.86e-01
# Epoch  760 - Loss: 9.26e-01, Validation loss: 9.86e-01
# Epoch  770 - Loss: 9.28e-01, Validation loss: 9.86e-01
# Epoch  780 - Loss: 9.28e-01, Validation loss: 9.85e-01
# Epoch  790 - Loss: 9.24e-01, Validation loss: 9.85e-01
# Epoch  800 - Loss: 9.26e-01, Validation loss: 9.85e-01
# Epoch  810 - Loss: 9.26e-01, Validation loss: 9.85e-01
# Epoch  820 - Loss: 9.26e-01, Validation loss: 9.85e-01
# Epoch  830 - Loss: 9.25e-01, Validation loss: 9.85e-01
# Epoch  840 - Loss: 9.25e-01, Validation loss: 9.84e-01
# Epoch  850 - Loss: 9.26e-01, Validation loss: 9.84e-01
# Epoch  860 - Loss: 9.22e-01, Validation loss: 9.84e-01
# Epoch  870 - Loss: 9.26e-01, Validation loss: 9.84e-01
# Epoch  880 - Loss: 9.22e-01, Validation loss: 9.84e-01
# Epoch  890 - Loss: 9.24e-01, Validation loss: 9.84e-01
# Epoch  900 - Loss: 9.23e-01, Validation loss: 9.83e-01
# Epoch  910 - Loss: 9.23e-01, Validation loss: 9.83e-01
# Epoch  920 - Loss: 9.24e-01, Validation loss: 9.83e-01
# Epoch  930 - Loss: 9.22e-01, Validation loss: 9.83e-01
# Epoch  940 - Loss: 9.25e-01, Validation loss: 9.83e-01
# Epoch  950 - Loss: 9.26e-01, Validation loss: 9.83e-01
# Epoch  960 - Loss: 9.23e-01, Validation loss: 9.83e-01
# Epoch  970 - Loss: 9.23e-01, Validation loss: 9.83e-01
# Epoch  980 - Loss: 9.22e-01, Validation loss: 9.83e-01
# Epoch  990 - Loss: 9.24e-01, Validation loss: 9.83e-01
# Epoch 1000 - Loss: 9.25e-01, Validation loss: 9.82e-01
# Epoch 1010 - Loss: 9.23e-01, Validation loss: 9.82e-01
# Epoch 1020 - Loss: 9.21e-01, Validation loss: 9.82e-01
# Epoch 1030 - Loss: 9.25e-01, Validation loss: 9.82e-01
# Epoch 1040 - Loss: 9.23e-01, Validation loss: 9.82e-01
# Epoch 1050 - Loss: 9.22e-01, Validation loss: 9.82e-01
# Epoch 1060 - Loss: 9.25e-01, Validation loss: 9.82e-01
# Epoch 1070 - Loss: 9.23e-01, Validation loss: 9.82e-01
# Epoch 1080 - Loss: 9.21e-01, Validation loss: 9.82e-01
# Epoch 1090 - Loss: 9.22e-01, Validation loss: 9.82e-01
# Epoch 1100 - Loss: 9.24e-01, Validation loss: 9.82e-01
# Epoch 1110 - Loss: 9.21e-01, Validation loss: 9.82e-01
# Epoch 1120 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1130 - Loss: 9.23e-01, Validation loss: 9.82e-01
# Epoch 1140 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1150 - Loss: 9.25e-01, Validation loss: 9.81e-01
# Epoch 1160 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1170 - Loss: 9.23e-01, Validation loss: 9.81e-01
# Epoch 1180 - Loss: 9.24e-01, Validation loss: 9.81e-01
# Epoch 1190 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1200 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1210 - Loss: 9.18e-01, Validation loss: 9.81e-01
# Epoch 1220 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1230 - Loss: 9.19e-01, Validation loss: 9.81e-01
# Epoch 1240 - Loss: 9.20e-01, Validation loss: 9.81e-01
# Epoch 1250 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1260 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1270 - Loss: 9.20e-01, Validation loss: 9.81e-01
# Epoch 1280 - Loss: 9.20e-01, Validation loss: 9.81e-01
# Epoch 1290 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1300 - Loss: 9.19e-01, Validation loss: 9.81e-01
# Epoch 1310 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1320 - Loss: 9.23e-01, Validation loss: 9.81e-01
# Epoch 1330 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1340 - Loss: 9.19e-01, Validation loss: 9.81e-01
# Epoch 1350 - Loss: 9.22e-01, Validation loss: 9.81e-01
# Epoch 1360 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1370 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1380 - Loss: 9.21e-01, Validation loss: 9.80e-01
# Epoch 1390 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1400 - Loss: 9.21e-01, Validation loss: 9.81e-01
# Epoch 1410 - Loss: 9.21e-01, Validation loss: 9.80e-01
# Epoch 1420 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1430 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1440 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1450 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1460 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1470 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1480 - Loss: 9.21e-01, Validation loss: 9.80e-01
# Epoch 1490 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1500 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1510 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1520 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1530 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1540 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1550 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1560 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1570 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1580 - Loss: 9.21e-01, Validation loss: 9.80e-01
# Epoch 1590 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1600 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1610 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1620 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1630 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1640 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1650 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1660 - Loss: 9.22e-01, Validation loss: 9.80e-01
# Epoch 1670 - Loss: 9.21e-01, Validation loss: 9.80e-01
# Epoch 1680 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1690 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1700 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1710 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1720 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1730 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1740 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1750 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1760 - Loss: 9.18e-01, Validation loss: 9.80e-01
# Epoch 1770 - Loss: 9.19e-01, Validation loss: 9.80e-01
# Epoch 1780 - Loss: 9.18e-01, Validation loss: 9.80e-01
# Epoch 1790 - Loss: 9.20e-01, Validation loss: 9.80e-01
# Epoch 1800 - Loss: 9.18e-01, Validation loss: 9.80e-01
# Epoch 1810 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1820 - Loss: 9.20e-01, Validation loss: 9.79e-01
# Epoch 1830 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 1840 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 1850 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 1860 - Loss: 9.20e-01, Validation loss: 9.79e-01
# Epoch 1870 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1880 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1890 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 1900 - Loss: 9.20e-01, Validation loss: 9.79e-01
# Epoch 1910 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 1920 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 1930 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1940 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 1950 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1960 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 1970 - Loss: 9.20e-01, Validation loss: 9.79e-01
# Epoch 1980 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 1990 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2000 - Loss: 9.20e-01, Validation loss: 9.79e-01
# Epoch 2010 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2020 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2030 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2040 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2050 - Loss: 9.21e-01, Validation loss: 9.79e-01
# Epoch 2060 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2070 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2080 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2090 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2100 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 2110 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2120 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2130 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2140 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2150 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 2160 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2170 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2180 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2190 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2200 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2210 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2220 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2230 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2240 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2250 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2260 - Loss: 9.18e-01, Validation loss: 9.79e-01
# Epoch 2270 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 2280 - Loss: 9.17e-01, Validation loss: 9.79e-01
# Epoch 2290 - Loss: 9.19e-01, Validation loss: 9.79e-01
# Epoch 2300 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2310 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2320 - Loss: 9.16e-01, Validation loss: 9.79e-01
# Epoch 2330 - Loss: 9.20e-01, Validation loss: 9.78e-01
# Epoch 2340 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2350 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2360 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2370 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2380 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2390 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2400 - Loss: 9.20e-01, Validation loss: 9.78e-01
# Epoch 2410 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2420 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2430 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2440 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2450 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2460 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2470 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2480 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2490 - Loss: 9.15e-01, Validation loss: 9.78e-01
# Epoch 2500 - Loss: 9.19e-01, Validation loss: 9.78e-01
# Epoch 2510 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2520 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2530 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2540 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2550 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2560 - Loss: 9.13e-01, Validation loss: 9.78e-01
# Epoch 2570 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2580 - Loss: 9.15e-01, Validation loss: 9.78e-01
# Epoch 2590 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2600 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2610 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2620 - Loss: 9.15e-01, Validation loss: 9.78e-01
# Epoch 2630 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2640 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2650 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2660 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2670 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2680 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2690 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2700 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2710 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2720 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2730 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2740 - Loss: 9.15e-01, Validation loss: 9.78e-01
# Epoch 2750 - Loss: 9.18e-01, Validation loss: 9.78e-01
# Epoch 2760 - Loss: 9.16e-01, Validation loss: 9.78e-01
# Epoch 2770 - Loss: 9.17e-01, Validation loss: 9.78e-01
# Epoch 2780 - Loss: 9.14e-01, Validation loss: 9.78e-01
# Epoch 2790 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 2800 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 2810 - Loss: 9.15e-01, Validation loss: 9.78e-01
# Epoch 2820 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 2830 - Loss: 9.18e-01, Validation loss: 9.77e-01
# Epoch 2840 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2850 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2860 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2870 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2880 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 2890 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2900 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 2910 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 2920 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 2930 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2940 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2950 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 2960 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 2970 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2980 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 2990 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3000 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 3010 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3020 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 3030 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 3040 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 3050 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3060 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3070 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 3080 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3090 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 3100 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 3110 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 3120 - Loss: 9.13e-01, Validation loss: 9.77e-01
# Epoch 3130 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 3140 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3150 - Loss: 9.13e-01, Validation loss: 9.77e-01
# Epoch 3160 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 3170 - Loss: 9.17e-01, Validation loss: 9.77e-01
# Epoch 3180 - Loss: 9.14e-01, Validation loss: 9.77e-01
# Epoch 3190 - Loss: 9.15e-01, Validation loss: 9.77e-01
# Epoch 3200 - Loss: 9.16e-01, Validation loss: 9.77e-01
# Epoch 3210 - Loss: 9.13e-01, Validation loss: 9.77e-01
# Epoch 3220 - Loss: 9.12e-01, Validation loss: 9.77e-01
# Epoch 3230 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3240 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3250 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3260 - Loss: 9.16e-01, Validation loss: 9.76e-01
# Epoch 3270 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3280 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3290 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3300 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3310 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3320 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3330 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3340 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3350 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3360 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3370 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3380 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3390 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3400 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3410 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3420 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3430 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3440 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3450 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3460 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3470 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3480 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3490 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3500 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3510 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3520 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3530 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3540 - Loss: 9.11e-01, Validation loss: 9.76e-01
# Epoch 3550 - Loss: 9.15e-01, Validation loss: 9.76e-01
# Epoch 3560 - Loss: 9.12e-01, Validation loss: 9.76e-01
# Epoch 3570 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3580 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3590 - Loss: 9.14e-01, Validation loss: 9.76e-01
# Epoch 3600 - Loss: 9.11e-01, Validation loss: 9.76e-01
# Epoch 3610 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3620 - Loss: 9.10e-01, Validation loss: 9.76e-01
# Epoch 3630 - Loss: 9.13e-01, Validation loss: 9.76e-01
# Epoch 3640 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3650 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3660 - Loss: 9.14e-01, Validation loss: 9.75e-01
# Epoch 3670 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3680 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3690 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3700 - Loss: 9.14e-01, Validation loss: 9.75e-01
# Epoch 3710 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3720 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3730 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3740 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3750 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3760 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3770 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3780 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3790 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3800 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3810 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3820 - Loss: 9.10e-01, Validation loss: 9.75e-01
# Epoch 3830 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3840 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3850 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3860 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3870 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3880 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3890 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3900 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3910 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3920 - Loss: 9.13e-01, Validation loss: 9.75e-01
# Epoch 3930 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3940 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3950 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3960 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3970 - Loss: 9.12e-01, Validation loss: 9.75e-01
# Epoch 3980 - Loss: 9.11e-01, Validation loss: 9.75e-01
# Epoch 3990 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4000 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4010 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4020 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4030 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4040 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4050 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4060 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4070 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4080 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4090 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4100 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4110 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4120 - Loss: 9.09e-01, Validation loss: 9.74e-01
# Epoch 4130 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4140 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4150 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4160 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4170 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4180 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4190 - Loss: 9.09e-01, Validation loss: 9.74e-01
# Epoch 4200 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4210 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4220 - Loss: 9.11e-01, Validation loss: 9.74e-01
# Epoch 4230 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4240 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4250 - Loss: 9.12e-01, Validation loss: 9.74e-01
# Epoch 4260 - Loss: 9.10e-01, Validation loss: 9.74e-01
# Epoch 4270 - Loss: 9.11e-01, Validation loss: 9.73e-01
# Epoch 4280 - Loss: 9.12e-01, Validation loss: 9.73e-01
# Epoch 4290 - Loss: 9.11e-01, Validation loss: 9.73e-01
# Epoch 4300 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4310 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4320 - Loss: 9.12e-01, Validation loss: 9.73e-01
# Epoch 4330 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4340 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4350 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4360 - Loss: 9.11e-01, Validation loss: 9.73e-01
# Epoch 4370 - Loss: 9.08e-01, Validation loss: 9.73e-01
# Epoch 4380 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4390 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4400 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4410 - Loss: 9.08e-01, Validation loss: 9.73e-01
# Epoch 4420 - Loss: 9.11e-01, Validation loss: 9.73e-01
# Epoch 4430 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4440 - Loss: 9.08e-01, Validation loss: 9.73e-01
# Epoch 4450 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4460 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4470 - Loss: 9.08e-01, Validation loss: 9.73e-01
# Epoch 4480 - Loss: 9.07e-01, Validation loss: 9.73e-01
# Epoch 4490 - Loss: 9.10e-01, Validation loss: 9.73e-01
# Epoch 4500 - Loss: 9.09e-01, Validation loss: 9.73e-01
# Epoch 4510 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4520 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4530 - Loss: 9.07e-01, Validation loss: 9.72e-01
# Epoch 4540 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4550 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4560 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4570 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4580 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4590 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4600 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4610 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4620 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4630 - Loss: 9.10e-01, Validation loss: 9.72e-01
# Epoch 4640 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4650 - Loss: 9.10e-01, Validation loss: 9.72e-01
# Epoch 4660 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4670 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4680 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4690 - Loss: 9.07e-01, Validation loss: 9.72e-01
# Epoch 4700 - Loss: 9.08e-01, Validation loss: 9.72e-01
# Epoch 4710 - Loss: 9.08e-01, Validation loss: 9.71e-01
# Epoch 4720 - Loss: 9.09e-01, Validation loss: 9.72e-01
# Epoch 4730 - Loss: 9.08e-01, Validation loss: 9.71e-01
# Epoch 4740 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4750 - Loss: 9.11e-01, Validation loss: 9.71e-01
# Epoch 4760 - Loss: 9.08e-01, Validation loss: 9.71e-01
# Epoch 4770 - Loss: 9.08e-01, Validation loss: 9.71e-01
# Epoch 4780 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4790 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4800 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4810 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4820 - Loss: 9.08e-01, Validation loss: 9.71e-01
# Epoch 4830 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4840 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4850 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4860 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4870 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4880 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4890 - Loss: 9.05e-01, Validation loss: 9.71e-01
# Epoch 4900 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4910 - Loss: 9.06e-01, Validation loss: 9.71e-01
# Epoch 4920 - Loss: 9.09e-01, Validation loss: 9.71e-01
# Epoch 4930 - Loss: 9.07e-01, Validation loss: 9.71e-01
# Epoch 4940 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 4950 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 4960 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 4970 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 4980 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 4990 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5000 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5010 - Loss: 9.05e-01, Validation loss: 9.70e-01
# Epoch 5020 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 5030 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 5040 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5050 - Loss: 9.09e-01, Validation loss: 9.70e-01
# Epoch 5060 - Loss: 9.08e-01, Validation loss: 9.70e-01
# Epoch 5070 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5080 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 5090 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5100 - Loss: 9.07e-01, Validation loss: 9.70e-01
# Epoch 5110 - Loss: 9.06e-01, Validation loss: 9.70e-01
# Epoch 5120 - Loss: 9.06e-01, Validation loss: 9.69e-01
# Epoch 5130 - Loss: 9.07e-01, Validation loss: 9.69e-01
# Epoch 5140 - Loss: 9.07e-01, Validation loss: 9.69e-01
# Epoch 5150 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5160 - Loss: 9.06e-01, Validation loss: 9.69e-01
# Epoch 5170 - Loss: 9.06e-01, Validation loss: 9.69e-01
# Epoch 5180 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5190 - Loss: 9.07e-01, Validation loss: 9.69e-01
# Epoch 5200 - Loss: 9.06e-01, Validation loss: 9.69e-01
# Epoch 5210 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5220 - Loss: 9.04e-01, Validation loss: 9.69e-01
# Epoch 5230 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5240 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5250 - Loss: 9.05e-01, Validation loss: 9.69e-01
# Epoch 5260 - Loss: 9.07e-01, Validation loss: 9.69e-01
# Epoch 5270 - Loss: 9.04e-01, Validation loss: 9.69e-01
# Epoch 5280 - Loss: 9.07e-01, Validation loss: 9.69e-01
# Epoch 5290 - Loss: 9.04e-01, Validation loss: 9.69e-01
# Epoch 5300 - Loss: 9.03e-01, Validation loss: 9.69e-01
# Epoch 5310 - Loss: 9.03e-01, Validation loss: 9.69e-01
# Epoch 5320 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5330 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5340 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5350 - Loss: 9.04e-01, Validation loss: 9.68e-01
# Epoch 5360 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5370 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5380 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5390 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5400 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5410 - Loss: 9.04e-01, Validation loss: 9.68e-01
# Epoch 5420 - Loss: 9.04e-01, Validation loss: 9.68e-01
# Epoch 5430 - Loss: 9.05e-01, Validation loss: 9.68e-01
# Epoch 5440 - Loss: 9.04e-01, Validation loss: 9.68e-01
# Epoch 5450 - Loss: 9.06e-01, Validation loss: 9.68e-01
# Epoch 5460 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5470 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5480 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5490 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5500 - Loss: 9.03e-01, Validation loss: 9.68e-01
# Epoch 5510 - Loss: 9.04e-01, Validation loss: 9.67e-01
# Epoch 5520 - Loss: 9.04e-01, Validation loss: 9.68e-01
# Epoch 5530 - Loss: 9.01e-01, Validation loss: 9.67e-01
# Epoch 5540 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5550 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5560 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5570 - Loss: 9.02e-01, Validation loss: 9.67e-01
# Epoch 5580 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5590 - Loss: 9.02e-01, Validation loss: 9.67e-01
# Epoch 5600 - Loss: 9.04e-01, Validation loss: 9.67e-01
# Epoch 5610 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5620 - Loss: 9.04e-01, Validation loss: 9.67e-01
# Epoch 5630 - Loss: 9.04e-01, Validation loss: 9.67e-01
# Epoch 5640 - Loss: 9.01e-01, Validation loss: 9.67e-01
# Epoch 5650 - Loss: 9.05e-01, Validation loss: 9.67e-01
# Epoch 5660 - Loss: 9.02e-01, Validation loss: 9.67e-01
# Epoch 5670 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5680 - Loss: 9.02e-01, Validation loss: 9.67e-01
# Epoch 5690 - Loss: 9.03e-01, Validation loss: 9.67e-01
# Epoch 5700 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5710 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5720 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5730 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5740 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5750 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5760 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5770 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5780 - Loss: 9.03e-01, Validation loss: 9.66e-01
# Epoch 5790 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5800 - Loss: 9.01e-01, Validation loss: 9.66e-01
# Epoch 5810 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5820 - Loss: 9.01e-01, Validation loss: 9.66e-01
# Epoch 5830 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5840 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5850 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5860 - Loss: 9.01e-01, Validation loss: 9.66e-01
# Epoch 5870 - Loss: 9.01e-01, Validation loss: 9.66e-01
# Epoch 5880 - Loss: 9.00e-01, Validation loss: 9.66e-01
# Epoch 5890 - Loss: 9.02e-01, Validation loss: 9.66e-01
# Epoch 5900 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 5910 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 5920 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 5930 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 5940 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 5950 - Loss: 9.03e-01, Validation loss: 9.65e-01
# Epoch 5960 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 5970 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 5980 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 5990 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 6000 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 6010 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 6020 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 6030 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 6040 - Loss: 9.02e-01, Validation loss: 9.65e-01
# Epoch 6050 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 6060 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 6070 - Loss: 9.03e-01, Validation loss: 9.65e-01
# Epoch 6080 - Loss: 9.01e-01, Validation loss: 9.65e-01
# Epoch 6090 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 6100 - Loss: 9.00e-01, Validation loss: 9.65e-01
# Epoch 6110 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6120 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6130 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6140 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6150 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6160 - Loss: 9.02e-01, Validation loss: 9.64e-01
# Epoch 6170 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6180 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6190 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6200 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6210 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6220 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6230 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6240 - Loss: 8.98e-01, Validation loss: 9.64e-01
# Epoch 6250 - Loss: 9.01e-01, Validation loss: 9.64e-01
# Epoch 6260 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6270 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6280 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6290 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6300 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6310 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6320 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6330 - Loss: 9.00e-01, Validation loss: 9.64e-01
# Epoch 6340 - Loss: 8.98e-01, Validation loss: 9.64e-01
# Epoch 6350 - Loss: 8.98e-01, Validation loss: 9.64e-01
# Epoch 6360 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6370 - Loss: 8.99e-01, Validation loss: 9.64e-01
# Epoch 6380 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6390 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6400 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6410 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6420 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6430 - Loss: 9.00e-01, Validation loss: 9.63e-01
# Epoch 6440 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6450 - Loss: 9.00e-01, Validation loss: 9.63e-01
# Epoch 6460 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6470 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6480 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6490 - Loss: 9.00e-01, Validation loss: 9.63e-01
# Epoch 6500 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6510 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6520 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6530 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6540 - Loss: 9.00e-01, Validation loss: 9.63e-01
# Epoch 6550 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6560 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6570 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6580 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6590 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6600 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6610 - Loss: 8.99e-01, Validation loss: 9.63e-01
# Epoch 6620 - Loss: 8.97e-01, Validation loss: 9.63e-01
# Epoch 6630 - Loss: 8.98e-01, Validation loss: 9.63e-01
# Epoch 6640 - Loss: 8.97e-01, Validation loss: 9.63e-01
# Epoch 6650 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6660 - Loss: 8.97e-01, Validation loss: 9.63e-01
# Epoch 6670 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6680 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6690 - Loss: 8.99e-01, Validation loss: 9.62e-01
# Epoch 6700 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6710 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6720 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6730 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6740 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6750 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6760 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6770 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6780 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6790 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6800 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6810 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6820 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6830 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6840 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6850 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6860 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6870 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6880 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6890 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6900 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6910 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6920 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6930 - Loss: 8.98e-01, Validation loss: 9.62e-01
# Epoch 6940 - Loss: 8.97e-01, Validation loss: 9.62e-01
# Epoch 6950 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 6960 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6970 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6980 - Loss: 8.96e-01, Validation loss: 9.62e-01
# Epoch 6990 - Loss: 8.98e-01, Validation loss: 9.61e-01
# Epoch 7000 - Loss: 8.98e-01, Validation loss: 9.61e-01
# Epoch 7010 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7020 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7030 - Loss: 8.98e-01, Validation loss: 9.61e-01
# Epoch 7040 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7050 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7060 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7070 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7080 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7090 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7100 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7110 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7120 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7130 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7140 - Loss: 8.95e-01, Validation loss: 9.61e-01
# Epoch 7150 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7160 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7170 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7180 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7190 - Loss: 8.97e-01, Validation loss: 9.61e-01
# Epoch 7200 - Loss: 8.95e-01, Validation loss: 9.61e-01
# Epoch 7210 - Loss: 8.96e-01, Validation loss: 9.61e-01
# Epoch 7220 - Loss: 8.94e-01, Validation loss: 9.61e-01
# Epoch 7230 - Loss: 8.97e-01, Validation loss: 9.60e-01
# Epoch 7240 - Loss: 8.95e-01, Validation loss: 9.61e-01
# Epoch 7250 - Loss: 8.95e-01, Validation loss: 9.61e-01
# Epoch 7260 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7270 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7280 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7290 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7300 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7310 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7320 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7330 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7340 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7350 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7360 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7370 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7380 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7390 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7400 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7410 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7420 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7430 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7440 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7450 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7460 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7470 - Loss: 8.97e-01, Validation loss: 9.60e-01
# Epoch 7480 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7490 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7500 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7510 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7520 - Loss: 8.95e-01, Validation loss: 9.60e-01
# Epoch 7530 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7540 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7550 - Loss: 8.95e-01, Validation loss: 9.59e-01
# Epoch 7560 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7570 - Loss: 8.96e-01, Validation loss: 9.60e-01
# Epoch 7580 - Loss: 8.94e-01, Validation loss: 9.60e-01
# Epoch 7590 - Loss: 8.95e-01, Validation loss: 9.59e-01
# Epoch 7600 - Loss: 8.94e-01, Validation loss: 9.59e-01
# Restoring model weights from the end of the best epoch: 7552.
# Epoch 7602: early stopping
# 12/12 [==============================] - 0s 8ms/step
# Saved model for fold 1: model_fold1_ens1.h5
# --- Training Model: Fold 2 ---
# Epoch    0 - Loss: 1.00e+00, Validation loss: 9.85e-01
# Epoch   10 - Loss: 1.00e+00, Validation loss: 9.85e-01
# Epoch   20 - Loss: 1.00e+00, Validation loss: 9.85e-01
# Epoch   30 - Loss: 1.00e+00, Validation loss: 9.85e-01
# Epoch   40 - Loss: 1.00e+00, Validation loss: 9.85e-01
# Epoch   50 - Loss: 1.00e+00, Validation loss: 9.84e-01
# Epoch   60 - Loss: 1.00e+00, Validation loss: 9.84e-01
# Epoch   70 - Loss: 1.00e+00, Validation loss: 9.84e-01
# Epoch   80 - Loss: 1.00e+00, Validation loss: 9.83e-01
# Epoch   90 - Loss: 1.00e+00, Validation loss: 9.83e-01
# Epoch  100 - Loss: 1.00e+00, Validation loss: 9.82e-01
# Epoch  110 - Loss: 1.00e+00, Validation loss: 9.81e-01
# Epoch  120 - Loss: 9.99e-01, Validation loss: 9.81e-01
# Epoch  130 - Loss: 9.99e-01, Validation loss: 9.80e-01
# Epoch  140 - Loss: 9.98e-01, Validation loss: 9.79e-01
# Epoch  150 - Loss: 9.97e-01, Validation loss: 9.79e-01
# Epoch  160 - Loss: 9.96e-01, Validation loss: 9.78e-01
# Epoch  170 - Loss: 9.95e-01, Validation loss: 9.77e-01
# Epoch  180 - Loss: 9.94e-01, Validation loss: 9.76e-01
# Epoch  190 - Loss: 9.94e-01, Validation loss: 9.75e-01
# Epoch  200 - Loss: 9.93e-01, Validation loss: 9.74e-01
# Epoch  210 - Loss: 9.91e-01, Validation loss: 9.74e-01
# Epoch  220 - Loss: 9.91e-01, Validation loss: 9.73e-01
# Epoch  230 - Loss: 9.89e-01, Validation loss: 9.72e-01
# Epoch  240 - Loss: 9.89e-01, Validation loss: 9.71e-01
# Epoch  250 - Loss: 9.87e-01, Validation loss: 9.70e-01
# Epoch  260 - Loss: 9.87e-01, Validation loss: 9.69e-01
# Epoch  270 - Loss: 9.85e-01, Validation loss: 9.68e-01
# Epoch  280 - Loss: 9.85e-01, Validation loss: 9.67e-01
# Epoch  290 - Loss: 9.83e-01, Validation loss: 9.66e-01
# Epoch  300 - Loss: 9.82e-01, Validation loss: 9.65e-01
# Epoch  310 - Loss: 9.81e-01, Validation loss: 9.64e-01
# Epoch  320 - Loss: 9.81e-01, Validation loss: 9.63e-01
# Epoch  330 - Loss: 9.80e-01, Validation loss: 9.62e-01
# Epoch  340 - Loss: 9.77e-01, Validation loss: 9.61e-01
# Epoch  350 - Loss: 9.79e-01, Validation loss: 9.60e-01
# Epoch  360 - Loss: 9.76e-01, Validation loss: 9.59e-01
# Epoch  370 - Loss: 9.76e-01, Validation loss: 9.58e-01
# Epoch  380 - Loss: 9.76e-01, Validation loss: 9.57e-01
# Epoch  390 - Loss: 9.72e-01, Validation loss: 9.56e-01
# Epoch  400 - Loss: 9.72e-01, Validation loss: 9.55e-01
# Epoch  410 - Loss: 9.72e-01, Validation loss: 9.54e-01
# Epoch  420 - Loss: 9.70e-01, Validation loss: 9.53e-01
# Epoch  430 - Loss: 9.69e-01, Validation loss: 9.52e-01
# Epoch  440 - Loss: 9.68e-01, Validation loss: 9.52e-01
# Epoch  450 - Loss: 9.67e-01, Validation loss: 9.51e-01
# Epoch  460 - Loss: 9.67e-01, Validation loss: 9.50e-01
# Epoch  470 - Loss: 9.66e-01, Validation loss: 9.49e-01
# Epoch  480 - Loss: 9.63e-01, Validation loss: 9.48e-01
# Epoch  490 - Loss: 9.62e-01, Validation loss: 9.47e-01
# Epoch  500 - Loss: 9.65e-01, Validation loss: 9.47e-01
# Epoch  510 - Loss: 9.61e-01, Validation loss: 9.46e-01
# Epoch  520 - Loss: 9.63e-01, Validation loss: 9.45e-01
# Epoch  530 - Loss: 9.59e-01, Validation loss: 9.44e-01
# Epoch  540 - Loss: 9.59e-01, Validation loss: 9.44e-01
# Epoch  550 - Loss: 9.57e-01, Validation loss: 9.43e-01
# Epoch  560 - Loss: 9.58e-01, Validation loss: 9.42e-01
# Epoch  570 - Loss: 9.59e-01, Validation loss: 9.41e-01
# Epoch  580 - Loss: 9.58e-01, Validation loss: 9.41e-01
# Epoch  590 - Loss: 9.57e-01, Validation loss: 9.40e-01
# Epoch  600 - Loss: 9.57e-01, Validation loss: 9.40e-01
# Epoch  610 - Loss: 9.58e-01, Validation loss: 9.39e-01
# Epoch  620 - Loss: 9.54e-01, Validation loss: 9.38e-01
# Epoch  630 - Loss: 9.55e-01, Validation loss: 9.38e-01
# Epoch  640 - Loss: 9.50e-01, Validation loss: 9.37e-01
# Epoch  650 - Loss: 9.54e-01, Validation loss: 9.37e-01
# Epoch  660 - Loss: 9.52e-01, Validation loss: 9.36e-01
# Epoch  670 - Loss: 9.53e-01, Validation loss: 9.36e-01
# Epoch  680 - Loss: 9.51e-01, Validation loss: 9.35e-01
# Epoch  690 - Loss: 9.52e-01, Validation loss: 9.35e-01
# Epoch  700 - Loss: 9.49e-01, Validation loss: 9.34e-01
# Epoch  710 - Loss: 9.50e-01, Validation loss: 9.34e-01
# Epoch  720 - Loss: 9.51e-01, Validation loss: 9.34e-01
# Epoch  730 - Loss: 9.51e-01, Validation loss: 9.33e-01
# Epoch  740 - Loss: 9.48e-01, Validation loss: 9.33e-01
# Epoch  750 - Loss: 9.48e-01, Validation loss: 9.32e-01
# Epoch  760 - Loss: 9.47e-01, Validation loss: 9.32e-01
# Epoch  770 - Loss: 9.48e-01, Validation loss: 9.32e-01
# Epoch  780 - Loss: 9.45e-01, Validation loss: 9.32e-01
# Epoch  790 - Loss: 9.47e-01, Validation loss: 9.31e-01
# Epoch  800 - Loss: 9.45e-01, Validation loss: 9.31e-01
# Epoch  810 - Loss: 9.48e-01, Validation loss: 9.31e-01
# Epoch  820 - Loss: 9.44e-01, Validation loss: 9.30e-01
# Epoch  830 - Loss: 9.47e-01, Validation loss: 9.30e-01
# Epoch  840 - Loss: 9.46e-01, Validation loss: 9.30e-01
# Epoch  850 - Loss: 9.47e-01, Validation loss: 9.30e-01
# Epoch  860 - Loss: 9.44e-01, Validation loss: 9.29e-01
# Epoch  870 - Loss: 9.42e-01, Validation loss: 9.29e-01
# Epoch  880 - Loss: 9.41e-01, Validation loss: 9.29e-01
# Epoch  890 - Loss: 9.44e-01, Validation loss: 9.29e-01
# Epoch  900 - Loss: 9.47e-01, Validation loss: 9.29e-01
# Epoch  910 - Loss: 9.42e-01, Validation loss: 9.28e-01
# Epoch  920 - Loss: 9.43e-01, Validation loss: 9.28e-01
# ...
# Epoch    0 - Loss: 1.02e+00, Validation loss: 9.38e-01
# Epoch   10 - Loss: 1.02e+00, Validation loss: 9.38e-01
# Epoch   20 - Loss: 1.02e+00, Validation loss: 9.38e-01
# Epoch   30 - Loss: 1.02e+00, Validation loss: 9.38e-01
# Epoch   40 - Loss: 1.01e+00, Validation loss: 9.38e-01
# Epoch   50 - Loss: 1.01e+00, Validation loss: 9.38e-01
# Epoch   60 - Loss: 1.01e+00, Validation loss: 9.37e-01
# Epoch   70 - Loss: 1.01e+00, Validation loss: 9.37e-01
# Epoch   80 - Loss: 1.01e+00, Validation loss: 9.37e-01
# Epoch   90 - Loss: 1.01e+00, Validation loss: 9.36e-01
# Epoch  100 - Loss: 1.01e+00, Validation loss: 9.36e-01
# Epoch  110 - Loss: 1.01e+00, Validation loss: 9.35e-01
# Epoch  120 - Loss: 1.01e+00, Validation loss: 9.34e-01
# Epoch  130 - Loss: 1.01e+00, Validation loss: 9.34e-01
# Epoch  140 - Loss: 1.01e+00, Validation loss: 9.33e-01
# Epoch  150 - Loss: 1.01e+00, Validation loss: 9.32e-01
# Epoch  160 - Loss: 1.01e+00, Validation loss: 9.31e-01
# Epoch  170 - Loss: 1.01e+00, Validation loss: 9.30e-01
# Epoch  180 - Loss: 1.01e+00, Validation loss: 9.29e-01
# Epoch  190 - Loss: 1.01e+00, Validation loss: 9.28e-01
# Epoch  200 - Loss: 1.00e+00, Validation loss: 9.28e-01
# Epoch  210 - Loss: 1.00e+00, Validation loss: 9.26e-01
# Epoch  220 - Loss: 1.00e+00, Validation loss: 9.25e-01
# Epoch  230 - Loss: 1.00e+00, Validation loss: 9.24e-01
# Epoch  240 - Loss: 1.00e+00, Validation loss: 9.23e-01
# Epoch  250 - Loss: 1.00e+00, Validation loss: 9.22e-01
# Epoch  260 - Loss: 9.99e-01, Validation loss: 9.21e-01
# Epoch  270 - Loss: 9.98e-01, Validation loss: 9.20e-01
# Epoch  280 - Loss: 9.97e-01, Validation loss: 9.19e-01
# Epoch  290 - Loss: 9.97e-01, Validation loss: 9.18e-01
# Epoch  300 - Loss: 9.95e-01, Validation loss: 9.17e-01
# Epoch  310 - Loss: 9.94e-01, Validation loss: 9.16e-01
# Epoch  320 - Loss: 9.93e-01, Validation loss: 9.14e-01
# Epoch  330 - Loss: 9.91e-01, Validation loss: 9.13e-01
# Epoch  340 - Loss: 9.91e-01, Validation loss: 9.12e-01
# Epoch  350 - Loss: 9.90e-01, Validation loss: 9.11e-01
# Epoch  360 - Loss: 9.89e-01, Validation loss: 9.10e-01
# Epoch  370 - Loss: 9.86e-01, Validation loss: 9.09e-01
# Epoch  380 - Loss: 9.87e-01, Validation loss: 9.08e-01
# Epoch  390 - Loss: 9.86e-01, Validation loss: 9.07e-01
# Epoch  400 - Loss: 9.85e-01, Validation loss: 9.06e-01
# Epoch  410 - Loss: 9.83e-01, Validation loss: 9.05e-01
# Epoch  420 - Loss: 9.83e-01, Validation loss: 9.03e-01
# Epoch  430 - Loss: 9.81e-01, Validation loss: 9.03e-01
# Epoch  440 - Loss: 9.80e-01, Validation loss: 9.01e-01
# Epoch  450 - Loss: 9.79e-01, Validation loss: 9.01e-01
# Epoch  460 - Loss: 9.80e-01, Validation loss: 9.00e-01
# Epoch  470 - Loss: 9.79e-01, Validation loss: 8.99e-01
# Epoch  480 - Loss: 9.77e-01, Validation loss: 8.98e-01
# Epoch  490 - Loss: 9.76e-01, Validation loss: 8.97e-01
# Epoch  500 - Loss: 9.74e-01, Validation loss: 8.96e-01
# Epoch  510 - Loss: 9.74e-01, Validation loss: 8.95e-01
# Epoch  520 - Loss: 9.73e-01, Validation loss: 8.94e-01
# Epoch  530 - Loss: 9.74e-01, Validation loss: 8.94e-01
# Epoch  540 - Loss: 9.73e-01, Validation loss: 8.93e-01
# Epoch  550 - Loss: 9.73e-01, Validation loss: 8.92e-01
# Epoch  560 - Loss: 9.70e-01, Validation loss: 8.91e-01
# Epoch  570 - Loss: 9.69e-01, Validation loss: 8.90e-01
# Epoch  580 - Loss: 9.72e-01, Validation loss: 8.90e-01
# Epoch  590 - Loss: 9.69e-01, Validation loss: 8.89e-01
# Epoch  600 - Loss: 9.69e-01, Validation loss: 8.88e-01
# Epoch  610 - Loss: 9.68e-01, Validation loss: 8.88e-01
# Epoch  620 - Loss: 9.66e-01, Validation loss: 8.87e-01
# Epoch  630 - Loss: 9.67e-01, Validation loss: 8.86e-01
# Epoch  640 - Loss: 9.67e-01, Validation loss: 8.86e-01
# Epoch  650 - Loss: 9.65e-01, Validation loss: 8.85e-01
# Epoch  660 - Loss: 9.64e-01, Validation loss: 8.85e-01
# Epoch  670 - Loss: 9.65e-01, Validation loss: 8.84e-01
# Epoch  680 - Loss: 9.64e-01, Validation loss: 8.84e-01
# Epoch  690 - Loss: 9.64e-01, Validation loss: 8.83e-01
# Epoch  700 - Loss: 9.64e-01, Validation loss: 8.82e-01
# Epoch  710 - Loss: 9.62e-01, Validation loss: 8.82e-01
# Epoch  720 - Loss: 9.62e-01, Validation loss: 8.81e-01
# Epoch  730 - Loss: 9.63e-01, Validation loss: 8.81e-01
# Epoch  740 - Loss: 9.61e-01, Validation loss: 8.81e-01
# Epoch  750 - Loss: 9.60e-01, Validation loss: 8.80e-01
# Epoch  760 - Loss: 9.62e-01, Validation loss: 8.80e-01
# Epoch  770 - Loss: 9.59e-01, Validation loss: 8.79e-01
# Epoch  780 - Loss: 9.60e-01, Validation loss: 8.79e-01
# Epoch  790 - Loss: 9.58e-01, Validation loss: 8.79e-01
# Epoch  800 - Loss: 9.58e-01, Validation loss: 8.78e-01
# Epoch  810 - Loss: 9.59e-01, Validation loss: 8.78e-01
# Epoch  820 - Loss: 9.60e-01, Validation loss: 8.78e-01
# Epoch  830 - Loss: 9.58e-01, Validation loss: 8.77e-01
# Epoch  840 - Loss: 9.58e-01, Validation loss: 8.77e-01
# Epoch  850 - Loss: 9.57e-01, Validation loss: 8.77e-01
# Epoch  860 - Loss: 9.58e-01, Validation loss: 8.77e-01
# Epoch  870 - Loss: 9.55e-01, Validation loss: 8.76e-01
# Epoch  880 - Loss: 9.56e-01, Validation loss: 8.76e-01
# Epoch  890 - Loss: 9.55e-01, Validation loss: 8.76e-01
# Epoch  900 - Loss: 9.59e-01, Validation loss: 8.76e-01
# Epoch  910 - Loss: 9.57e-01, Validation loss: 8.75e-01
# Epoch  920 - Loss: 9.57e-01, Validation loss: 8.75e-01
# Epoch  930 - Loss: 9.55e-01, Validation loss: 8.75e-01
# Epoch  940 - Loss: 9.56e-01, Validation loss: 8.75e-01
# Epoch  950 - Loss: 9.53e-01, Validation loss: 8.75e-01
# Epoch  960 - Loss: 9.56e-01, Validation loss: 8.74e-01
# Epoch  970 - Loss: 9.55e-01, Validation loss: 8.74e-01
# Epoch  980 - Loss: 9.55e-01, Validation loss: 8.74e-01
# Epoch  990 - Loss: 9.54e-01, Validation loss: 8.74e-01
# Epoch 1000 - Loss: 9.52e-01, Validation loss: 8.74e-01
# Epoch 1010 - Loss: 9.54e-01, Validation loss: 8.74e-01
# Epoch 1020 - Loss: 9.52e-01, Validation loss: 8.74e-01
# Epoch 1030 - Loss: 9.54e-01, Validation loss: 8.73e-01
# Epoch 1040 - Loss: 9.54e-01, Validation loss: 8.73e-01
# Epoch 1050 - Loss: 9.52e-01, Validation loss: 8.73e-01
# Epoch 1060 - Loss: 9.56e-01, Validation loss: 8.73e-01
# Epoch 1070 - Loss: 9.53e-01, Validation loss: 8.73e-01
# Epoch 1080 - Loss: 9.53e-01, Validation loss: 8.73e-01
# Epoch 1090 - Loss: 9.53e-01, Validation loss: 8.73e-01
# Epoch 1100 - Loss: 9.55e-01, Validation loss: 8.73e-01
# Epoch 1110 - Loss: 9.51e-01, Validation loss: 8.72e-01
# Epoch 1120 - Loss: 9.53e-01, Validation loss: 8.72e-01
# Epoch 1130 - Loss: 9.53e-01, Validation loss: 8.72e-01
# Epoch 1140 - Loss: 9.52e-01, Validation loss: 8.72e-01
# Epoch 1150 - Loss: 9.52e-01, Validation loss: 8.72e-01
# Epoch 1160 - Loss: 9.55e-01, Validation loss: 8.72e-01
# Epoch 1170 - Loss: 9.52e-01, Validation loss: 8.72e-01
# Epoch 1180 - Loss: 9.54e-01, Validation loss: 8.72e-01
# Epoch 1190 - Loss: 9.54e-01, Validation loss: 8.72e-01
# Epoch 1200 - Loss: 9.53e-01, Validation loss: 8.72e-01
# Epoch 1210 - Loss: 9.52e-01, Validation loss: 8.72e-01
# Epoch 1220 - Loss: 9.51e-01, Validation loss: 8.72e-01
# Epoch 1230 - Loss: 9.51e-01, Validation loss: 8.71e-01
# Epoch 1240 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1250 - Loss: 9.53e-01, Validation loss: 8.71e-01
# Epoch 1260 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1270 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1280 - Loss: 9.50e-01, Validation loss: 8.71e-01
# Epoch 1290 - Loss: 9.49e-01, Validation loss: 8.71e-01
# Epoch 1300 - Loss: 9.53e-01, Validation loss: 8.71e-01
# Epoch 1310 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1320 - Loss: 9.49e-01, Validation loss: 8.71e-01
# Epoch 1330 - Loss: 9.50e-01, Validation loss: 8.71e-01
# Epoch 1340 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1350 - Loss: 9.50e-01, Validation loss: 8.71e-01
# Epoch 1360 - Loss: 9.51e-01, Validation loss: 8.71e-01
# Epoch 1370 - Loss: 9.49e-01, Validation loss: 8.71e-01
# Epoch 1380 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Epoch 1390 - Loss: 9.52e-01, Validation loss: 8.71e-01
# Restoring model weights from the end of the best epoch: 1348.
# Epoch 1398: early stopping
# 12/12 [==============================] - 0s 8ms/step
# Saved model for fold 4: model_fold4_ens1.h5
# --- Training Model: Fold 5 ---
# Epoch    0 - Loss: 9.94e-01, Validation loss: 1.03e+00
# Epoch   10 - Loss: 9.94e-01, Validation loss: 1.03e+00
# Epoch   20 - Loss: 9.94e-01, Validation loss: 1.03e+00
# Epoch   30 - Loss: 9.93e-01, Validation loss: 1.03e+00
# Epoch   40 - Loss: 9.93e-01, Validation loss: 1.03e+00
# Epoch   50 - Loss: 9.93e-01, Validation loss: 1.03e+00
# Epoch   60 - Loss: 9.93e-01, Validation loss: 1.03e+00
# Epoch   70 - Loss: 9.93e-01, Validation loss: 1.02e+00
# Epoch   80 - Loss: 9.93e-01, Validation loss: 1.02e+00
# Epoch   90 - Loss: 9.92e-01, Validation loss: 1.02e+00
# Epoch  100 - Loss: 9.92e-01, Validation loss: 1.02e+00
# Epoch  110 - Loss: 9.91e-01, Validation loss: 1.02e+00
# Epoch  120 - Loss: 9.91e-01, Validation loss: 1.02e+00
# Epoch  130 - Loss: 9.90e-01, Validation loss: 1.02e+00
# Epoch  140 - Loss: 9.89e-01, Validation loss: 1.02e+00
# Epoch  150 - Loss: 9.88e-01, Validation loss: 1.02e+00
# Epoch  160 - Loss: 9.87e-01, Validation loss: 1.02e+00
# Epoch  170 - Loss: 9.87e-01, Validation loss: 1.02e+00
# Epoch  180 - Loss: 9.86e-01, Validation loss: 1.02e+00
# Epoch  190 - Loss: 9.85e-01, Validation loss: 1.02e+00
# Epoch  200 - Loss: 9.84e-01, Validation loss: 1.01e+00
# Epoch  210 - Loss: 9.83e-01, Validation loss: 1.01e+00
# Epoch  220 - Loss: 9.82e-01, Validation loss: 1.01e+00
# Epoch  230 - Loss: 9.81e-01, Validation loss: 1.01e+00
# Epoch  240 - Loss: 9.81e-01, Validation loss: 1.01e+00
# Epoch  250 - Loss: 9.80e-01, Validation loss: 1.01e+00
# Epoch  260 - Loss: 9.79e-01, Validation loss: 1.01e+00
# Epoch  270 - Loss: 9.78e-01, Validation loss: 1.01e+00
# Epoch  280 - Loss: 9.77e-01, Validation loss: 1.01e+00
# Epoch  290 - Loss: 9.77e-01, Validation loss: 1.01e+00
# Epoch  300 - Loss: 9.74e-01, Validation loss: 1.00e+00
# Epoch  310 - Loss: 9.74e-01, Validation loss: 1.00e+00
# Epoch  320 - Loss: 9.73e-01, Validation loss: 1.00e+00
# Epoch  330 - Loss: 9.72e-01, Validation loss: 1.00e+00
# Epoch  340 - Loss: 9.71e-01, Validation loss: 9.99e-01
# Epoch  350 - Loss: 9.71e-01, Validation loss: 9.98e-01
# Epoch  360 - Loss: 9.70e-01, Validation loss: 9.97e-01
# Epoch  370 - Loss: 9.68e-01, Validation loss: 9.96e-01
# Epoch  380 - Loss: 9.68e-01, Validation loss: 9.95e-01
# Epoch  390 - Loss: 9.67e-01, Validation loss: 9.93e-01
# Epoch  400 - Loss: 9.66e-01, Validation loss: 9.92e-01
# Epoch  410 - Loss: 9.64e-01, Validation loss: 9.91e-01
# Epoch  420 - Loss: 9.63e-01, Validation loss: 9.90e-01
# Epoch  430 - Loss: 9.63e-01, Validation loss: 9.89e-01
# Epoch  440 - Loss: 9.64e-01, Validation loss: 9.88e-01
# Epoch  450 - Loss: 9.61e-01, Validation loss: 9.87e-01
# Epoch  460 - Loss: 9.59e-01, Validation loss: 9.86e-01
# Epoch  470 - Loss: 9.60e-01, Validation loss: 9.84e-01
# Epoch  480 - Loss: 9.59e-01, Validation loss: 9.84e-01
# Epoch  490 - Loss: 9.57e-01, Validation loss: 9.83e-01
# Epoch  500 - Loss: 9.59e-01, Validation loss: 9.82e-01
# Epoch  510 - Loss: 9.56e-01, Validation loss: 9.81e-01
# Epoch  520 - Loss: 9.56e-01, Validation loss: 9.80e-01
# Epoch  530 - Loss: 9.53e-01, Validation loss: 9.79e-01
# Epoch  540 - Loss: 9.52e-01, Validation loss: 9.78e-01
# Epoch  550 - Loss: 9.53e-01, Validation loss: 9.77e-01
# Epoch  560 - Loss: 9.55e-01, Validation loss: 9.76e-01
# Epoch  570 - Loss: 9.52e-01, Validation loss: 9.75e-01
# Epoch  580 - Loss: 9.52e-01, Validation loss: 9.74e-01
# Epoch  590 - Loss: 9.50e-01, Validation loss: 9.74e-01
# Epoch  600 - Loss: 9.49e-01, Validation loss: 9.72e-01
# Epoch  610 - Loss: 9.50e-01, Validation loss: 9.72e-01
# Epoch  620 - Loss: 9.49e-01, Validation loss: 9.71e-01
# Epoch  630 - Loss: 9.49e-01, Validation loss: 9.70e-01
# Epoch  640 - Loss: 9.46e-01, Validation loss: 9.70e-01
# Epoch  650 - Loss: 9.45e-01, Validation loss: 9.69e-01
# Epoch  660 - Loss: 9.46e-01, Validation loss: 9.68e-01
# Epoch  670 - Loss: 9.49e-01, Validation loss: 9.68e-01
# Epoch  680 - Loss: 9.45e-01, Validation loss: 9.67e-01
# Epoch  690 - Loss: 9.45e-01, Validation loss: 9.67e-01
# Epoch  700 - Loss: 9.44e-01, Validation loss: 9.66e-01
# Epoch  710 - Loss: 9.46e-01, Validation loss: 9.65e-01
# Epoch  720 - Loss: 9.47e-01, Validation loss: 9.65e-01
# Epoch  730 - Loss: 9.43e-01, Validation loss: 9.64e-01
# Epoch  740 - Loss: 9.41e-01, Validation loss: 9.63e-01
# Epoch  750 - Loss: 9.43e-01, Validation loss: 9.63e-01
# Epoch  760 - Loss: 9.43e-01, Validation loss: 9.63e-01
# Epoch  770 - Loss: 9.41e-01, Validation loss: 9.62e-01
# Epoch  780 - Loss: 9.43e-01, Validation loss: 9.62e-01
# Epoch  790 - Loss: 9.41e-01, Validation loss: 9.61e-01
# Epoch  800 - Loss: 9.42e-01, Validation loss: 9.61e-01
# Epoch  810 - Loss: 9.38e-01, Validation loss: 9.61e-01
# Epoch  820 - Loss: 9.40e-01, Validation loss: 9.60e-01
# Epoch  830 - Loss: 9.38e-01, Validation loss: 9.60e-01
# Epoch  840 - Loss: 9.39e-01, Validation loss: 9.59e-01
# Epoch  850 - Loss: 9.40e-01, Validation loss: 9.59e-01
# Epoch  860 - Loss: 9.38e-01, Validation loss: 9.59e-01
# Epoch  870 - Loss: 9.39e-01, Validation loss: 9.59e-01
# Epoch  880 - Loss: 9.37e-01, Validation loss: 9.58e-01
# Epoch  890 - Loss: 9.40e-01, Validation loss: 9.58e-01
# Epoch  900 - Loss: 9.39e-01, Validation loss: 9.57e-01
# Epoch  910 - Loss: 9.37e-01, Validation loss: 9.58e-01
# Epoch  920 - Loss: 9.38e-01, Validation loss: 9.57e-01
# Epoch  930 - Loss: 9.36e-01, Validation loss: 9.57e-01
# Epoch  940 - Loss: 9.36e-01, Validation loss: 9.56e-01
# Epoch  950 - Loss: 9.34e-01, Validation loss: 9.56e-01
# Epoch  960 - Loss: 9.36e-01, Validation loss: 9.56e-01
# Epoch  970 - Loss: 9.37e-01, Validation loss: 9.56e-01
# Epoch  980 - Loss: 9.35e-01, Validation loss: 9.55e-01
# Epoch  990 - Loss: 9.37e-01, Validation loss: 9.55e-01
# Epoch 1000 - Loss: 9.35e-01, Validation loss: 9.55e-01
# Epoch 1010 - Loss: 9.35e-01, Validation loss: 9.55e-01
# Epoch 1020 - Loss: 9.35e-01, Validation loss: 9.55e-01
# Epoch 1030 - Loss: 9.37e-01, Validation loss: 9.54e-01
# Epoch 1040 - Loss: 9.35e-01, Validation loss: 9.55e-01
# Epoch 1050 - Loss: 9.37e-01, Validation loss: 9.54e-01
# Epoch 1060 - Loss: 9.36e-01, Validation loss: 9.54e-01
# Epoch 1070 - Loss: 9.34e-01, Validation loss: 9.54e-01
# Epoch 1080 - Loss: 9.34e-01, Validation loss: 9.54e-01
# Epoch 1090 - Loss: 9.33e-01, Validation loss: 9.54e-01
# Epoch 1100 - Loss: 9.33e-01, Validation loss: 9.54e-01
# Epoch 1110 - Loss: 9.35e-01, Validation loss: 9.54e-01
# Epoch 1120 - Loss: 9.33e-01, Validation loss: 9.54e-01
# Epoch 1130 - Loss: 9.36e-01, Validation loss: 9.54e-01
# Epoch 1140 - Loss: 9.35e-01, Validation loss: 9.54e-01
# Epoch 1150 - Loss: 9.32e-01, Validation loss: 9.53e-01
# Epoch 1160 - Loss: 9.34e-01, Validation loss: 9.53e-01
# Epoch 1170 - Loss: 9.31e-01, Validation loss: 9.53e-01
# Epoch 1180 - Loss: 9.34e-01, Validation loss: 9.53e-01
# Epoch 1190 - Loss: 9.33e-01, Validation loss: 9.53e-01
# Epoch 1200 - Loss: 9.34e-01, Validation loss: 9.53e-01
# Epoch 1210 - Loss: 9.32e-01, Validation loss: 9.53e-01
# Epoch 1220 - Loss: 9.35e-01, Validation loss: 9.53e-01
# Epoch 1230 - Loss: 9.32e-01, Validation loss: 9.53e-01
# Epoch 1240 - Loss: 9.35e-01, Validation loss: 9.53e-01
# Epoch 1250 - Loss: 9.33e-01, Validation loss: 9.53e-01
# Epoch 1260 - Loss: 9.34e-01, Validation loss: 9.53e-01
# Epoch 1270 - Loss: 9.35e-01, Validation loss: 9.52e-01
# Epoch 1280 - Loss: 9.31e-01, Validation loss: 9.53e-01
# Epoch 1290 - Loss: 9.32e-01, Validation loss: 9.52e-01
# Epoch 1300 - Loss: 9.32e-01, Validation loss: 9.52e-01
# Epoch 1310 - Loss: 9.33e-01, Validation loss: 9.52e-01
# Epoch 1320 - Loss: 9.34e-01, Validation loss: 9.52e-01
# Epoch 1330 - Loss: 9.30e-01, Validation loss: 9.52e-01
# Epoch 1340 - Loss: 9.31e-01, Validation loss: 9.52e-01
# Epoch 1350 - Loss: 9.28e-01, Validation loss: 9.52e-01
# Epoch 1360 - Loss: 9.32e-01, Validation loss: 9.52e-01
# Epoch 1370 - Loss: 9.30e-01, Validation loss: 9.52e-01
# Epoch 1380 - Loss: 9.32e-01, Validation loss: 9.52e-01
# Epoch 1390 - Loss: 9.30e-01, Validation loss: 9.52e-01
# Epoch 1400 - Loss: 9.33e-01, Validation loss: 9.52e-01
# Epoch 1410 - Loss: 9.32e-01, Validation loss: 9.52e-01
# Restoring model weights from the end of the best epoch: 1370.
# Epoch 1420: early stopping
# 12/12 [==============================] - 0s 9ms/step
# Saved model for fold 5: model_fold5_ens1.h5
#
# ✅ Training with {num_folds}-fold cross-validation finished!

# %%
# --- 6. Post-Training Analysis and Visualization ---
print("\n--- Starting Post-Training Analysis ---")
Model_pred_zonal = np.concatenate(trained_model_predictions, axis=0)
y_truth_zonal = y # Use the un-normalized ground truth for comparison
print(f"Shape of final truth data for analysis: {y_truth_zonal.shape}")
print(f"Shape of final prediction data for analysis: {Model_pred_zonal.shape}")

# --- Calculate and Print Overall Pattern Correlation ---
print("\n    Calculating Overall Pattern Correlation...")
from scipy.stats import pearsonr # Ensure this is imported

# Flatten the 2D [time, lat] matrices into 1D vectors
truth_flat = y_truth_zonal.flatten()
pred_flat = Model_pred_zonal.flatten()

# Calculate Pearson correlation between the two flattened vectors
pattern_r, _ = pearsonr(truth_flat, pred_flat)

# Print the single pattern correlation value
print(f"✅ Overall Pattern Correlation (r) = {pattern_r:.4f}")

# --- 3. UPDATED: Plot R-squared as a Function of Latitude ---
print("\n    Calculating and plotting R-squared per latitude...")
from sklearn.metrics import r2_score # Ensure this is imported
r2_by_latitude = []
# Use num_latitudes, which should be defined from your data loading cell (e.g., len(lat))
for i in range(num_latitudes):
    # Calculate R-squared score for each latitude time series
    r2 = r2_score(y_truth_zonal[:, i], Model_pred_zonal[:, i])
    r2_by_latitude.append(r2)

# Plot R2 vs. Latitude
plt.figure(figsize=(10, 6))
plt.plot(lat, r2_by_latitude, marker='o', linestyle='-')
plt.title('Model Performance (R²) by Latitude', fontsize=16)
plt.xlabel('Latitude', fontsize=12)
plt.ylabel('R-squared Score', fontsize=12)
plt.grid(True, linestyle='--'); plt.ylim(0, 1)
plt.tight_layout()
# Use your 'output_dir' variable for saving
plt.savefig(os.path.join(output_dir, 'R2_vs_Latitude.png'), dpi=300)
plt.show()

# --- 4. Plot Truth vs. Prediction as a 2D Contour Map ---
print("\n    Plotting Truth vs. Prediction as contour maps...")
time_axis = np.arange(y_truth_zonal.shape[0])

# Use constrained_layout=True to automatically handle spacing
fig, axes = plt.subplots(1, 2, figsize=(20, 7), constrained_layout=True, sharey=True)

# Set the single color scale based on the ground truth
vmax = np.percentile(np.abs(y_truth_zonal), 98)
vmin = -vmax

# --- Plot Ground Truth ---
axes[0].set_title('Ground Truth TOA Zonal Mean', fontsize=16)
axes[0].contourf(time_axis, lat, y_truth_zonal.T, levels=20, cmap='RdBu_r', vmin=vmin, vmax=vmax)
axes[0].set_xlabel('Time (Years)', fontsize=12)
axes[0].set_ylabel('Latitude', fontsize=12)

# --- Plot Model Prediction ---
axes[1].set_title('Predicted TOA Zonal Mean', fontsize=16)
# Capture the output of this plot for the color bar
cf = axes[1].contourf(time_axis, lat, Model_pred_zonal.T, levels=20, cmap='RdBu_r', vmin=vmin, vmax=vmax)
axes[1].set_xlabel('Time (Years)', fontsize=12)

# --- Create Color Bar and Title ---
# Create the color bar for the whole figure
fig.colorbar(cf, ax=axes.ravel().tolist(), shrink=0.8, label='TOA Anomaly (W/m²)')
# Set a main title for the figure
fig.suptitle('In-Sample Performance for Zonal-Mean Prediction', fontsize=20, weight='bold')

# Save and show the figure. No need for fig.tight_layout().
plt.savefig(os.path.join(output_dir, 'Truth_vs_Prediction_ZonalMean.png'), dpi=300)
plt.show()
# Out:
# --- Starting Post-Training Analysis ---
# Shape of final truth data for analysis: (1801, 192)
# Shape of final prediction data for analysis: (1801, 192)
#
#     Calculating Overall Pattern Correlation...
# ✅ Overall Pattern Correlation (r) = 0.2625
#
#     Calculating and plotting R-squared per latitude...
#     Plotting Truth vs. Prediction as contour maps...
