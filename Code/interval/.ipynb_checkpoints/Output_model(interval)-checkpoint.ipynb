# %%
"""
Created on Mon Feb 24 10:04:04 2025

@author: hwei
"""


# V3 25-03-2025 updated normalization


import os
import gc
import logging
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import tensorflow as tf
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
from keras import regularizers
from keras.models import Model
from keras.layers import Dense,LeakyReLU, Dropout, Add, Activation, Conv2D, Flatten, MaxPooling2D, Dense, PReLU
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.utils import plot_model
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import Callback
from matplotlib.colors import Normalize
from sklearn.preprocessing import FunctionTransformer
tf.keras.utils.set_random_seed(0)
tf.config.list_physical_devices('GPU')  
tf.compat.v1.disable_eager_execution()
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="keras.engine.training_v1")
import xarray as xr
import innvestigate
import scipy.io as sio
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
# Out:
# 2025-07-03 06:09:39.162787: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-03 06:09:40.487010: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-03 06:09:40.737644: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pwd
# Out:
# /jet/home/ezhu3/Code/interval

# %%
# --- Experiment Configuration ---
# 1. DEFINE a list of how you want to divide the data.
#    This corresponds to your colleague's 'PartialDataTot'.
#    e.g., [1, 2, 4, 10, 20] will run the experiment for the full dataset,
#    then for 2 halves, 4 quarters, 10 tenths, and 20 twentieths.
INTERVAL_DIVISIONS = [1, 2, 4, 10, 20]

# 2. DEFINE the directory where you want to save all the trained models.
OUTPUT_MODEL_DIR = '/ocean/projects/ees250004p/ezhu3/data/CESM1/trained_models_by_interval'

# 3. This code creates the directory if it doesn't already exist.
os.makedirs(OUTPUT_MODEL_DIR, exist_ok=True)

# 4. (Optional) This dictionary will store the file paths of every model we train.
#    It will be very useful in the next phase (evaluation).
all_model_paths = {}

print("Configuration set. Models will be saved in:", OUTPUT_MODEL_DIR)
# Out:
# Configuration set. Models will be saved in: /ocean/projects/ees250004p/ezhu3/data/CESM1/trained_models_by_interval

# %% [markdown]
# ##IMPORTANT!!
# NEED TO CHANGE INPUT/OUTPUT path for CESM1/CESM2

# %%
# load the input variable -- global Surface temperature

#CESM1 control
ds = xr.open_dataset("/ocean/projects/ees250004p/ezhu3/data/CESM1/control/input.B1850C5CN.TS.ANN.0400-2200.new.nc")

#CESM2 data 1: 
#ds = xr.open_dataset("/ocean/projects/ees250004p/ezhu3/data/CESM2/control/input.CESM2-B1850.TS_detrend.ANN.nc")

#CESM2 data2:
#ds = xr.open_dataset("/ocean/projects/ees250004p/ezhu3/data/CESM2/control/input.CESM2-B1850.TS.ANN.nc")

#ds = xr.open_dataset("E:\\Yue\\CESM2\\control\\input.CESM2-B1850.TS_detrend.ANN.nc")# Display dataset info
print(ds)

# Access a specific variable
TS = ds["TS_anom"] # Surface temperature (radiative)     units = 'K'
lat = ds["lat"] #latitude
lon = ds["lon"] #longitude
time = ds["time"]


# Define the directory where the output variables are stored
data_dir = '/ocean/projects/ees250004p/ezhu3/data/CESM1/control' #this is for CESM1
# Define the filenames and corresponding variable names
files = {
    #CESM1:
    "TOA_anom": "output.B1850C5CN.TOA.gmean.ANN.0400-2200.new.nc"
    
    #CESM2 data 1:
    #"TOA_anom": "output.CESM2-B1850.TOA_detrend.ANN.nc"
    #CESM2 data 2:
    #"TOA_anom": "output.CESM2-B1850.TOA.ANN.nc"
}

datasets = {}
# Load variables
for var, filename in files.items():
    file_path = os.path.join(data_dir, filename)
    ds = xr.open_dataset(file_path)
    datasets[var] = ds[var]  # Extract only the variable


# Now the variables can be accessed as datasets["CRE"], datasets["TOA"], etc.
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 192, lon: 288, time: 1801)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) int64 400 401 402 403 404 405 ... 2196 2197 2198 2199 2200
# Data variables:
#     TS       (time, lat, lon) float32 ...
#     TS_anom  (time, lat, lon) float32 ...
# Attributes:
#     script:   /glade/work/dongy24/Python/create_input_for_huaiyu.ipynb
#     author:   Y. Dong, 03/24/2025

# %%
# Neural network architecture:
# Example: [64, 64, 64] means three hidden layers, each containing 64 neurons.
kernels = [32, 32]
kernel_acts =  ["gelu", "gelu"]
kernel_size = 3
stride = 1
rng_seed = 42
hiddens = [16, 8]
activation_function_dense = ["PRelu", "PRelu"]
pool_size = 2

# Loss function for regression tasks:
# Options: 'mse' (mean squared error), 'mae' (mean absolute error), 'mape' (mean absolute percentage error)
# Full list of regression losses: https://keras.io/api/losses/
loss_function = 'mse'


reg_strength = 0         # L2 regularization strength; 1e-1~1e-5
dropout_rate = 0.25         # Dropout rate (0.0 to disable dropout)


# low-pass filter time scale; 0 means no low-pass filter
LPF_year = 0


#### normalization
remove_mean = 0
divide_std = 1


#### usually we do not change the parameters below 

# Training configuration
epoch_max = 25000            # Maximum number of training epochs
batch_size = 32            # Batch size used during training
learning_rate = 0.000005       # Default learning rate for Adam optimizer 0.001
num_folds = 5 # Number of fold during cross-validation
NNrepeats = 1 # Repeat the training for NNrepeats times

# %%
# input_raw = TS.values.reshape(TS.shape[0],TS.shape[1]*TS.shape[2])
# For CNN, we don't need to flatten the data
input_raw = TS.values



# Define the variable names as a comma-separated string
# names_strALL = "CRE,FLNT,FSNT,LCC,LWCF,SWCF,TCC,TOA"
# If we only want to reconstruct TOA
names_strALL = "TOA_anom"
names_str = "TOA_anom"

output_raw = datasets[names_str].values.reshape(-1,1)

# %%
def create_NN_name():

    NN_name = 'CNN'
        
    activation_function_str = '_'+kernel_acts[0]+ '+'+activation_function_dense[0] 
    loss_function_str = '_'+str(loss_function)+'loss' if loss_function!='mse' else ''
    
    if remove_mean + divide_std == 0:
        scaler_str = 'NoScaler_'
    elif remove_mean + divide_std == 2:
        scaler_str = 'StandardScaler_'
    elif remove_mean:
        scaler_str = 'RemoveMean_'
    elif divide_std:
        scaler_str = 'DivideSTD_'
    LPF_str = f'_LPF{int(LPF_year)}Year' if LPF_year else ''
    NN_structure_str = 'x'.join(map(str, kernels)) 
    reg_str = f'Reg{reg_strength}' + (f'Drop{dropout_rate}' if dropout_rate != 0 else '')
    batch_size_str =  f'BS{batch_size}_' if batch_size !=600 else ''
    return f"{NN_name}_{scaler_str}Neur{NN_structure_str}_{batch_size_str}{num_folds}foldCV_{reg_str}{loss_function_str}{activation_function_str}{LPF_str}"
NN_name = create_NN_name()

    
def construct_output_directory(data_dir, NN_name):
    output_dir = os.path.join(data_dir, 'NeuralNet', NN_name, names_str)
    os.makedirs(output_dir, exist_ok=True)
    return output_dir

output_dir = construct_output_directory(data_dir, NN_name)

# %%
logger_name = 'logfile.log'  
# Configure logger
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# Create handlers
file_handler = logging.FileHandler(os.path.join(output_dir, logger_name))
console_handler = logging.StreamHandler()

# Set level and format for handlers
file_handler.setLevel(logging.INFO)
console_handler.setLevel(logging.INFO)

formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# Test the setup
logger.info("logfile")

 
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    logger.info("Using GPU for training.")
    logger.info(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
else:
    logger.info("Using CPU for training.") 

logger.info(os.getenv('TF_GPU_ALLOCATOR'))
    
logger.info(f"Output path: {'created successfully' if os.path.exists(output_dir) else 'already exists'}")
logger.info(f"The output path is {output_dir}")
# Out:
# 2025-07-03 06:09:52,778 - logfile
# 2025-07-03 06:09:52.784051: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-03 06:09:53,785 - Using GPU for training.
# 2025-07-03 06:09:53.779873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2025-07-03 06:09:53,786 - 1 Physical GPUs, 1 Logical GPUs
# 2025-07-03 06:09:53,787 - None
# 2025-07-03 06:09:53,787 - Output path: created successfully
# 2025-07-03 06:09:53,788 - The output path is /ocean/projects/ees250004p/ezhu3/data/CESM1/control/NeuralNet/CNN_DivideSTD_Neur32x32_BS32_5foldCV_Reg0Drop0.25_gelu+PRelu/TOA_anom

# %%
logger.info('------------------------------------------------------------------------')
logger.info('------------------------------------------------------------------------')
logger.info(f'Applying {LPF_year}-year low pass filter ...')
logger.info('------------------------------------------------------------------------')
logger.info('------------------------------------------------------------------------')

from scipy.signal import butter, sosfilt

def apply_low_pass_filter(data, cutoff_freq, order=5, sampling_rate=1, padding_length=None):
    """Applies a Butterworth low-pass filter to the given data."""
    sos = butter(order, cutoff_freq, btype='low', output='sos', analog=False, fs=sampling_rate)
    
    # Apply Boundary Padding to the data before filtering
    padded_data = np.pad(data, [(padding_length, padding_length), (0, 0)], mode='reflect')
    
    # Apply the filter across each column without explicit looping
    filtered_data = sosfilt(sos, padded_data, axis=0)
    
    # Remove padding
    return filtered_data[padding_length:-padding_length]

if LPF_year:
    # Calculate the sampling rate (monthly data)
    sampling_rate = 1  # Data is sampled monthly    
    cutoff_freq = 1 / LPF_year
    order = 5
    padding_length =  3* LPF_year

if LPF_year:
    input = apply_low_pass_filter(input_raw, cutoff_freq, order, sampling_rate, padding_length)     
    output= apply_low_pass_filter(output_raw, cutoff_freq, order, sampling_rate, padding_length)     
    
    plt.figure(figsize=(30, 6))  
    plt.plot(time, output_raw, label="Original", color="C0", linewidth=2)  # Use color and linewidth
    plt.plot(time, output, label="Low-pass filtered", color="C1", linestyle="-", linewidth=1.5)  # Dashed line for prediction
    plt.xlabel("Time (year)", fontsize=14)
    plt.ylabel(names_str, fontsize=14)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend(fontsize=12, loc="best")
    plt.savefig(os.path.join(output_dir, names_str+"_LPF.png"), dpi=300, bbox_inches="tight")
    plt.show()
else:
    input  =  input_raw
    output = output_raw

input_full = input
output_full = output

# Add a confirmation print statement
print(f"Full input data shape: {input_full.shape}")
print(f"Full output data shape: {output_full.shape}")
# Out:
# 2025-07-03 06:09:53,798 - ------------------------------------------------------------------------
# 2025-07-03 06:09:53,799 - ------------------------------------------------------------------------
# 2025-07-03 06:09:53,799 - Applying 0-year low pass filter ...
# 2025-07-03 06:09:53,799 - ------------------------------------------------------------------------
# 2025-07-03 06:09:53,800 - ------------------------------------------------------------------------
# Full input data shape: (1801, 192, 288)
# Full output data shape: (1801, 1)

# %%
#######################################################################
#                       define the neural network                     #
#######################################################################

log_path =os.path.join(output_dir, 'training_logs.txt')
os.makedirs(os.path.dirname(log_path), exist_ok=True)
class PrintTrainingOnTextEvery10EpochsCallback(Callback):
    def __init__(self, log_path):
        super().__init__()
        self.log_path = log_path

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 10 == 0:  # Log every 10 epochs
            with open(self.log_path, "a") as log_file:
                log_file.write(
                    f"Epoch: {epoch:>3} | "
                    f"Loss: {logs.get('loss', 0):.2e} | "
#                        f"Accuracy: {logs.get('accuracy', 0):.2e} | "
                    f"Validation loss: {logs.get('val_loss', 0):.2e} |\n "
#                        f"Validation accuracy: {logs.get('val_accuracy', 0):.2e}\n"
                )
                print(
                    f"Epoch {epoch:>3} - "
                    f"Loss: {logs.get('loss', 0):.2e}, "
#                        f"Accuracy: {logs.get('accuracy', 0):.2e}, "
                    f"Validation loss: {logs.get('val_loss', 0):.2e}, "
#                        f"Validation accuracy: {logs.get('val_accuracy', 0):.2e}"
                )

my_callbacks = [
    PrintTrainingOnTextEvery10EpochsCallback(log_path=log_path),
]   
     
def train_model(X_train, y_train, X_test, y_test, y_mean, y_std, model_save_path):
    # ... (your existing initializations for kernels, kernel_acts, hiddens, etc.) ...
    # Ensure 'kernels', 'hiddens' are defined.
    # 'kernel_acts' and 'activation_function_dense' will now control WHICH activation layer to add.

    inputs = tf.keras.Input(shape=(X_train.shape[1:]),)
    layers = inputs

    # Convolutional Layers
    for i, kernel_filters in enumerate(kernels): # Assuming kernels is a list of filter numbers
        layers = Conv2D(
            kernel_filters,
            (kernel_size, kernel_size), # Assuming kernel_size is defined
            strides=(stride, stride),     # Assuming stride is defined
            use_bias=True,
            padding="same",
            # NO 'activation' argument here if PReLU or another layer follows
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming kernel_acts[i] could be 'prelu', 'gelu', 'relu', etc.
        if kernel_acts[i].lower() == 'prelu':
            layers = PReLU(shared_axes=[1, 2],
                           alpha_initializer=tf.keras.initializers.Constant(0.25) # Common starting point
                          )(layers) # shared_axes for Conv2D with channels_last
        elif kernel_acts[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers) # Using Activation layer for GeLU
        elif kernel_acts[i]: # For 'relu', 'elu', etc.
            layers = tf.keras.layers.Activation(kernel_acts[i])(layers)
        # If kernel_acts[i] is None or an empty string, no explicit activation layer added here.

        layers = MaxPooling2D((pool_size, pool_size))(layers) # Assuming pool_size is defined
    
    layers = Flatten()(layers)

    # Dense Layers
    for i, hidden_units in enumerate(hiddens): # Assuming hiddens is a list of unit numbers
        layers = Dense(
            hidden_units,
            use_bias=True,
            # NO 'activation' argument here
            bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
            kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        )(layers)

        # Apply PReLU (or other chosen activation)
        # Assuming activation_function_dense[i] could be 'prelu', 'gelu', 'elu', etc.
        if activation_function_dense[i].lower() == 'prelu':
            layers = PReLU(alpha_initializer=tf.keras.initializers.Constant(0.25))(layers) # No shared_axes for Dense
        elif activation_function_dense[i].lower() == 'gelu':
            layers = tf.keras.layers.Activation('gelu')(layers)
        elif activation_function_dense[i]: # For 'elu', 'relu', etc.
            layers = tf.keras.layers.Activation(activation_function_dense[i])(layers)
        # If activation_function_dense[i] is None or an empty string, no explicit activation layer.

    output_layer = Dense(
        y_train.shape[-1], # Assuming y_train is (samples, features_out) or (samples,)
        activation="linear",
        use_bias=True,
        bias_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
        kernel_initializer=tf.keras.initializers.RandomNormal(seed=rng_seed),
    )(layers)
    
    model = Model(inputs, output_layer)

    # ... (rest of your model compilation, summary, plotting, training, saving) ...
    # Example:
    if fold_no + ens_no == 2: # Assuming these are defined in your script's scope
        model.summary()
        # ... (your summary saving and plot_model code) ...

    model.compile(loss=loss_function, optimizer=Adam(learning_rate=learning_rate)) # Assuming these are defined

    early_stopping = EarlyStopping(patience=10, monitor='val_loss', mode='auto', restore_best_weights=True, verbose=1) # restore_best_weights=1 is True

    # Make sure my_callbacks is defined in this scope or passed as an argument
    history = model.fit(X_train, y_train, epochs=epoch_max, batch_size=batch_size,
                        validation_data=(X_test, y_test), callbacks=[early_stopping] + my_callbacks, verbose=0) # Added '+' for list concatenation
    history_path = model_save_path.replace('.h5', '_history.npy')
    np.save(history_path, history.history)
    skill = model.evaluate(X_test, y_test, verbose=0)
    pred = (model.predict(X_test) * y_std) + y_mean # Make sure y_std and y_mean are defined

    R2_val = []
    truth = (y_test * y_std) + y_mean
    for latind in range(truth.shape[1] if truth.ndim > 1 else 1): # Handle if y_test is 1D output
        y_lat = truth[:, latind] if truth.ndim > 1 else truth
        y_pred_lat = pred[:, latind] if pred.ndim > 1 else pred
        R2_val.append(r2_score(y_lat, y_pred_lat))
    
    model.save(model_save_path)
    # Use the model_save_path to create matching file names
    pred_path = model_save_path.replace('.h5', '_pred.npy')
    truth_path = model_save_path.replace('.h5', '_truth.npy')
    np.save(pred_path, pred)
    np.save(truth_path, truth)
    
    return skill, history, pred, R2_val

# %%
#######################################################################
#                             Train loop                              #
#######################################################################
# Master loop for iterating through different interval divisions (e.g., 1, 2, 4, 10, 20)
for total_segments in INTERVAL_DIVISIONS:
    print(f"============================================================")
    print(f"STARTING EXPERIMENT FOR {total_segments} TOTAL SEGMENT(S)")
    print(f"============================================================")
    
    all_model_paths[total_segments] = []
    segment_length = input_full.shape[0] // total_segments

    # Loop for each individual segment within a division
    for segment_num in range(1, total_segments + 1):
        print(f"--- Training on Segment #{segment_num} of {total_segments} ---")

        # 1. SLICE THE DATA for this specific experiment
        start_index = (segment_num - 1) * segment_length
        end_index = segment_num * segment_length
        
        X = input_full[start_index:end_index] # This now defines X for the K-fold loop
        y = output_full[start_index:end_index] # This now defines y for the K-fold loop
        
        print(f"   Data for this run has shape: {X.shape}")
    
        X_mean = np.mean(X, axis=0)
        X_std = np.std(X, axis=0)
        
        y_mean = np.mean(y, axis=0)
        y_std = np.std(y, axis=0)
        
        if remove_mean ==0:
            X_mean = 0
            y_mean = 0            
        if divide_std ==0:
            X_std = 1
            y_std = 1
        else:
            X_std = X_std[:,:, tf.newaxis]           
        sio.savemat(os.path.join(output_dir,'Normalization.mat'), 
                    {'X_mean': X_mean, 'X_std': X_std,'y_mean':y_mean,'y_std':y_std})        
        # if not os.path.exists(os.path.join(output_dir, 'inputs_info.mat')):

        trained_models = []
        y_pred_reconstructed_allfolds = []
           
        # Train the neural network multiple times using k-fold cross validation
        # Define the K-fold Cross Validator
        kfold = KFold(n_splits=num_folds, shuffle=False)
        fold_no = 1
        for trainind, testind in kfold.split(X, y):   
            # break
            X_train = X[trainind,:,:, tf.newaxis]
            y_train = y[trainind,:]
            X_test = X[testind,:, :,tf.newaxis]
            y_test = y[testind,:]
         
            # Normalize the input and out data based on the information from the entire PI control run       
            X_train = (X_train - X_mean)/X_std
            X_test = (X_test - X_mean)/X_std
            
            y_train = (y_train - y_mean)/y_std
            y_test = (y_test - y_mean)/y_std
            
            # Generate a print
            logger.info('------------------------------------------------------------------------')
            # We use ensemble training for each fold of the cross-validation
            # Create the full, unique path for the model
            for ens_no  in np.arange(1,NNrepeats+1):
                model_name = f"model_total_{total_segments}_segs_segment_{segment_num}_fold_{fold_no}_ens_{ens_no}.h5"
                model_path = os.path.join(OUTPUT_MODEL_DIR, model_name)
                logger.info(f'Training for fold {fold_no} ensemble {ens_no}...')
                # Pass the new path to the function
                skill, history, pred, R2_val = train_model(X_train, y_train, X_test, y_test, y_mean, y_std, model_path)

                # Also add the path to our dictionary for later
                all_model_paths[total_segments].append(model_path)          
            # Increase fold number
            fold_no = fold_no + 1
            tf.keras.backend.clear_session()
            gc.collect()      
            
logger.info('------------------------------------------------------------------------')
logger.info(f'Training with {num_folds}-fold cross-validation finished!') 
logger.info('------------------------------------------------------------------------')
# Out:
# ============================================================
# STARTING EXPERIMENT FOR 1 TOTAL SEGMENT(S)
# ============================================================
# --- Training on Segment #1 of 1 ---
#    Data for this run has shape: (1801, 192, 288)
# 2025-07-03 06:09:54,521 - ------------------------------------------------------------------------
# 2025-07-03 06:09:54,522 - Training for fold 1 ensemble 1...
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 192, 288, 1)]     0
#
#  conv2d (Conv2D)             (None, 192, 288, 32)      320
#
#  activation (Activation)     (None, 192, 288, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 96, 144, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 96, 144, 32)       9248
#
#  activation_1 (Activation)   (None, 96, 144, 32)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 72, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 110592)            0
#
#  dense (Dense)               (None, 16)                1769488
#
#  p_re_lu (PReLU)             (None, 16)                16
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  p_re_lu_1 (PReLU)           (None, 8)                 8
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,779,225
# Trainable params: 1,779,225
# Non-trainable params: 0
# _________________________________________________________________
# 2025-07-03 06:09:54.888783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2025-07-03 06:09:54.911093: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2025-07-03 06:09:56.349793: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8201
# Epoch   0 - Loss: 9.73e-01, Validation loss: 1.06e+00,
# Epoch  10 - Loss: 6.54e-01, Validation loss: 7.42e-01,
# Epoch  20 - Loss: 4.04e-01, Validation loss: 4.87e-01,
# Epoch  30 - Loss: 3.13e-01, Validation loss: 3.94e-01,
# Epoch  40 - Loss: 2.58e-01, Validation loss: 3.50e-01,
# Epoch  50 - Loss: 2.22e-01, Validation loss: 3.18e-01,
# Epoch  60 - Loss: 1.99e-01, Validation loss: 3.00e-01,
# Epoch  70 - Loss: 1.82e-01, Validation loss: 2.85e-01,
# Epoch  80 - Loss: 1.69e-01, Validation loss: 2.75e-01,
# Epoch  90 - Loss: 1.58e-01, Validation loss: 2.67e-01,
# Epoch 100 - Loss: 1.49e-01, Validation loss: 2.60e-01,
# Epoch 110 - Loss: 1.40e-01, Validation loss: 2.55e-01,
# Epoch 120 - Loss: 1.33e-01, Validation loss: 2.52e-01,
# Epoch 130 - Loss: 1.26e-01, Validation loss: 2.50e-01,
# Epoch 140 - Loss: 1.20e-01, Validation loss: 2.50e-01,
# Epoch 150 - Loss: 1.14e-01, Validation loss: 2.48e-01,
# Epoch 160 - Loss: 1.09e-01, Validation loss: 2.48e-01,
# Restoring model weights from the end of the best epoch: 157.
# Epoch 167: early stopping
# 2025-07-03 06:13:52,292 - ------------------------------------------------------------------------
# 2025-07-03 06:13:52,293 - Training for fold 2 ensemble 1...
# 2025-07-03 06:13:52.579134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 1.00e+00, Validation loss: 9.40e-01,
# Epoch  10 - Loss: 7.04e-01, Validation loss: 6.40e-01,
# Epoch  20 - Loss: 4.51e-01, Validation loss: 4.14e-01,
# Epoch  30 - Loss: 3.59e-01, Validation loss: 3.39e-01,
# Epoch  40 - Loss: 3.06e-01, Validation loss: 2.93e-01,
# Epoch  50 - Loss: 2.66e-01, Validation loss: 2.61e-01,
# Epoch  60 - Loss: 2.37e-01, Validation loss: 2.42e-01,
# Epoch  70 - Loss: 2.17e-01, Validation loss: 2.27e-01,
# Epoch  80 - Loss: 2.01e-01, Validation loss: 2.18e-01,
# Epoch  90 - Loss: 1.89e-01, Validation loss: 2.10e-01,
# Epoch 100 - Loss: 1.79e-01, Validation loss: 2.06e-01,
# Epoch 110 - Loss: 1.70e-01, Validation loss: 2.01e-01,
# Epoch 120 - Loss: 1.62e-01, Validation loss: 1.99e-01,
# Epoch 130 - Loss: 1.54e-01, Validation loss: 1.96e-01,
# Epoch 140 - Loss: 1.48e-01, Validation loss: 1.96e-01,
# Epoch 150 - Loss: 1.42e-01, Validation loss: 1.96e-01,
# Epoch 160 - Loss: 1.37e-01, Validation loss: 1.94e-01,
# Restoring model weights from the end of the best epoch: 158.
# Epoch 168: early stopping
# 2025-07-03 06:17:40,301 - ------------------------------------------------------------------------
# 2025-07-03 06:17:40,302 - Training for fold 3 ensemble 1...
# 2025-07-03 06:17:40.583184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss:
# Epoch 110 - Loss: 1.68e-01, Validation loss: 2.00e-01,
# Epoch 120 - Loss: 1.60e-01, Validation loss: 1.98e-01,
# Epoch 130 - Loss: 1.52e-01, Validation loss: 1.96e-01,
# Epoch 140 - Loss: 1.46e-01, Validation loss: 1.92e-01,
# Epoch 150 - Loss: 1.41e-01, Validation loss: 1.92e-01,
# Restoring model weights from the end of the best epoch: 145.
# Epoch 155: early stopping
# 2025-07-03 06:26:28,515 - ------------------------------------------------------------------------
# 2025-07-03 06:26:28,516 - Training for fold 5 ensemble 1...
# 2025-07-03 06:26:28.798952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 9.71e-01, Validation loss: 1.06e+00,
# Epoch  10 - Loss: 6.84e-01, Validation loss: 7.19e-01,
# Epoch  20 - Loss: 4.49e-01, Validation loss: 4.69e-01,
# Epoch  30 - Loss: 3.51e-01, Validation loss: 3.72e-01,
# Epoch  40 - Loss: 2.95e-01, Validation loss: 3.17e-01,
# Epoch  50 - Loss: 2.54e-01, Validation loss: 2.79e-01,
# Epoch  60 - Loss: 2.27e-01, Validation loss: 2.52e-01,
# Epoch  70 - Loss: 2.08e-01, Validation loss: 2.36e-01,
# Epoch  80 - Loss: 1.94e-01, Validation loss: 2.24e-01,
# Epoch  90 - Loss: 1.83e-01, Validation loss: 2.15e-01,
# Epoch 100 - Loss: 1.73e-01, Validation loss: 2.08e-01,
# Epoch 110 - Loss: 1.64e-01, Validation loss: 2.03e-01,
# Epoch 120 - Loss: 1.57e-01, Validation loss: 1.98e-01,
# Epoch 130 - Loss: 1.50e-01, Validation loss: 1.95e-01,
# Epoch 140 - Loss: 1.43e-01, Validation loss: 1.93e-01,
# Epoch 150 - Loss: 1.37e-01, Validation loss: 1.91e-01,
# Epoch 160 - Loss: 1.32e-01, Validation loss: 1.88e-01,
# Epoch 170 - Loss: 1.27e-01, Validation loss: 1.87e-01,
# Epoch 180 - Loss: 1.22e-01, Validation loss: 1.86e-01,
# Epoch 190 - Loss: 1.17e-01, Validation loss: 1.85e-01,
# Epoch 200 - Loss: 1.13e-01, Validation loss: 1.85e-01,
# Restoring model weights from the end of the best epoch: 197.
# Epoch 207: early stopping
# ============================================================
# STARTING EXPERIMENT FOR 2 TOTAL SEGMENT(S)
# ============================================================
# --- Training on Segment #1 of 2 ---
#    Data for this run has shape: (900, 192, 288)
# 2025-07-03 06:31:17,134 - ------------------------------------------------------------------------
# 2025-07-03 06:31:17,135 - Training for fold 1 ensemble 1...
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 192, 288, 1)]     0
#
#  conv2d (Conv2D)             (None, 192, 288, 32)      320
#
#  activation (Activation)     (None, 192, 288, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 96, 144, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 96, 144, 32)       9248
#
#  activation_1 (Activation)   (None, 96, 144, 32)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 72, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 110592)            0
#
#  dense (Dense)               (None, 16)                1769488
#
#  p_re_lu (PReLU)             (None, 16)                16
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  p_re_lu_1 (PReLU)           (None, 8)                 8
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,779,225
# Trainable params: 1,779,225
# Non-trainable params: 0
# _________________________________________________________________
# 2025-07-03 06:31:17.429897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss:
# Epoch  60 - Loss: 3.08e-01, Validation loss: 3.26e-01,
# Epoch  70 - Loss: 2.79e-01, Validation loss: 3.05e-01,
# Epoch  80 - Loss: 2.54e-01, Validation loss: 2.92e-01,
# Epoch  90 - Loss: 2.33e-01, Validation loss: 2.81e-01,
# Epoch 100 - Loss: 2.17e-01, Validation loss: 2.72e-01,
# Epoch 110 - Loss: 2.01e-01, Validation loss: 2.63e-01,
# Epoch 120 - Loss: 1.88e-01, Validation loss: 2.56e-01,
# Epoch 130 - Loss: 1.76e-01, Validation loss: 2.53e-01,
# Epoch 140 - Loss: 1.66e-01, Validation loss: 2.48e-01,
# Epoch 150 - Loss: 1.57e-01, Validation loss: 2.44e-01,
# Epoch 160 - Loss: 1.48e-01, Validation loss: 2.43e-01,
# Epoch 170 - Loss: 1.40e-01, Validation loss: 2.44e-01,
# Epoch 180 - Loss: 1.33e-01, Validation loss: 2.41e-01,
# Restoring model weights from the end of the best epoch: 177.
# Epoch 187: early stopping
# 2025-07-03 06:41:41,641 - ------------------------------------------------------------------------
# 2025-07-03 06:41:41,642 - Training for fold 5 ensemble 1...
# 2025-07-03 06:41:41.938211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 9.80e-01, Validation loss: 1.04e+00,
# Epoch  10 - Loss: 8.47e-01, Validation loss: 8.80e-01,
# Epoch  20 - Loss: 6.66e-01, Validation loss: 6.78e-01,
# Epoch  30 - Loss: 5.04e-01, Validation loss: 5.03e-01,
# Epoch  40 - Loss: 4.04e-01, Validation loss: 4.01e-01,
# Epoch  50 - Loss: 3.50e-01, Validation loss: 3.45e-01,
# Epoch  60 - Loss: 3.14e-01, Validation loss: 3.10e-01,
# Epoch  70 - Loss: 2.85e-01, Validation loss: 2.81e-01,
# Epoch  80 - Loss: 2.60e-01, Validation loss: 2.58e-01,
# Epoch  90 - Loss: 2.40e-01, Validation loss: 2.40e-01,
# Epoch 100 - Loss: 2.22e-01, Validation loss: 2.28e-01,
# Epoch 110 - Loss: 2.08e-01, Validation loss: 2.18e-01,
# Epoch 120 - Loss: 1.95e-01, Validation loss: 2.12e-01,
# Epoch 130 - Loss: 1.84e-01, Validation loss: 2.07e-01,
# Epoch 140 - Loss: 1.74e-01, Validation loss: 2.04e-01,
# Epoch 150 - Loss: 1.65e-01, Validation loss: 2.00e-01,
# Epoch 160 - Loss: 1.57e-01, Validation loss: 1.98e-01,
# Epoch 170 - Loss: 1.49e-01, Validation loss: 1.96e-01,
# Epoch 180 - Loss: 1.43e-01, Validation loss: 1.94e-01,
# Epoch 190 - Loss: 1.36e-01, Validation loss: 1.92e-01,
# Epoch 200 - Loss: 1.29e-01, Validation loss: 1.92e-01,
# Epoch 210 - Loss: 1.23e-01, Validation loss: 1.91e-01,
# Restoring model weights from the end of the best epoch: 210.
# Epoch 220: early stopping
# --- Training on Segment #2 of 2 ---
#    Data for this run has shape: (900, 192, 288)
# 2025-07-03 06:44:16,696 - ------------------------------------------------------------------------
# 2025-07-03 06:44:16,697 - Training for fold 1 ensemble 1...
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 192, 288, 1)]     0
#
#  conv2d (Conv2D)             (None, 192, 288, 32)      320
#
#  activation (Activation)     (None, 192, 288, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 96, 144, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 96, 144, 32)       9248
#
#  activation_1 (Activation)   (None, 96, 144, 32)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 72, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 110592)            0
#
#  dense (Dense)               (None, 16)                1769488
#
#  p_re_lu (PReLU)             (None, 16)                16
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  p_re_lu_1 (PReLU)           (None, 8)                 8
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,779,225
# Trainable params: 1,779,225
# Non-trainable params: 0
# _________________________________________________________________
# 2025-07-03 06:44:17.007061: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 9.89e-01, Validation loss: 1.02e+00,
# Epoch  10 - Loss: 8.48e-01, Validation loss: 8.72e-01,
# Epoch  20 - Loss: 6.67e-01, Validation loss: 6.99e-01,
# Epoch  30 - Loss: 5.09e-01, Validation loss: 5.58e-01,
# Epoch  40 - Loss: 4.10e-01, Validation loss: 4.72e-01,
# Epoch  50 - Loss: 3.55e-01, Validation loss: 4.24e-01,
# Epoch  60 - Loss: 3.16e-01, Validation loss: 3.86e-01,
# Epoch  70 - Loss: 2.83e-01, Validation loss: 3.54e-01,
# Epoch  80 - Loss: 2.55e-01, Validation loss: 3.28e-01,
# Epoch  90 - Loss: 2.32e-01, Validation loss: 3.08e-01,
# Epoch 100 - Loss: 2.12e-01, Validation loss: 2.94e-01,
# Epoch 110 - Loss: 1.96e-01, Validation loss: 2.83e-01,
# Epoch 120 - Loss: 1.82e-01, Validation loss: 2.75e-01,
# Epoch 130 - Loss: 1.70e-01, Validation loss: 2.69e-01,
# Epoch 140 - Loss: 1.59e-01, Validation loss: 2.64e-01,
# Epoch 150 - Loss: 1.49e-01, Validation loss: 2.61e-01,
# Epoch 160 - Loss: 1.41e-01, Validation loss: 2.58e-01,
# Epoch 170 - Loss: 1.33e-01, Validation loss: 2.56e-01,
# Epoch 180 - Loss: 1.26e-01, Validation loss: 2.54e-01,
# Epoch 190 - Loss: 1.19e-01, Validation loss: 2.52e-01,
# Epoch 200 - Loss: 1.13e-01, Validation loss: 2.51e-01,
# Epoch 210 - Loss: 1.07e-01, Validation loss: 2.50e-01,
# Epoch 220 - Loss: 1.01e-01, Validation loss: 2.49e-01,
# Epoch 230 - Loss: 9.62e-02, Validation loss: 2.49e-01,
# Restoring model weights from the end of the best epoch: 227.
# Epoch 237: early stopping
# 2025-07-03 06:47:03,312 - ------------------------------------------------------------------------
# 2025-07-03 06:47:03,313 - Training for fold 2 ensemble 1...
# 2025-07-03 06:47:03.612120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 1.04e+00, Validation loss: 8.27e-01,
# Epoch  10 - Loss: 8.87e-01, Validation loss: 7.20e-01,
# Epoch  20 - Loss: 6.93e-01, Validation loss: 5.85e-01,
# Epoch  30 - Loss: 5.24e-01, Validation loss: 4.73e-01,
# Epoch  40 - Loss: 4.21e-01, Validation loss: 4.12e-01,
# Epoch  50 - Loss: 3.63e-01, Validation loss: 3.80e-01,
# Epoch  60 - Loss: 3.22e-01, Validation loss: 3.53e-01,
# Epoch  70 - Loss: 2.90e-01, Validation loss: 3.27e-01,
# Epoch  80 - Loss: 2.63e-01, Validation loss: 3.02e-01,
# Epoch 110 - Loss: 1.99e-01, Validation loss: 2.54e-01,
# Epoch 120 - Loss: 1.86e-01, Validation loss: 2.50e-01,
# Epoch 130 - Loss: 1.74e-01, Validation loss: 2.46e-01,
# Epoch 140 - Loss: 1.64e-01, Validation loss: 2.43e-01,
# Epoch 150 - Loss: 1.55e-01, Validation loss: 2.40e-01,
# Epoch 160 - Loss: 1.47e-01, Validation loss: 2.36e-01,
# Epoch 170 - Loss: 1.39e-01, Validation loss: 2.35e-01,
# Epoch 180 - Loss: 1.32e-01, Validation loss: 2.32e-01,
# Epoch 190 - Loss: 1.25e-01, Validation loss: 2.30e-01,
# Epoch 200 - Loss: 1.18e-01, Validation loss: 2.28e-01,
# Epoch 210 - Loss: 1.12e-01, Validation loss: 2.27e-01,
# Epoch 220 - Loss: 1.06e-01, Validation loss: 2.26e-01,
# Epoch 230 - Loss: 1.01e-01, Validation loss: 2.25e-01,
# Epoch 240 - Loss: 9.57e-02, Validation loss: 2.24e-01,
# Epoch 250 - Loss: 9.07e-02, Validation loss: 2.23e-01,
# Epoch 260 - Loss: 8.61e-02, Validation loss: 2.23e-01,
# Epoch 270 - Loss: 8.14e-02, Validation loss: 2.22e-01,
# Epoch 280 - Loss: 7.70e-02, Validation loss: 2.21e-01,
# Restoring model weights from the end of the best epoch: 278.
# Epoch 288: early stopping
# 2025-07-03 06:58:50,245 - ------------------------------------------------------------------------
# 2025-07-03 06:58:50,246 - Training for fold 1 ensemble 1...
# ============================================================
# STARTING EXPERIMENT FOR 4 TOTAL SEGMENT(S)
# ============================================================
# --- Training on Segment #1 of 4 ---
#    Data for this run has shape: (450, 192, 288)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 192, 288, 1)]     0
#
#  conv2d (Conv2D)             (None, 192, 288, 32)      320
#
#  activation (Activation)     (None, 192, 288, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 96, 144, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 96, 144, 32)       9248
#
#  activation_1 (Activation)   (None, 96, 144, 32)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 72, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 110592)            0
#
#  dense (Dense)               (None, 16)                1769488
#
#  p_re_lu (PReLU)             (None, 16)                16
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  p_re_lu_1 (PReLU)           (None, 8)                 8
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,779,225
# Trainable params: 1,779,225
# Non-trainable params: 0
# _________________________________________________________________
# 2025-07-03 06:58:50.540001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 9.52e-01, Validation loss: 1.17e+00,
# Epoch  10 - Loss: 8.97e-01, Validation loss: 1.11e+00,
# Epoch  20 - Loss: 8.19e-01, Validation loss: 1.03e+00,
# Epoch  30 - Loss: 7.30e-01, Validation loss: 9.27e-01,
# Epoch  40 - Loss: 6.38e-01, Validation loss: 8.23e-01,
# Epoch  50 - Loss: 5.51e-01, Validation loss: 7.23e-01,
# Epoch  60 - Loss: 4.76e-01, Validation loss: 6.34e-01,
# Epoch  70 - Loss: 4.18e-01, Validation loss: 5.66e-01,
# Epoch  80 - Loss: 3.74e-01, Validation loss: 5.13e-01,
# Epoch  90 - Loss: 3.41e-01, Validation loss: 4.76e-01,
# Epoch 100 - Loss: 3.16e-01, Validation loss: 4.48e-01,
# Epoch 510 - Loss: 1.14e-01, Validation loss: 4.12e-01,
# Epoch 520 - Loss: 1.11e-01, Validation loss: 4.10e-01,
# Epoch 530 - Loss: 1.07e-01, Validation loss: 4.10e-01,
# Epoch 540 - Loss: 1.04e-01, Validation loss: 4.07e-01,
# Epoch 550 - Loss: 1.01e-01, Validation loss: 4.06e-01,
# Restoring model weights from the end of the best epoch: 549.
# Epoch 559: early stopping
# 2025-07-03 09:18:21,380 - ------------------------------------------------------------------------
# 2025-07-03 09:18:21,381 - Training for fold 3 ensemble 1...
# 2025-07-03 09:18:21.666441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31088 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# Epoch   0 - Loss: 9.25e-01, Validation loss: 1.28e+00,
# Epoch  10 - Loss: 9.17e-01, Validation loss: 1.27e+00,
# Epoch  20 - Loss: 9.05e-01, Validation loss: 1.25e+00,
# Epoch  30 - Loss: 8.88e-01, Validation loss: 1.23e+00,
# Epoch  40 - Loss: 8.69e-01, Validation loss: 1.21e+00,
# Epoch  50 - Loss: 8.48e-01, Validation loss: 1.18e+00,
# Epoch  60 - Loss: 8.26e-01, Validation loss: 1.15e+00,
# Epoch  70 - Loss: 8.03e-01, Validation loss: 1.13e+00,
# Epoch  80 - Loss: 7.80e-01, Validation loss: 1.10e+00,
# Epoch  90 - Loss: 7.57e-01, Validation loss: 1.08e+00,
# Epoch 100 - Loss: 7.30e-01, Validation loss: 1.05e+00,
# Epoch 110 - Loss: 7.03e-01, Validation loss: 1.02e+00,
# Epoch 120 - Loss: 6.77e-01, Validation loss: 9.89e-01,
# Epoch 130 - Loss: 6.49e-01, Validation loss: 9.58e-01,
# Epoch 140 - Loss: 6.20e-01, Validation loss: 9.26e-01,
# Epoch 150 - Loss: 5.92e-01, Validation loss: 9.00e-01,
# Epoch 160 - Loss: 5.62e-01, Validation loss: 8.68e-01,
# Epoch 170 - Loss: 5.34e-01, Validation loss: 8.39e-01,
# Epoch 180 - Loss: 5.05e-01, Validation loss: 8.09e-01,
# Epoch 190 - Loss: 4.79e-01, Validation loss: 7.81e-01,
# Epoch 200 - Loss: 4.51e-01, Validation loss: 7.52e-01,
# Epoch 210 - Loss: 4.25e-01, Validation loss: 7.27e-01,
# Epoch 220 - Loss: 3.99e-01, Validation loss: 7.00e-01,
# Epoch 230 - Loss: 3.75e-01, Validation loss: 6.73e-01,
# Epoch 240 - Loss: 3.52e-01, Validation loss: 6.45e-01,
# Epoch 250 - Loss: 3.31e-01, Validation loss: 6.24e-01,
# Epoch 260 - Loss: 3.12e-01, Validation loss: 6.05e-01,
# Epoch 270 - Loss: 2.93e-01, Validation loss: 5.81e-01,
# Epoch 280 - Loss: 2.76e-01, Validation loss: 5.66e-01,
# Epoch 290 - Loss: 2.61e-01, Validation loss: 5.51e-01,
# Epoch 300 - Loss: 2.48e-01, Validation loss: 5.37e-01,
# Epoch 310 - Loss: 2.36e-01, Validation loss: 5.29e-01,
# Epoch 320 - Loss: 2.25e-01, Validation loss: 5.22e-01,
# Epoch 330 - Loss: 2.15e-01, Validation loss: 5.20e-01,
# Epoch 340 - Loss: 2.07e-01, Validation loss: 5.08e-01,
# Epoch  50 - Loss: 9.24e-01, Validation loss: 8.80e-01,
# Epoch  60 - Loss: 9.04e-01, Validation loss: 8.56e-01,
# Epoch  70 - Loss: 8.84e-01, Validation loss: 8.31e-01,
# Epoch  80 - Loss: 8.63e-01, Validation loss: 8.06e-01,
# Epoch  90 - Loss: 8.42e-01, Validation loss: 7.80e-01,
# Epoch 100 - Loss: 8.18e-01, Validation loss: 7.50e-01,
# Epoch 110 - Loss: 7.91e-01, Validation loss: 7.18e-01,
# Epoch 120 - Loss: 7.65e-01, Validation loss: 6.89e-01,
# Epoch 130 - Loss: 7.39e-01, Validation loss: 6.58e-01,
# Epoch 140 - Loss: 7.11e-01, Validation loss: 6.27e-01,
# Epoch 150 - Loss: 6.83e-01, Validation loss: 5.96e-01,
# Epoch 160 - Loss: 6.54e-01, Validation loss: 5.66e-01,
# Epoch 170 - Loss: 6.24e-01, Validation loss: 5.36e-01,
# Epoch 180 - Loss: 5.94e-01, Validation loss: 5.04e-01,
# Epoch 190 - Loss: 5.63e-01, Validation loss: 4.72e-01,
# Epoch 200 - Loss: 5.34e-01, Validation loss: 4.43e-01,
# Epoch 210 - Loss: 5.06e-01, Validation loss: 4.15e-01,
# Epoch 220 - Loss: 4.78e-01, Validation loss: 3.88e-01,
# Epoch 230 - Loss: 4.50e-01, Validation loss: 3.62e-01,
# Epoch 240 - Loss: 4.22e-01, Validation loss: 3.37e-01,
# Epoch 250 - Loss: 3.97e-01, Validation loss: 3.16e-01,
# Epoch 260 - Loss: 3.73e-01, Validation loss: 2.97e-01,
# Epoch 270 - Loss: 3.50e-01, Validation loss: 2.79e-01,
# Epoch 280 - Loss: 3.30e-01, Validation loss: 2.64e-01,
# Epoch 290 - Loss: 3.10e-01, Validation loss: 2.50e-01,
# Epoch 300 - Loss: 2.92e-01, Validation loss: 2.39e-01,
# Epoch 310 - Loss: 2.75e-01, Validation loss: 2.28e-01,
# Epoch 320 - Loss: 2.60e-01, Validation loss: 2.18e-01,
# Epoch 330 - Loss: 2.46e-01, Validation loss: 2.10e-01,
# Epoch 340 - Loss: 2.34e-01, Validation loss: 2.04e-01,
# Epoch 350 - Loss: 2.23e-01, Validation loss: 1.99e-01,
# Epoch 360 - Loss: 2.13e-01, Validation loss: 1.95e-01,
# Epoch 370 - Loss: 2.03e-01, Validation loss: 1.92e-01,
# Epoch 380 - Loss: 1.95e-01, Validation loss: 1.92e-01,
# Epoch 390 - Loss: 1.87e-01, Validation loss: 1.91e-01,
# Epoch 400 - Loss: 1.80e-01, Validation loss: 1.90e-01,
# Epoch 410 - Loss: 1.74e-01, Validation loss: 1.89e-01,
# Restoring model weights from the end of the best epoch: 406.
# Epoch 416: early stopping
# 2025-07-03 09:20:11,596 - ------------------------------------------------------------------------
# 2025-07-03 09:20:11,596 - Training with 5-fold cross-validation finished!
# 2025-07-03 09:20:11,597 - ------------------------------------------------------------------------

# %%
#######################################################################
#                                                                     #
#                  SUMMARY PLOTTING AND ANALYSIS(Loss Curve)          #
#                                                                     #
#######################################################################

print("--- Starting Summary Plot Generation ---")

# Loop through each of the interval configurations that we tested.
# e.g., total_segments will be 1, then 2, then 4, etc.
for total_segments in INTERVAL_DIVISIONS:
    
    # --- 1. Setup the Plot ---
    # Create a new figure for this specific interval size.
    plt.figure(figsize=(12, 8))
    
    # Get the list of all model paths that were trained for this configuration.
    # We retrieve this from the dictionary we populated during training.
    model_paths_for_interval = all_model_paths.get(total_segments, [])
    
    if not model_paths_for_interval:
        print(f"No models found for {total_segments} segments. Skipping.")
        continue

    # This list will hold the validation loss history from each model run
    all_val_losses = []
    shortest_epoch_count = float('inf') # We need to find the shortest training run

    # --- 2. Plot Individual Loss Curves ---
    # Loop through each model file path for the current interval size.
    for model_path in model_paths_for_interval:
        # Construct the path to the corresponding history file
        history_path = model_path.replace('.h5', '_history.npy')
        
        try:
            # Load the history dictionary from the .npy file
            # allow_pickle=True is required to load a dictionary object.
            # .item() extracts the dictionary from the numpy array wrapper.
            history = np.load(history_path, allow_pickle=True).item()
            
            # Get the validation loss from the history
            val_loss = history['val_loss']
            
            # Plot this model's validation loss curve.
            # We use a low alpha to make it semi-transparent. This helps see density.
            plt.plot(val_loss, color='dodgerblue', alpha=0.3)
            
            # Store the validation loss history for calculating the median later
            all_val_losses.append(val_loss)
            
            # Keep track of the length of the shortest training run.
            # This is necessary because EarlyStopping makes each run have a different length.
            if len(val_loss) < shortest_epoch_count:
                shortest_epoch_count = len(val_loss)

        except FileNotFoundError:
            print(f"Warning: Could not find history file: {history_path}")
            continue

    # --- 3. Plot the Median Loss Curve ---
    # This gives us a robust "average" of all the training runs.
    if all_val_losses:
        # Create a new list where all loss histories are truncated to the same length
        truncated_losses = [loss[:shortest_epoch_count] for loss in all_val_losses]
        
        # Convert the list of lists into a 2D NumPy array
        loss_matrix = np.array(truncated_losses)
        
        # Calculate the median loss at each epoch across all runs
        median_loss_curve = np.median(loss_matrix, axis=0)
        
        # Plot the median curve with a thick, solid, contrasting line to make it stand out
        plt.plot(median_loss_curve, color='crimson', linewidth=3, label=f'Median Validation Loss ({len(all_val_losses)} runs)')

    # --- 4. Finalize and Save the Plot ---
    plt.yscale('log') # Use a logarithmic scale for the y-axis to better see changes
    plt.title(f'Validation Loss Curves for {total_segments} Data Segment(s)', fontsize=16)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Validation Loss (Log Scale)', fontsize=12)
    plt.grid(True, which="both", ls="--", alpha=0.5)
    plt.legend(fontsize=12)
    
    # Create a descriptive filename for the plot
    plot_filename = f'summary_loss_curve_total_{total_segments}_segments.png'
    # Save the figure to the same directory where the models are stored
    plt.savefig(os.path.join(OUTPUT_MODEL_DIR, plot_filename), dpi=300, bbox_inches='tight')
    
    # Display the plot in the notebook
    plt.show()

print("\n--- All Summary Plots Have Been Generated. ---")
# Out:
# --- Starting Summary Plot Generation ---
# --- All Summary Plots Have Been Generated. ---

# %%
#######################################################################
#                                                                     #
#                  SUMMARY SCATTER PLOT GENERATION(Scatter plot)      #
#                                                                     #
#######################################################################

print("--- Starting Summary Scatter Plot Generation ---")

# Loop through each of the interval configurations (e.g., 1, 2, 4, 10, 20)
for total_segments in INTERVAL_DIVISIONS:
    
    # These lists will collect the data from all folds and ensembles for this interval size
    all_predictions = []
    all_truths = []
    
    print(f"\n--- Generating plot for {total_segments} segment(s) ---")
    
    # Now, we reconstruct the file paths to load the data for each fold
    for segment_num in range(1, total_segments + 1):
        for fold_no in range(1, num_folds + 1):
            for ens_no in range(1, NNrepeats + 1):
                # Recreate the unique model name to find the corresponding data files
                model_name = f"model_total_{total_segments}_segs_segment_{segment_num}_fold_{fold_no}_ens_{ens_no}.h5"
                model_path = os.path.join(OUTPUT_MODEL_DIR, model_name)
                
                pred_path = model_path.replace('.h5', '_pred.npy')
                truth_path = model_path.replace('.h5', '_truth.npy')
                
                try:
                    # Load the saved prediction and truth arrays
                    pred = np.load(pred_path)
                    truth = np.load(truth_path)
                    
                    # Add the loaded data to our master lists
                    all_predictions.append(pred)
                    all_truths.append(truth)

                except FileNotFoundError:
                    # This handles cases where a specific fold/ensemble might not have run
                    print(f"Warning: Could not find data for {model_name}")
                    continue

    if not all_predictions:
        print("No data found to plot for this interval.")
        continue
        
    # --- Data Aggregation and Plotting ---
    
    # Concatenate all the arrays in the lists into single large arrays
    final_predictions = np.concatenate(all_predictions)
    final_truths = np.concatenate(all_truths)

    # --- Plotting - Styled like your example ---
    plt.figure(figsize=(8, 8))
    
    # Scatter plot of the data points
    plt.plot(final_predictions, final_truths, 'o', markersize=5, alpha=0.6, label="Data Points")

    # Determine plot limits to make the plot square
    min_val = min(np.min(final_predictions), np.min(final_truths))
    max_val = max(np.max(final_predictions), np.max(final_truths))
    plt.xlim(min_val, max_val)
    plt.ylim(min_val, max_val)
    
    # 1:1 Reference Line
    plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label="1:1 Reference")
    
    # Calculate and display the overall R² score
    r2 = r2_score(final_truths, final_predictions)
    plt.text(0.05, 0.9, f"$R^2$: {r2:.3f}", transform=plt.gca().transAxes,
             fontsize=14, bbox=dict(facecolor="white", alpha=0.8, edgecolor="black"))

    # Labels, title, and formatting
    plt.xlabel("Prediction", fontsize=16, fontweight='bold')
    plt.ylabel("Truth", fontsize=16, fontweight='bold')
    plt.title(f'Truth vs. Prediction for {total_segments} Data Segment(s)', fontsize=16)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.legend(fontsize=12, loc="lower right")
    plt.axis("equal") # Ensure the plot is square
    
    # Save and show the plot
    plot_filename = f'summary_scatter_total_{total_segments}_segments.png'
    plt.savefig(os.path.join(OUTPUT_MODEL_DIR, plot_filename), dpi=300, bbox_inches='tight')
    plt.show()

print("\n--- All Summary Scatter Plots Have Been Generated. ---")
# Out:
# --- Starting Summary Scatter Plot Generation ---
#
# --- Generating plot for 1 segment(s) ---
# --- Generating plot for 2 segment(s) ---
# --- Generating plot for 4 segment(s) ---
# --- Generating plot for 10 segment(s) ---
# --- Generating plot for 20 segment(s) ---
# --- All Summary Scatter Plots Have Been Generated. ---
